# %% [markdown]
# # Один из возможных алгоритмов скрейпинга
#
# * указать в коде адрес интересующего сайта: откуда вы хотите скачать данные?
# для этого используется библиотека requests
#
# * сохранить веб-страницу (html-код страницы)
#
# * выбрать данные, которые нужно собрать (используется BeautifulSoup)
#
# * записать данные в csv-файл.
#
# Если нужно соскрейпить несколько страниц - повторяем процесс для каждой из них.

# %% [markdown]
# **Наша задача:** выгрузить недавние новости в датафрейм `pandas`, чтобы потом сохранить все в csv-файл.
#
# Сначала сгрузим весь html-код страницы и сохраним его в отдельную переменную. Для этого нам понадобится библиотека `requests`. Документация: https://requests.readthedocs.io/en/latest/
#
# Импортируем её:

# %%
import requests

# %% [markdown]
# Сохраним ссылку на главную страницу сайта в переменную `url` для удобства и выгрузим страницу. (Разумеется, это будет работать при подключении к интернету. Если соединение будет отключено, Python выдаст `NewConnectionError`).

# %%
url = 'https://nplus1.ru/' # сохраняем
page = requests.get(url) # загружаем страницу по ссылке

# %% [markdown]
# Если мы просто посмотрим на объект, мы ничего особенного не увидим:

# %%
page  # response 200 - страница загружена
# Out:
# <Response [200]>

# %% [markdown]
# **BeautifulSoup** - python-библиотека для синтаксического разбора файлов HTML/XML. В веб-разработке «суп из тегов» (tag soup) - это слово для синтаксически или структурно некорректного HTML, написанного для веб-страницы.
#
# Документация: https://www.crummy.com/software/BeautifulSoup/bs4/doc/
#
# Импортируем функцию `BeautifulSoup` из библиотеки `bs4` (от *beautifulsoup4*) и заберём со страницы `page` код html в виде текста.
#
# Сохраним в переменную 'soup' весь HTML-код страницы. HTML-код - это "дерево тегов", формирующее контент страницы.

# %%
# !pip install bs4

# %%
from bs4 import BeautifulSoup 
# название - отсылка к песне про суп из Алисы в стране чудес https://aliceinwonderland.fandom.com/wiki/Turtle_Soup

# %%
soup = BeautifulSoup(page.text, 'html')

# %% [markdown]
# Если выведем `soup` на экран, мы увидим то же самое, что в режиме разработчика или в режиме происмотра исходного кода (`view-source` через *Ctrl+U* в Google Chrome).

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="ru" prefix="og: http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>N + 1 — главное издание о науке, технике и технологиях</title>
# <link as="font" crossorigin="" href="https://staticn1.nplus1.ru/fonts/AeonikPro/AeonikPro-Regular.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://staticn1.nplus1.ru/fonts/Spectral/Spectral-Regular.woff" rel="preload" type="font/woff2"/>
# <link href="/front-build/css/main.css?id=9b496fbb252428c03791da99722528ab" rel="stylesheet"/>
# <link href="/front-build/css/app.css?id=f9c00b5102d287d01698f43324336ca6" rel="stylesheet"/>
# <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/site.webmanifest" rel="manifest"/>
# <link color="#f26e40" href="/safari-pinned-tab.svg" rel="mask-icon"/>
# <meta content="#f26e40" name="msapplication-TileColor"/>
# <meta content="#ffffff" name="theme-color"/>
# <link href="https://nplus1.ru" rel="canonical"/>
# <meta content="8c90b02c84ac3b72" name="yandex-verification"/>
# <meta content="b419949322895fc9106e24ed01be58ac" name="pmail-verification"/>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#
#     })(window,document,'script','dataLayer','GTM-PJWMQBQ');</script>
# <!-- End Google Tag Manager -->
# <meta content="N + 1 - это научно-популярное издание, которое познакомит вас с природными явлениями, открытиями и технологиями, расскажет
#  просто о сложном и поможет узнать что-то новое для себя" name="description"/>
# <meta content="N + 1 — главное издание о науке, технике и технологиях" property="og:site_name"/>
# <meta content="N + 1 — главное издание о науке, технике и технологиях" property="og:title"/>
# <meta content="https://nplus1.ru/images-new/share_snippet.png" property="og:image"/>
# <meta content="https://nplus1.ru" property="og:url"/>
# <meta content="N + 1 — главное издание о науке, технике и технологиях" property="og:description"/>
# <meta content="" property="og:type"/>
# <script type="application/ld+json">
# {
# 	"@context": "http://schema.org",
# 	"@type": "WebSite",
# 	"url": "https://nplus1.ru/",
# 	"name": "N + 1 — главное издание о науке, технике и технологиях",
# 	"description": "N + 1 — главное издание о науке, технике и технологиях",
# 	"image": "https://staticn1.nplus1.ru/image-new/share_snippet.png",
# 	"publisher": {
# 	"@type": "Organization",
# 		"name": "N+1",
# 		"logo": {
# 			"@type":"ImageObject",
# 			"url": "https://staticn1.nplus1.ru/image-new/logo-alt.png"
# 		},
# 		"sameAs": [
# 			"https://www.facebook.com/nplusone",
# 			"https://twitter.com/nplusodin",
# 			"https://vk.com/nplusone",
# 			"https://ok.ru/nplus1",
# 			"https://soundcloud.com/nplus_1",
# 			"https://t.me/nplusone"
# 		]
# 	},
# 	"potentialAction":{
# 		"@type":"SearchAction",
# 		"target":"https://nplus1.ru/search/{search_term_string}",
# 		"query-input":"required name=search_term_string"
# 	}
# }
#
#   </script>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@nplusodin" name="twitter:site"/>
# <meta content="N + 1 — главное издание о науке, технике и технологиях" name="twitter:title"/>
# <meta content="N + 1 — главное издание о науке, технике и технологиях" name="twitter:description"/>
# <meta content="https://nplus1.ru/images-new/share_snippet.png" name="twitter:image"/>
# <link href="https://nplus1.ru/rss" rel="alternate" title="RSS" type="application/rss+xml"/>
# </head>
# <body class="antialiased">
# <!-- Top.Mail.Ru counter -->
# <script type="text/javascript">
#
# var tmr = window.tmr || (window._tmr = []);
#
# _tmr.push({id: "3377932", type: "pageView", start: (new Date()).getTime()});
#
# (function (d, w, id) {
#
#   if (d.getElementById(id)) return;
#
#   var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
#
#   ts.src = "https://top-fwz1.mail.ru/js/code.js";
#
#   var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
#
#   if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
#
# })(document, window, "tmr-code");
#
# </script>
# <noscript><div><img alt="Top.Mail.Ru" src="https://top-fwz1.mail.ru/counter?id=3377932;js=na" style="position:absolute;left:-9999px;"/></div></noscript>
# <!-- /Top.Mail.Ru counter -->
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PJWMQBQ" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <div class="font-aeonik text-main-black flex flex-col min-h-screen pt-15 bg-light-gray" id="appfront">
# <header class="bg-light-gray fixed h-15 left-0 top-0 w-full z-50" data-ref-header="" ref="headerRef">
# <div class="border-b border-main-gray h-full">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto flex justify-between items-center h-full" data-ref-header-container="" ref="headerContainerRef">
# <button aria-label="Go" class="w-7.5 h-7.5" data-ref-header-menu-btn="" id="topMenuBtn" ref="headerMenuBtnRef">
# <template v-if="isOpenDesktopMenu || isOpenMobileMenu">
# <svg class="w-full h-full">
# <use xlink:href="#n1_cross_menu"></use>
# </svg>
# </template>
# <template v-else="">
# <svg class="w-full h-full">
# <use xlink:href="#n1_burger"></use>
# </svg>
# </template>
# </button>
# <div>
# <img alt="as" height="23" loading="lazy" src="https://staticn1.nplus1.ru/image-new/logo.svg" width="57"/>
# </div>
# <a class="w-7.5 h-7.5" href="/search">
# <svg class="w-full h-full">
# <use xlink:href="#n1_pupa"></use>
# </svg>
# </a>
# </div>
# </div>
# <nav :style="stylesNavDesktop" class="relative bg-light-gray max-h-0 n1_top_nav overflow-hidden" id="navMenu" v-if="isOpenDesktopMenu">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto h-full flex flex-col overflow-y-auto">
# <div class="py-12 mb-12 border-b border-gray-2 text-18 grid grid-cols-flow lg:grid-cols-12 gap-x-5 md:gap-x-9">
# <!--
#         <a @click.native="menuClose"
#            class="col-span-3 flex gap-x-2 lg:gap-x-5 items-center hover:text-main transition-colors duration-75"
#            href="/lk">
#           <svg class="h-10 lg:h-12 w-10 lg:w-12 shrink-0">
#             <use xlink:href="#n1_person"></use>
#           </svg>
#           <span>Личный кабинет</span>
#         </a>
#         -->
# <a class="col-span-3 lg:col-span-2 col-start-7 lg:col-start-9 flex items-center hover:text-main transition-colors duration-75" href="https://offline.nplus1.ru/">N + offline</a>
# <a class="col-span-3 lg:col-span-2 col-start-10 lg:col-start-11 flex items-center hover:text-main transition-colors duration-75" href="https://nplus.pro/">N + production</a>
# </div>
# <div class="grid grid-cols-12 gap-x-5 gap-y-5 md:gap-y-9 pb-6">
# <div class="col-span-6 md:col-span-3 text-20 lg:text-26 xl:text-34 font-spectral flex flex-col gap-y-3">
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/about">
#                 О нас
#               </a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/difficult" target="_blank">
#                 Сложность
#               </a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/adv" target="_blank">
#                 Рекламодателям
#               </a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/blog/2022/04/01/samotek" target="_blank">
#                 Авторам
#               </a>
# </div>
# <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=946">Игры</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=869">Физика</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=874">Зоология</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=880">Астрономия</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=768">Генетика</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=890">Математика</a>
# </div>
# <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=871">Космонавтика</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=876">Археология</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=775">Нейронауки</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=767">На мышах</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=771">Звук</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=772">Красота</a>
# </div>
# <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=778">Научные закрытия</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=917">ИИ спешит на помощь</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=918">Когда рассеется дым</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=824">Книжная полка</a>
# </div>
# </div>
# <div class="py-12 mt-auto border-t border-gray-2 text-18 grid grid-cols-12 gap-x-5 md:gap-x-9">
# <ul class="flex gap-2.5">
# <li>
# <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_tg"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_vk"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_ok"></use>
# </svg>
# </a>
# </li>
# <li class="w-12">
# <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_tw"></use>
# </svg>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <nav :style="stylesNavMobile" class="relative bg-white max-h-0 n1_top_nav overflow-hidden" id="mobNavMenu" v-if="isOpenMobileMenu">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto h-full flex flex-col overflow-y-auto">
# <div class="text-30 font-spectral flex flex-col gap-y-5 mb-10 mt-10">
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/about">О нас</a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/difficult" target="_blank">Сложность</a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/adv" target="_blank">Рекламодателям</a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/news/2015/09/21/editor-thy-name" target="_blank">Вакансии</a>
# </div>
# <div class="text-28 text-main flex flex-col gap-y-2.5 mb-10">
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=946">Игры
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=869">Физика
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=874">Зоология
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=880">Астрономия
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=768">Генетика
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=890">Математика
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=871">Космонавтика
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=876">Археология
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=775">Нейронауки
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=767">На мышах
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=771">Звук
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=772">Красота
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=778">Научные закрытия
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=917">ИИ спешит на помощь
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=918">Когда рассеется дым
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=824">Книжная полка
#           </a>
# </div>
# <div class="max-w-full flex py-5 border-t border-gray-2">
# <div class="flex gap-x-5 overflow-x-auto">
# <a class="hover:text-main whitespace-nowrap" href="https://offline.nplus1.ru/">N + offline</a>
# <a class="hover:text-main whitespace-nowrap" href="https://nplus.pro/">N + production</a>
# </div>
# </div>
# <div class="pt-5 pb-10 border-t border-gray-2 text-18">
# <ul class="flex gap-2.5">
# <li>
# <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
# <svg class="w-10 h-10">
# <use xlink:href="#n1_tg"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
# <svg class="w-10 h-10">
# <use xlink:href="#n1_vk"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
# <svg class="w-10 h-10">
# <use xlink:href="#n1_ok"></use>
# </svg>
# </a>
# </li>
# <li class="w-12">
# <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
# <svg class="w-10 h-10">
# <use xlink:href="#n1_tw"></use>
# </svg>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# </header>
# <section class="mb-10">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto mx-auto">
# <div class="grid grid-cols-2 col-span-2 gap-0.5 n1_m_full n1_fs_main">
# <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
# <div class="absolute z-10 top-5 inset-x-4 md:inset-x-5">
# <div class="flex flex-wrap gap-2 text-tags">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=903">Наука</a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/2">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">2.2</span>
# </a>
# </div>
# </div>
# <a class="" href="https://nplus1.ru/material/2023/12/14/nature-top-10-2023">
# <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
# <div class="hidden sm:block max-height-[333px]">
# <div class="-inset-0.5 absolute group">
# <picture>
# <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/867516/014928d934004b2f63bfc59772b5ccaf.png">
# <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/867517/aeeafd2b48b0e0443c09edbcf956a69a.png">
# <img alt="ChatGPT, лунная миссия и мышата от двух отцов" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
# </source></source></picture>
# </div>
# </div>
# <div class="block sm:hidden">
# <div class="-inset-0.5 absolute max-height-[333px]">
# <picture>
# <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/867516/014928d934004b2f63bfc59772b5ccaf.png">
# <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/867517/aeeafd2b48b0e0443c09edbcf956a69a.png">
# <img alt="ChatGPT, лунная миссия и мышата от двух отцов" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
# </source></source></picture>
# </div>
# </div>
# <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
# <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">ChatGPT, лунная миссия и мышата от двух отцов</h3>
# <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#                     Редакция Nature назвала героев уходящего года
#                   </div>
# </div>
# </div>
# </a>
# </div>
# <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
# <div class="absolute z-10 top-5 inset-x-4 md:inset-x-5">
# <div class="flex flex-wrap gap-2 text-tags">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=908">Подкасты</a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=873">Медицина</a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/3">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">3.9</span>
# </a>
# </div>
# </div>
# <a class="" href="https://nplus1.ru/blog/2023/12/14/circle-gets-the-square">
# <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
# <div class="hidden sm:block max-height-[333px]">
# <div class="-inset-0.5 absolute group">
# <picture>
# <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/868087/21e63eb31348fe20076f5635f309d519.gif">
# <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/868088/a741e7e915a37b160a9238e57d19cbe3.gif">
# <img alt="Голова кругом" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
# </source></source></picture>
# <picture>
# <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/868086/05c2ddea46b61fec25b430faf49ea499.gif">
# <img alt="Голова кругом" class="w-full h-full object-cover absolute inset-0 opacity-0 group-hover:opacity-100 transition-opacity duration-500" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
# </source></picture>
# </div>
# </div>
# <div class="block sm:hidden">
# <div class="-inset-0.5 absolute max-height-[333px]">
# <picture>
# <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/868087/21e63eb31348fe20076f5635f309d519.gif">
# <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/868088/a741e7e915a37b160a9238e57d19cbe3.gif">
# <img alt="Голова кругом" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
# </source></source></picture>
# </div>
# </div>
# <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
# <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">Голова кругом</h3>
# <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#                     Есть ли у сосудов мозга углы
#                   </div>
# </div>
# </div>
# </a>
# </div>
# <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
# <div class="absolute z-10 top-5 inset-x-4 md:inset-x-5">
# <div class="flex flex-wrap gap-2 text-tags">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=812">Партнерский материал</a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=872">Экология и климат</a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/1">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">1.1</span>
# </a>
# </div>
# </div>
# <a class="" href="https://nplus1.ru/material/2023/12/14/green-uni-initiatives">
# <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
# <div class="hidden sm:block max-height-[333px]">
# <div class="-inset-0.5 absolute group">
# <picture>
# <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/867448/d70a69ba48c9ab8b204da20326370eff.gif">
# <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/867449/29ac7b1c83fe2a972e776960e3bd84e1.gif">
# <img alt="Не парами едиными" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
# </source></source></picture>
# <picture>
# <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/867447/0edff5ba8e5f864f03f8b4abf994dd31.gif">
# <img alt="Не парами едиными" class="w-full h-full object-cover absolute inset-0 opacity-0 group-hover:opacity-100 transition-opacity duration-500" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
# </source></picture>
# </div>
# </div>
# <div class="block sm:hidden">
# <div class="-inset-0.5 absolute max-height-[333px]">
# <picture>
# <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/867448/d70a69ba48c9ab8b204da20326370eff.gif">
# <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/867449/29ac7b1c83fe2a972e776960e3bd84e1.gif">
# <img alt="Не парами едиными" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
# </source></source></picture>
# </div>
# </div>
# <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
# <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">Не парами едиными</h3>
# <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#                     Как университеты становятся центрами зеленой экономики и экологического просвещения
#                   </div>
# </div>
# </div>
# </a>
# </div>
# <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
# <div class="absolute z-10 top-5 inset-x-4 md:inset-x-5">
# <div class="flex flex-wrap gap-2 text-tags">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=876">Археология</a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/3">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">3.2</span>
# </a>
# </div>
# </div>
# <a class="" href="https://nplus1.ru/news/2023/12/15/human-skin">
# <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
# <div class="hidden sm:block max-height-[333px]">
# <div class="-inset-0.5 absolute group">
# <picture>
# <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/868710/8ca3b9fb4be51fa8cbd4b1d0d2bdf991.jpg">
# <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/868711/8930a9285a9a3de1829e48335f4c3566.jpg">
# <img alt="У скифов нашли изделия из человеческой кожи" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
# </source></source></picture>
# </div>
# </div>
# <div class="block sm:hidden">
# <div class="-inset-0.5 absolute max-height-[333px]">
# <picture>
# <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/868710/8ca3b9fb4be51fa8cbd4b1d0d2bdf991.jpg">
# <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/868711/8930a9285a9a3de1829e48335f4c3566.jpg">
# <img alt="У скифов нашли изделия из человеческой кожи" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
# </source></source></picture>
# </div>
# </div>
# <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
# <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">У скифов нашли изделия из человеческой кожи</h3>
# <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#                     По данным Геродота, они снимали ее с мертвых врагов
#                   </div>
# </div>
# </div>
# </a>
# </div>
# </div>
# </div>
# </section>
# <section class="mb-0 sm:mb-5">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto grid grid-cols-6 sm:grid-cols-12 gap-x-5 md:gap-x-9 relative">
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <div class="inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full">
# <span class="overflow-hidden text-ellipsis whitespace-nowrap">10:28</span>
# </div>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/12/18">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">18.12.23</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=876">
# <p class="truncate">Археология</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">2.5</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/12/18/parasite-eggs-from-granada">
# <div>В старинных выгребных ямах Гранады нашли яйца кишечных паразитов</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <div class="inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full">
# <span class="overflow-hidden text-ellipsis whitespace-nowrap">10:05</span>
# </div>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/12/18">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">18.12.23</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=877">
# <p class="truncate">Антропология</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">1.2</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/12/18/medieval-deformed-skull">
# <div>Женщина с искусственно деформированным черепом обрела лицо</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <div class="inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full">
# <span class="overflow-hidden text-ellipsis whitespace-nowrap">09:34</span>
# </div>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/12/18">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">18.12.23</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=877">
# <p class="truncate">Антропология</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/3">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">3.1</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/12/18/qafzeh-25">
# <div>Архаичного сапиенса из пещеры Кафзех ранили в челюсть</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/12/16">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">16.12.23</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=880">
# <p class="truncate">Астрономия</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/4">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">4.1</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/12/16/jwst-bd-light">
# <div>«Джеймс Уэбб» напрямую рассмотрел кандидата в рекордно легкий одиночный коричневый карлик</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/12/16">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">16.12.23</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=883">
# <p class="truncate">Роботы и дроны</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">1.7</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/12/16/hound-record-100m">
# <div>Корейская робособака установила рекорд среди четвероногих роботов в забеге на 100 метров</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/12/16">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">16.12.23</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=903">
# <p class="truncate">Наука</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">1.9</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/12/16/retracted-2023">
# <div>Больше десяти тысяч научных статей отозвали в 2023 году</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/12/16">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">16.12.23</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=882">
# <p class="truncate">Психология</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/3">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">3.9</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/12/16/turn-off">
# <div>Изменение сознания при медитации зафиксировали на энцефалограмме</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/12/16">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">16.12.23</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=882">
# <p class="truncate">Психология</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">1.8</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/12/16/label-smart">
# <div>Метки «веганский» и «растительный» не привлекли людей к продуктам без мяса</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/12/16">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">16.12.23</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=874">
# <p class="truncate">Зоология</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">1.5</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/12/16/wisdom-dance">
# <div>Самая старая дикая птица вернулась на родной атолл и поучаствовала в брачных танцах</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/12/15">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">15.12.23</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=872">
# <p class="truncate">Экология и климат</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">2.9</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/12/15/cr6-forest-fires">
# <div>Пожары в Калифорнии оказались опасным источником шестивалентного хрома</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/12/15">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">15.12.23</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=871">
# <p class="truncate">Космонавтика</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">1.9</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/12/15/vega-later-final">
# <div>Финальный пуск ракеты Vega перенесли на осень 2024 года</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/12/15">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">15.12.23</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=880">
# <p class="truncate">Астрономия</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/4">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">4.1</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/12/15/cute-hot-jupiter">
# <div>Космический телескоп размером с обувную коробку заметил потерю атмосферы горячим юпитером</div>
# </a>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="mb-0 sm:mb-10">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto grid grid-cols-6 sm:grid-cols-12 gap-x-5 md:gap-x-9">
# <div class="col-span-6">
# <div class="flex flex-col gap-x-9 border-t border-gray-2 pt-5 pb-10 sm:pb-5">
# <a class="shrink-0 h-60 lg:h-72 xl:h-88 relative group" href="https://nplus1.ru/blog/2023/12/14/sex-with-scientists">
# <picture>
# <source media="(max-width: 768px)" srcset="https://minio.nplus1.ru/app-images/867792/65798e669b97e_cover_mobile.png">
# <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/867791/65798e656d8f8_cover_tablet.png">
# <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/867790/65798e644509d_cover.png">
# <img alt="«Секс с учеными: Половое размножение и другие загадки биологии»" class="w-full h-full object-cover" loading="lazy" src="https://minio.nplus1.ru/app-images/867790/65798e644509d_cover.png"/>
# </source></source></source></picture>
# </a>
# <div class="flex flex-col">
# <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags xl:pr-9">
# ...
# <ul class="flex gap-3 text-gray-2">
# <li>
# <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_tg"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_vk"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_ok"></use>
# </svg>
# </a>
# </li>
# <li class="w-12">
# <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_tw"></use>
# </svg>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </footer>
# </div>
# <svg class="stroke-current" fill="none" height="16" id="n1_star" style="display:block;width:0;height:0" viewbox="3 3 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
# <path d="M11 5V17"></path>
# <path d="M6.75781 6.75781L15.2431 15.2431"></path>
# <path d="M17 11L5 11"></path>
# <path d="M15.2422 6.75781L6.75691 15.2431"></path>
# </svg>
# <svg class="stroke-current" fill="none" id="n1_person" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <circle cx="25" cy="25" r="24.5"></circle>
# <path d="M30.1897 30.3212C28.9483 29.9852 27.5345 29.7164 27.5345 28.5067C27.5345 27.8347 27.5 27.0618 28.2931 26.625C31.0172 25.0457 32.5 22.3911 32.1552 18.2581C31.8103 14.0578 29.2586 11 24.9828 11C20.7069 11 18.1552 14.0578 17.8103 18.2581C17.4655 22.3911 18.9138 25.0457 21.6724 26.625C22.4655 27.0618 22.431 27.8347 22.431 28.5067C22.431 29.7164 21.0172 29.9516 19.8103 30.3212C17.3966 30.9933 12.5 31.9005 12.5 36C16.431 36 33.569 36 37.5 36C37.4655 31.9005 32.6034 30.9933 30.1897 30.3212Z" stroke-miterlimit="10"></path>
# </svg>
# <svg fill="none" id="n1_tg" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" d="M16.3181 21.32H19.4961V30H20.7141V21.32H23.8921V20.2H16.3181V21.32ZM28.6969 30.084C30.3769 30.084 31.4269 29.286 31.8749 28.572L31.9589 30H33.0089V24.694H28.8789V25.814H31.8189V26.15C31.8189 27.886 30.5169 28.964 28.7109 28.964C26.6809 28.964 25.3369 27.368 25.3369 25.1C25.3369 22.832 26.6809 21.236 28.7389 21.236C30.2229 21.236 31.2729 22.034 31.6089 23.392H32.9109C32.5749 21.376 30.9369 20.116 28.7669 20.116C25.9249 20.116 24.0909 22.132 24.0909 25.1C24.0909 28.068 25.9809 30.084 28.6969 30.084Z"></path>
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# </svg>
# <svg fill="none" id="n1_vk" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" d="M19.8015 30H21.2715L24.7995 20.2H23.5395L20.5575 28.558L17.5615 20.2H16.2735L19.8015 30ZM25.8768 30H27.0948V27.452L29.0408 25.254L32.3448 30H33.8008L29.9368 24.33L33.5208 20.2H32.0368L27.0948 25.758V20.2H25.8768V30Z"></path>
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# </svg>
# <svg fill="none" id="n1_ok" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" d="M25.2125 25.1C25.2125 22.216 23.2945 20.116 20.5365 20.116C17.7785 20.116 15.8605 22.216 15.8605 25.1C15.8605 27.984 17.7785 30.084 20.5365 30.084C23.2945 30.084 25.2125 27.984 25.2125 25.1ZM17.1065 25.1C17.1065 22.846 18.4925 21.236 20.5365 21.236C22.5805 21.236 23.9665 22.846 23.9665 25.1C23.9665 27.354 22.5805 28.964 20.5365 28.964C18.4925 28.964 17.1065 27.354 17.1065 25.1ZM26.7518 30H27.9698V27.452L29.9158 25.254L33.2198 30H34.6758L30.8118 24.33L34.3958 20.2H32.9118L27.9698 25.758V20.2H26.7518V30Z"></path>
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# </svg>
# <svg fill="none" id="n1_tw" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" d="M14.4792 21.32H17.6572V30H18.8752V21.32H22.0532V20.2H14.4792V21.32ZM25.332 30H26.788L29.014 22.23L31.254 30H32.71L35.58 20.2H34.32L32.01 28.432L29.686 20.2H28.454L26.046 28.432L23.75 20.2H22.476L25.332 30Z"></path>
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# </svg>
# <svg height="64px" id="n1_infinity" preserveaspectratio="xMidYMid" style="display:block;width:0;height:0" viewbox="0 0 100 100" width="64px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <path d="M24.3 30C11.4 30 5 43.3 5 50s6.4 20 19.3 20c19.3 0 32.1-40 51.4-40 C88.6 30 95 43.3 95 50s-6.4 20-19.3 20C56.4 70 43.6 30 24.3 30z" fill="none" stroke="#ffffff" stroke-dasharray="146.25568908691406 110.33323913574219" stroke-linecap="round" stroke-width="5" style="transform:scale(0.8);transform-origin:50px 50px">
# <animate attributename="stroke-dashoffset" dur="1.3157894736842106s" keytimes="0;1" repeatcount="indefinite" values="0;256.58892822265625"></animate>
# </path>
# </svg>
# <svg fill="none" id="n1_cross" style="display:block;width:0;height:0" viewbox="0 0 14 14" xmlns="http://www.w3.org/2000/svg">
# <path d="M1.00146 1L13.0015 13" stroke="#F9F9F9"></path>
# <path d="M13 1L1 13" stroke="#F9F9F9"></path>
# </svg>
# <svg id="n1_link_arrow" style="display:block;width:0;height:0" viewbox="0 0 11 11" xmlns="http://www.w3.org/2000/svg">
# <path d="M10.0738 5.87L5.08775 0.901999L4.15175 1.838L7.51775 5.204H0.19175V6.536H7.51775L4.15175 9.902L5.08775 10.838L10.0738 5.87Z" fill="currentColor"></path>
# </svg>
# <svg id="n1_big_star" style="display:block;width:0;height:0;" viewbox="0 0 61 61" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" clip-rule="evenodd" d="M3 29.7729H29.0656L10.6345 11.3418L11.3416 10.6347L29.7728 29.0658V3H30.7728V29.0658L49.2039 10.6347L49.911 11.3418L31.4799 29.7729H57.5455V30.7729H31.4799L49.9111 49.2042L49.204 49.9113L30.7728 31.4801V57.5455H29.7728V31.4801L11.3415 49.9113L10.6344 49.2042L29.0656 30.7729H3V29.7729Z" fill-rule="evenodd"></path>
# <path class="fill-current" d="M29.0656 29.7729V32.2729H35.1012L30.8334 28.0052L29.0656 29.7729ZM3 29.7729V27.2729H0.5V29.7729H3ZM10.6345 11.3418L8.86676 9.57407L7.099 11.3418L8.86676 13.1096L10.6345 11.3418ZM11.3416 10.6347L13.1094 8.86696L11.3416 7.09919L9.57387 8.86696L11.3416 10.6347ZM29.7728 29.0658L28.005 30.8336L32.2728 35.1014V29.0658H29.7728ZM29.7728 3V0.5H27.2728V3H29.7728ZM30.7728 3H33.2728V0.5H30.7728V3ZM30.7728 29.0658H28.2728V35.1014L32.5405 30.8336L30.7728 29.0658ZM49.2039 10.6347L50.9716 8.86696L49.2039 7.09919L47.4361 8.86696L49.2039 10.6347ZM49.911 11.3418L51.6787 13.1096L53.4465 11.3418L51.6787 9.57407L49.911 11.3418ZM31.4799 29.7729L29.7121 28.0052L25.4443 32.2729H31.4799V29.7729ZM57.5455 29.7729H60.0455V27.2729H57.5455V29.7729ZM57.5455 30.7729V33.2729H60.0455V30.7729H57.5455ZM31.4799 30.7729V28.2729H25.4443L29.7121 32.5407L31.4799 30.7729ZM49.9111 49.2042L51.6789 50.972L53.4466 49.2042L51.6789 47.4364L49.9111 49.2042ZM49.204 49.9113L47.4362 51.6791L49.204 53.4468L50.9718 51.6791L49.204 49.9113ZM30.7728 31.4801L32.5405 29.7123L28.2728 25.4445V31.4801H30.7728ZM30.7728 57.5455V60.0455H33.2728V57.5455H30.7728ZM29.7728 57.5455H27.2728V60.0455H29.7728V57.5455ZM29.7728 31.4801H32.2728V25.4445L28.005 29.7123L29.7728 31.4801ZM11.3415 49.9113L9.57374 51.6791L11.3415 53.4468L13.1093 51.6791L11.3415 49.9113ZM10.6344 49.2042L8.86664 47.4364L7.09887 49.2042L8.86664 50.972L10.6344 49.2042ZM29.0656 30.7729L30.8334 32.5407L35.1012 28.2729H29.0656V30.7729ZM3 30.7729H0.5V33.2729H3V30.7729ZM29.0656 27.2729H3V32.2729H29.0656V27.2729ZM8.86676 13.1096L27.2979 31.5407L30.8334 28.0052L12.4023 9.57407L8.86676 13.1096ZM9.57387 8.86696L8.86676 9.57407L12.4023 13.1096L13.1094 12.4025L9.57387 8.86696ZM31.5405 27.2981L13.1094 8.86696L9.57387 12.4025L28.005 30.8336L31.5405 27.2981ZM27.2728 3V29.0658H32.2728V3H27.2728ZM30.7728 0.5H29.7728V5.5H30.7728V0.5ZM33.2728 29.0658V3H28.2728V29.0658H33.2728ZM32.5405 30.8336L50.9716 12.4025L47.4361 8.86696L29.005 27.2981L32.5405 30.8336ZM47.4361 12.4025L48.1432 13.1096L51.6787 9.57407L50.9716 8.86696L47.4361 12.4025ZM48.1432 9.57407L29.7121 28.0052L33.2476 31.5407L51.6787 13.1096L48.1432 9.57407ZM57.5455 27.2729H31.4799V32.2729H57.5455V27.2729ZM60.0455 30.7729V29.7729H55.0455V30.7729H60.0455ZM31.4799 33.2729H57.5455V28.2729H31.4799V33.2729ZM51.6789 47.4364L33.2476 29.0052L29.7121 32.5407L48.1433 50.972L51.6789 47.4364ZM50.9718 51.6791L51.6789 50.972L48.1433 47.4364L47.4362 48.1435L50.9718 51.6791ZM29.005 33.2478L47.4362 51.6791L50.9718 48.1435L32.5405 29.7123L29.005 33.2478ZM33.2728 57.5455V31.4801H28.2728V57.5455H33.2728ZM29.7728 60.0455H30.7728V55.0455H29.7728V60.0455ZM27.2728 31.4801V57.5455H32.2728V31.4801H27.2728ZM28.005 29.7123L9.57374 48.1435L13.1093 51.6791L31.5405 33.2478L28.005 29.7123ZM13.1093 48.1435L12.4022 47.4364L8.86664 50.972L9.57374 51.6791L13.1093 48.1435ZM12.4022 50.972L30.8334 32.5407L27.2979 29.0052L8.86664 47.4364L12.4022 50.972ZM3 33.2729H29.0656V28.2729H3V33.2729ZM0.5 29.7729V30.7729H5.5V29.7729H0.5Z"></path>
# </svg>
# <svg class="stroke-current" fill="none" id="n1_circle_arrow" style="display:block;width:0;height:0" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
# <rect height="29" rx="14.5" transform="rotate(-180 29.5 29.5)" width="29" x="29.5" y="29.5"></rect>
# <path d="M9.33985 14.7014L14.6198 19.9414L15.2598 19.3014L11.1198 15.1614L20.3398 15.1614L20.3398 14.2214L11.1198 14.2214L15.2598 10.0814L14.6198 9.44141L9.33985 14.7014Z"></path>
# </svg>
# <svg fill="none" id="n1_circle_arrow_solid" style="display:block;width:0;height:0" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
# <mask id="path-1-inside-1_2694_77554">
# <path clip-rule="evenodd" d="M15 0C6.71573 0 0 6.71573 0 15C0 23.2843 6.71573 30 15 30C23.2843 30 30 23.2843 30 15C30 6.71573 23.2843 0 15 0ZM15.3792 10.0601L20.6592 15.3001L15.3792 20.5601L14.7392 19.9201L18.8792 15.7801H9.65918V14.8401H18.8792L14.7392 10.7001L15.3792 10.0601Z" fill-rule="evenodd"></path>
# </mask>
# <path clip-rule="evenodd" d="M15 0C6.71573 0 0 6.71573 0 15C0 23.2843 6.71573 30 15 30C23.2843 30 30 23.2843 30 15C30 6.71573 23.2843 0 15 0ZM15.3792 10.0601L20.6592 15.3001L15.3792 20.5601L14.7392 19.9201L18.8792 15.7801H9.65918V14.8401H18.8792L14.7392 10.7001L15.3792 10.0601Z" fill="#fff" fill-rule="evenodd"></path>
# <path d="M20.6592 15.3001L21.3649 16.0085L22.0774 15.2987L21.3636 14.5903L20.6592 15.3001ZM15.3792 10.0601L16.0836 9.35027L15.3765 8.64853L14.6721 9.35295L15.3792 10.0601ZM15.3792 20.5601L14.6721 21.2672L15.3778 21.9729L16.0849 21.2685L15.3792 20.5601ZM14.7392 19.9201L14.0321 19.213L13.325 19.9201L14.0321 20.6272L14.7392 19.9201ZM18.8792 15.7801L19.5863 16.4872L21.2934 14.7801H18.8792V15.7801ZM9.65918 15.7801H8.65918V16.7801H9.65918V15.7801ZM9.65918 14.8401V13.8401H8.65918V14.8401H9.65918ZM18.8792 14.8401V15.8401H21.2934L19.5863 14.133L18.8792 14.8401ZM14.7392 10.7001L14.0321 9.99295L13.325 10.7001L14.0321 11.4072L14.7392 10.7001ZM1 15C1 7.26801 7.26801 1 15 1V-1C6.16344 -1 -1 6.16344 -1 15H1ZM15 29C7.26801 29 1 22.732 1 15H-1C-1 23.8366 6.16344 31 15 31V29ZM29 15C29 22.732 22.732 29 15 29V31C23.8366 31 31 23.8366 31 15H29ZM15 1C22.732 1 29 7.26801 29 15H31C31 6.16344 23.8366 -1 15 -1V1ZM21.3636 14.5903L16.0836 9.35027L14.6748 10.7698L19.9548 16.0098L21.3636 14.5903ZM16.0849 21.2685L21.3649 16.0085L19.9534 14.5916L14.6734 19.8516L16.0849 21.2685ZM14.0321 20.6272L14.6721 21.2672L16.0863 19.853L15.4463 19.213L14.0321 20.6272ZM18.1721 15.073L14.0321 19.213L15.4463 20.6272L19.5863 16.4872L18.1721 15.073ZM9.65918 16.7801H18.8792V14.7801H9.65918V16.7801ZM8.65918 14.8401V15.7801H10.6592V14.8401H8.65918ZM18.8792 13.8401H9.65918V15.8401H18.8792V13.8401ZM14.0321 11.4072L18.1721 15.5472L19.5863 14.133L15.4463 9.99295L14.0321 11.4072ZM14.6721 9.35295L14.0321 9.99295L15.4463 11.4072L16.0863 10.7672L14.6721 9.35295Z" fill="#fff" mask="url(#path-1-inside-1_2694_77554)"></path>
# </svg>
# <svg fill="none" id="n1_play" style="display:block;width:0;height:0;" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# <path class="stroke-current" d="M18 35V15L36 25L18 35Z"></path>
# </svg>
# <svg fill="none" id="n1_pupa" style="display:block;width:0;height:0;" viewbox="0 0 24 23" xmlns="http://www.w3.org/2000/svg">
# <path clip-rule="evenodd" d="M17 8.80329C17 13.0922 13.4392 16.6066 9 16.6066C4.56077 16.6066 1 13.0922 1 8.80329C1 4.51437 4.56077 1 9 1C13.4392 1 17 4.51437 17 8.80329ZM14.9967 15.3678C13.4049 16.7601 11.3035 17.6066 9 17.6066C4.02944 17.6066 0 13.6652 0 8.80329C0 3.94137 4.02944 0 9 0C13.9706 0 18 3.94137 18 8.80329C18 11.0562 17.1348 13.1114 15.7118 14.6684L23.3531 22.1427C23.5505 22.3358 23.554 22.6524 23.3609 22.8498C23.1678 23.0472 22.8513 23.0507 22.6539 22.8576L14.9967 15.3678Z" fill="#32363A" fill-rule="evenodd"></path>
# </svg>
# <svg fill="none" id="n1_burger" style="display:block;width:0;height:0;" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
# <line stroke="#32363A" x2="30" y1="6.5" y2="6.5"></line>
# <line stroke="#32363A" x2="30" y1="23.5" y2="23.5"></line>
# <line stroke="#32363A" x2="30" y1="15" y2="15"></line>
# </svg>
# <svg fill="none" id="n1_cross_menu" style="display:block;width:0;height:0;" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
# <path d="M4 4L26 26" stroke="#32363A"></path>
# <path d="M26 4L4 26" stroke="#32363A"></path>
# </svg>
# <svg id="n1_check" style="display:block;width:0;height:0;fill:currentColor" version="1.1" viewbox="0 0 752 752" xmlns="http://www.w3.org/2000/svg">
# <path d="m183.6 357.87-22.184 22.168v0.003907c-3.2969 3.293-3.2969 8.6367 0 11.934l133.29 133.28v0.003907c3.7305 3.7266 8.7891 5.8242 14.066 5.8242 5.2734 0 10.332-2.0977 14.062-5.8242l267.76-267.76c1.582-1.582 2.4727-3.7305 2.4727-5.9688 0-2.2383-0.89062-4.3867-2.4727-5.9688l-22.156-22.168c-1.582-1.5898-3.7344-2.4805-5.9727-2.4805-2.2422 0-4.3945 0.89062-5.9766 2.4805l-244.31 244.3c-1.8828 1.8789-4.9336 1.8789-6.8164 0l-109.84-109.83c-3.293-3.2852-8.625-3.2852-11.918 0z"></path>
# </svg>
# <svg id="n1_specials_star" style="display:block;width:0;height:0;fill:none;stroke:white" version="1.1" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg">
# <path d="M7.99982 2.18188L9.79764 5.77236L13.818 6.35166L10.9089 9.14489L11.5955 13.091L7.99982 11.2269L4.40419 13.091L5.09073 9.14489L2.18164 6.35166L6.202 5.77236L7.99982 2.18188Z" stroke-linecap="round"></path>
# </svg>
# <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js"></script><script src="/front-build/js/app.js?id=8f64b9230b5c5522518a6ccb46220bfe"></script>
# <!-- Yandex.Metrika counter 2-->
# <script type="text/javascript">
# (function(m,e,t,r,i,k,a){m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
# 	m[i].l=1*new Date();k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)})
# (window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#
# ym(88946384, "init", {
# 	clickmap:true,
# 	trackLinks:true,
# 	accurateTrackBounce:true,
# 	webvisor:true
# });
#
#
# ym(29654565, "init", {
# 	clickmap:true,
# 	trackLinks:true,
# 	accurateTrackBounce:true,
# 	webvisor:true,
# 	trackHash:true,
# 	ecommerce:"dataLayer"
# });
# </script>
# <noscript>
# <div>
# <img alt="" src="https://mc.yandex.ru/watch/88946384" style="position:absolute; left:-9999px;"/>
# <img alt="" src="https://mc.yandex.ru/watch/29654565" style="position:absolute; left:-9999px;"/>
# </div>
# </noscript>
# <!-- /Yandex.Metrika counter -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-61773772-1"></script>
# <script>
# window.dataLayer = window.dataLayer || [];
# function gtag(){dataLayer.push(arguments);}
# gtag('js', new Date());
# gtag('config', 'UA-61773772-1');
# </script>
# <script>window.yaContextCb = window.yaContextCb || []</script>
# <script async="" src="https://yandex.ru/ads/system/context.js"></script>
# <script>
# if ('serviceWorker' in navigator) {
# 	window.addEventListener('load', () => {
# 		navigator.serviceWorker.register('/front-service-worker.js').then(reg => {
# 			// sometime later…
# 			reg.update()
# 		})
# 	})
# }
# </script>
# </body>
# </html>

# %% [markdown]
# Для просмотра выглядит не очень удобно.  «Причешем» наш `soup` – воспользуемся методом `.prettify()` в сочетании с функцией `print()`.

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="ru" prefix="og: http://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    N + 1 — главное издание о науке, технике и технологиях
#   </title>
#   <link as="font" crossorigin="" href="https://staticn1.nplus1.ru/fonts/AeonikPro/AeonikPro-Regular.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="" href="https://staticn1.nplus1.ru/fonts/Spectral/Spectral-Regular.woff" rel="preload" type="font/woff2"/>
#   <link href="/front-build/css/main.css?id=9b496fbb252428c03791da99722528ab" rel="stylesheet"/>
#   <link href="/front-build/css/app.css?id=f9c00b5102d287d01698f43324336ca6" rel="stylesheet"/>
#   <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/site.webmanifest" rel="manifest"/>
#   <link color="#f26e40" href="/safari-pinned-tab.svg" rel="mask-icon"/>
#   <meta content="#f26e40" name="msapplication-TileColor"/>
#   <meta content="#ffffff" name="theme-color"/>
#   <link href="https://nplus1.ru" rel="canonical"/>
#   <meta content="8c90b02c84ac3b72" name="yandex-verification"/>
#   <meta content="b419949322895fc9106e24ed01be58ac" name="pmail-verification"/>
#   <!-- Google Tag Manager -->
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#
#     })(window,document,'script','dataLayer','GTM-PJWMQBQ');
#   </script>
#   <!-- End Google Tag Manager -->
#   <meta content="N + 1 - это научно-популярное издание, которое познакомит вас с природными явлениями, открытиями и технологиями, расскажет
#  просто о сложном и поможет узнать что-то новое для себя" name="description"/>
#   <meta content="N + 1 — главное издание о науке, технике и технологиях" property="og:site_name"/>
#   <meta content="N + 1 — главное издание о науке, технике и технологиях" property="og:title"/>
#   <meta content="https://nplus1.ru/images-new/share_snippet.png" property="og:image"/>
#   <meta content="https://nplus1.ru" property="og:url"/>
#   <meta content="N + 1 — главное издание о науке, технике и технологиях" property="og:description"/>
#   <meta content="" property="og:type"/>
#   <script type="application/ld+json">
#    {
# 	"@context": "http://schema.org",
# 	"@type": "WebSite",
# 	"url": "https://nplus1.ru/",
# 	"name": "N + 1 — главное издание о науке, технике и технологиях",
# 	"description": "N + 1 — главное издание о науке, технике и технологиях",
# 	"image": "https://staticn1.nplus1.ru/image-new/share_snippet.png",
# 	"publisher": {
# 	"@type": "Organization",
# 		"name": "N+1",
# 		"logo": {
# 			"@type":"ImageObject",
# 			"url": "https://staticn1.nplus1.ru/image-new/logo-alt.png"
# 		},
# 		"sameAs": [
# 			"https://www.facebook.com/nplusone",
# 			"https://twitter.com/nplusodin",
# 			"https://vk.com/nplusone",
# 			"https://ok.ru/nplus1",
# 			"https://soundcloud.com/nplus_1",
# 			"https://t.me/nplusone"
# 		]
# 	},
# 	"potentialAction":{
# 		"@type":"SearchAction",
# 		"target":"https://nplus1.ru/search/{search_term_string}",
# 		"query-input":"required name=search_term_string"
# 	}
# }
#   </script>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="@nplusodin" name="twitter:site"/>
#   <meta content="N + 1 — главное издание о науке, технике и технологиях" name="twitter:title"/>
#   <meta content="N + 1 — главное издание о науке, технике и технологиях" name="twitter:description"/>
#   <meta content="https://nplus1.ru/images-new/share_snippet.png" name="twitter:image"/>
#   <link href="https://nplus1.ru/rss" rel="alternate" title="RSS" type="application/rss+xml"/>
#  </head>
#  <body class="antialiased">
#   <!-- Top.Mail.Ru counter -->
#   <script type="text/javascript">
#    var tmr = window.tmr || (window._tmr = []);
#
# _tmr.push({id: "3377932", type: "pageView", start: (new Date()).getTime()});
#
# (function (d, w, id) {
#
#   if (d.getElementById(id)) return;
#
#   var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
#
#   ts.src = "https://top-fwz1.mail.ru/js/code.js";
#
#   var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
#
#   if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
#
# })(document, window, "tmr-code");
#   </script>
#   <noscript>
#    <div>
#     <img alt="Top.Mail.Ru" src="https://top-fwz1.mail.ru/counter?id=3377932;js=na" style="position:absolute;left:-9999px;"/>
#    </div>
#   </noscript>
#   <!-- /Top.Mail.Ru counter -->
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PJWMQBQ" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <div class="font-aeonik text-main-black flex flex-col min-h-screen pt-15 bg-light-gray" id="appfront">
#    <header class="bg-light-gray fixed h-15 left-0 top-0 w-full z-50" data-ref-header="" ref="headerRef">
#     <div class="border-b border-main-gray h-full">
#      <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto flex justify-between items-center h-full" data-ref-header-container="" ref="headerContainerRef">
#       <button aria-label="Go" class="w-7.5 h-7.5" data-ref-header-menu-btn="" id="topMenuBtn" ref="headerMenuBtnRef">
#        <template v-if="isOpenDesktopMenu || isOpenMobileMenu">
#         <svg class="w-full h-full">
#          <use xlink:href="#n1_cross_menu">
#          </use>
#         </svg>
#        </template>
#        <template v-else="">
#         <svg class="w-full h-full">
#          <use xlink:href="#n1_burger">
#          </use>
#         </svg>
#        </template>
#       </button>
#       <div>
#        <img alt="as" height="23" loading="lazy" src="https://staticn1.nplus1.ru/image-new/logo.svg" width="57"/>
#       </div>
#       <a class="w-7.5 h-7.5" href="/search">
#        <svg class="w-full h-full">
#         <use xlink:href="#n1_pupa">
#         </use>
#        </svg>
#       </a>
#      </div>
#     </div>
#     <nav :style="stylesNavDesktop" class="relative bg-light-gray max-h-0 n1_top_nav overflow-hidden" id="navMenu" v-if="isOpenDesktopMenu">
#      <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto h-full flex flex-col overflow-y-auto">
#       <div class="py-12 mb-12 border-b border-gray-2 text-18 grid grid-cols-flow lg:grid-cols-12 gap-x-5 md:gap-x-9">
#        <!--
#         <a @click.native="menuClose"
#            class="col-span-3 flex gap-x-2 lg:gap-x-5 items-center hover:text-main transition-colors duration-75"
#            href="/lk">
#           <svg class="h-10 lg:h-12 w-10 lg:w-12 shrink-0">
#             <use xlink:href="#n1_person"></use>
#           </svg>
#           <span>Личный кабинет</span>
#         </a>
#         -->
#        <a class="col-span-3 lg:col-span-2 col-start-7 lg:col-start-9 flex items-center hover:text-main transition-colors duration-75" href="https://offline.nplus1.ru/">
#         N + offline
#        </a>
#        <a class="col-span-3 lg:col-span-2 col-start-10 lg:col-start-11 flex items-center hover:text-main transition-colors duration-75" href="https://nplus.pro/">
#         N + production
#        </a>
#       </div>
#       <div class="grid grid-cols-12 gap-x-5 gap-y-5 md:gap-y-9 pb-6">
#        <div class="col-span-6 md:col-span-3 text-20 lg:text-26 xl:text-34 font-spectral flex flex-col gap-y-3">
#         <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/about">
#          О нас
#         </a>
#         <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/difficult" target="_blank">
#          Сложность
#         </a>
#         <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/adv" target="_blank">
#          Рекламодателям
#         </a>
#         <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/blog/2022/04/01/samotek" target="_blank">
#          Авторам
#         </a>
#        </div>
#        <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=946">
#          Игры
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=869">
#          Физика
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=874">
#          Зоология
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=880">
#          Астрономия
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=768">
#          Генетика
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=890">
#          Математика
#         </a>
#        </div>
#        <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=871">
#          Космонавтика
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=876">
#          Археология
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=775">
#          Нейронауки
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=767">
#          На мышах
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=771">
#          Звук
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=772">
#          Красота
#         </a>
#        </div>
#        <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=778">
#          Научные закрытия
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=917">
#          ИИ спешит на помощь
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=918">
#          Когда рассеется дым
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=824">
#          Книжная полка
#         </a>
#        </div>
#       </div>
#       <div class="py-12 mt-auto border-t border-gray-2 text-18 grid grid-cols-12 gap-x-5 md:gap-x-9">
#        <ul class="flex gap-2.5">
#         <li>
#          <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
#           <svg class="w-12 h-12">
#            <use xlink:href="#n1_tg">
#            </use>
#           </svg>
#          </a>
#         </li>
#         <li>
#          <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
#           <svg class="w-12 h-12">
#            <use xlink:href="#n1_vk">
#            </use>
#           </svg>
#          </a>
#         </li>
#         <li>
#          <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
#           <svg class="w-12 h-12">
#            <use xlink:href="#n1_ok">
#            </use>
#           </svg>
#          </a>
#         </li>
#         <li class="w-12">
#          <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
#           <svg class="w-12 h-12">
#            <use xlink:href="#n1_tw">
#            </use>
#           </svg>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </nav>
#     <nav :style="stylesNavMobile" class="relative bg-white max-h-0 n1_top_nav overflow-hidden" id="mobNavMenu" v-if="isOpenMobileMenu">
#      <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto h-full flex flex-col overflow-y-auto">
#       <div class="text-30 font-spectral flex flex-col gap-y-5 mb-10 mt-10">
#        <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/about">
#         О нас
#        </a>
#        <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/difficult" target="_blank">
#         Сложность
#        </a>
#        <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/adv" target="_blank">
#         Рекламодателям
#        </a>
#        <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/news/2015/09/21/editor-thy-name" target="_blank">
#         Вакансии
#        </a>
#       </div>
#       <div class="text-28 text-main flex flex-col gap-y-2.5 mb-10">
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=946">
#         Игры
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=869">
#         Физика
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=874">
#         Зоология
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=880">
#         Астрономия
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=768">
#         Генетика
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=890">
#         Математика
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=871">
#         Космонавтика
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=876">
#         Археология
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=775">
#         Нейронауки
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=767">
#         На мышах
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=771">
#         Звук
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=772">
#         Красота
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=778">
#         Научные закрытия
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=917">
#         ИИ спешит на помощь
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=918">
#         Когда рассеется дым
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=824">
#         Книжная полка
#        </a>
#       </div>
#       <div class="max-w-full flex py-5 border-t border-gray-2">
#        <div class="flex gap-x-5 overflow-x-auto">
#         <a class="hover:text-main whitespace-nowrap" href="https://offline.nplus1.ru/">
#          N + offline
#         </a>
#         <a class="hover:text-main whitespace-nowrap" href="https://nplus.pro/">
#          N + production
#         </a>
#        </div>
#       </div>
#       <div class="pt-5 pb-10 border-t border-gray-2 text-18">
#        <ul class="flex gap-2.5">
#         <li>
#          <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
#           <svg class="w-10 h-10">
#            <use xlink:href="#n1_tg">
#            </use>
#           </svg>
#          </a>
#         </li>
#         <li>
#          <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
#           <svg class="w-10 h-10">
#            <use xlink:href="#n1_vk">
#            </use>
#           </svg>
#          </a>
#         </li>
#         <li>
#          <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
#           <svg class="w-10 h-10">
#            <use xlink:href="#n1_ok">
#            </use>
#           </svg>
#          </a>
#         </li>
#         <li class="w-12">
#          <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
#           <svg class="w-10 h-10">
#            <use xlink:href="#n1_tw">
#            </use>
#           </svg>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </nav>
#    </header>
#    <section class="mb-10">
#     <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto mx-auto">
#      <div class="grid grid-cols-2 col-span-2 gap-0.5 n1_m_full n1_fs_main">
#       <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#        <div class="absolute z-10 top-5 inset-x-4 md:inset-x-5">
#         <div class="flex flex-wrap gap-2 text-tags">
#          <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=903">
#           Наука
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/2">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">
#            2.2
#           </span>
#          </a>
#         </div>
#        </div>
#        <a class="" href="https://nplus1.ru/material/2023/12/14/nature-top-10-2023">
#         <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#          <div class="hidden sm:block max-height-[333px]">
#           <div class="-inset-0.5 absolute group">
#            <picture>
#             <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/867516/014928d934004b2f63bfc59772b5ccaf.png">
#              <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/867517/aeeafd2b48b0e0443c09edbcf956a69a.png">
#               <img alt="ChatGPT, лунная миссия и мышата от двух отцов" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#              </source>
#             </source>
#            </picture>
#           </div>
#          </div>
#          <div class="block sm:hidden">
#           <div class="-inset-0.5 absolute max-height-[333px]">
#            <picture>
#             <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/867516/014928d934004b2f63bfc59772b5ccaf.png">
#              <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/867517/aeeafd2b48b0e0443c09edbcf956a69a.png">
#               <img alt="ChatGPT, лунная миссия и мышата от двух отцов" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#              </source>
#             </source>
#            </picture>
#           </div>
#          </div>
#          <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
#           <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">
#            ChatGPT, лунная миссия и мышата от двух отцов
#           </h3>
#           <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#            Редакция Nature назвала героев уходящего года
#           </div>
#          </div>
#         </div>
#        </a>
#       </div>
#       <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#        <div class="absolute z-10 top-5 inset-x-4 md:inset-x-5">
#         <div class="flex flex-wrap gap-2 text-tags">
#          <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=908">
#           Подкасты
#          </a>
#          <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=873">
#           Медицина
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/3">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">
#            3.9
#           </span>
#          </a>
#         </div>
#        </div>
#        <a class="" href="https://nplus1.ru/blog/2023/12/14/circle-gets-the-square">
#         <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#          <div class="hidden sm:block max-height-[333px]">
#           <div class="-inset-0.5 absolute group">
#            <picture>
#             <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/868087/21e63eb31348fe20076f5635f309d519.gif">
#              <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/868088/a741e7e915a37b160a9238e57d19cbe3.gif">
#               <img alt="Голова кругом" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#              </source>
#             </source>
#            </picture>
#            <picture>
#             <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/868086/05c2ddea46b61fec25b430faf49ea499.gif">
#              <img alt="Голова кругом" class="w-full h-full object-cover absolute inset-0 opacity-0 group-hover:opacity-100 transition-opacity duration-500" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#             </source>
#            </picture>
#           </div>
#          </div>
#          <div class="block sm:hidden">
#           <div class="-inset-0.5 absolute max-height-[333px]">
#            <picture>
#             <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/868087/21e63eb31348fe20076f5635f309d519.gif">
#              <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/868088/a741e7e915a37b160a9238e57d19cbe3.gif">
#               <img alt="Голова кругом" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#              </source>
#             </source>
#            </picture>
#           </div>
#          </div>
#          <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
#           <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">
#            Голова кругом
#           </h3>
#           <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#            Есть ли у сосудов мозга углы
#           </div>
#          </div>
#         </div>
#        </a>
#       </div>
#       <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#        <div class="absolute z-10 top-5 inset-x-4 md:inset-x-5">
#         <div class="flex flex-wrap gap-2 text-tags">
#          <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=812">
#           Партнерский материал
#          </a>
#          <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=872">
#           Экология и климат
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/1">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">
#            1.1
#           </span>
#          </a>
#         </div>
#        </div>
#        <a class="" href="https://nplus1.ru/material/2023/12/14/green-uni-initiatives">
#         <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#          <div class="hidden sm:block max-height-[333px]">
#           <div class="-inset-0.5 absolute group">
#            <picture>
#             <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/867448/d70a69ba48c9ab8b204da20326370eff.gif">
#              <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/867449/29ac7b1c83fe2a972e776960e3bd84e1.gif">
#               <img alt="Не парами едиными" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#              </source>
#             </source>
#            </picture>
#            <picture>
#             <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/867447/0edff5ba8e5f864f03f8b4abf994dd31.gif">
#              <img alt="Не парами едиными" class="w-full h-full object-cover absolute inset-0 opacity-0 group-hover:opacity-100 transition-opacity duration-500" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#             </source>
#            </picture>
#           </div>
#          </div>
#          <div class="block sm:hidden">
#           <div class="-inset-0.5 absolute max-height-[333px]">
#            <picture>
#             <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/867448/d70a69ba48c9ab8b204da20326370eff.gif">
#              <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/867449/29ac7b1c83fe2a972e776960e3bd84e1.gif">
#               <img alt="Не парами едиными" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#              </source>
#             </source>
#            </picture>
#           </div>
#          </div>
#          <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
#           <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">
#            Не парами едиными
#           </h3>
#           <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#            Как университеты становятся центрами зеленой экономики и экологического просвещения
#           </div>
#          </div>
#         </div>
#        </a>
#       </div>
#       <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#        <div class="absolute z-10 top-5 inset-x-4 md:inset-x-5">
#         <div class="flex flex-wrap gap-2 text-tags">
#          <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=876">
#           Археология
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/3">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">
#            3.2
#           </span>
#          </a>
#         </div>
#        </div>
#        <a class="" href="https://nplus1.ru/news/2023/12/15/human-skin">
#         <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#          <div class="hidden sm:block max-height-[333px]">
#           <div class="-inset-0.5 absolute group">
#            <picture>
#             <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/868710/8ca3b9fb4be51fa8cbd4b1d0d2bdf991.jpg">
#              <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/868711/8930a9285a9a3de1829e48335f4c3566.jpg">
#               <img alt="У скифов нашли изделия из человеческой кожи" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#              </source>
#             </source>
#            </picture>
#           </div>
#          </div>
#          <div class="block sm:hidden">
#           <div class="-inset-0.5 absolute max-height-[333px]">
#            <picture>
#             <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/868710/8ca3b9fb4be51fa8cbd4b1d0d2bdf991.jpg">
#              <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/868711/8930a9285a9a3de1829e48335f4c3566.jpg">
#               <img alt="У скифов нашли изделия из человеческой кожи" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#              </source>
#             </source>
#            </picture>
#           </div>
#          </div>
#          <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
#           <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">
#            У скифов нашли изделия из человеческой кожи
#           </h3>
#           <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#            По данным Геродота, они снимали ее с мертвых врагов
#           </div>
#          </div>
#         </div>
#        </a>
#       </div>
#      </div>
#     </div>
#    </section>
#    <section class="mb-0 sm:mb-5">
#     <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto grid grid-cols-6 sm:grid-cols-12 gap-x-5 md:gap-x-9 relative">
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <div class="inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full">
#           <span class="overflow-hidden text-ellipsis whitespace-nowrap">
#            10:28
#           </span>
#          </div>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/12/18">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            18.12.23
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=876">
#           <p class="truncate">
#            Археология
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            2.5
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/12/18/parasite-eggs-from-granada">
#          <div>
#           В старинных выгребных ямах Гранады нашли яйца кишечных паразитов
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <div class="inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full">
#           <span class="overflow-hidden text-ellipsis whitespace-nowrap">
#            10:05
#           </span>
#          </div>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/12/18">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            18.12.23
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=877">
#           <p class="truncate">
#            Антропология
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            1.2
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/12/18/medieval-deformed-skull">
#          <div>
#           Женщина с искусственно деформированным черепом обрела лицо
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <div class="inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full">
#           <span class="overflow-hidden text-ellipsis whitespace-nowrap">
#            09:34
#           </span>
#          </div>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/12/18">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            18.12.23
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=877">
#           <p class="truncate">
#            Антропология
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/3">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            3.1
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/12/18/qafzeh-25">
#          <div>
#           Архаичного сапиенса из пещеры Кафзех ранили в челюсть
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/12/16">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            16.12.23
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=880">
#           <p class="truncate">
#            Астрономия
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/4">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            4.1
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/12/16/jwst-bd-light">
#          <div>
#           «Джеймс Уэбб» напрямую рассмотрел кандидата в рекордно легкий одиночный коричневый карлик
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/12/16">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            16.12.23
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=883">
#           <p class="truncate">
#            Роботы и дроны
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            1.7
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/12/16/hound-record-100m">
#          <div>
#           Корейская робособака установила рекорд среди четвероногих роботов в забеге на 100 метров
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/12/16">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            16.12.23
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=903">
#           <p class="truncate">
#            Наука
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            1.9
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/12/16/retracted-2023">
#          <div>
#           Больше десяти тысяч научных статей отозвали в 2023 году
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/12/16">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            16.12.23
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=882">
#           <p class="truncate">
#            Психология
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/3">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            3.9
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/12/16/turn-off">
#          <div>
#           Изменение сознания при медитации зафиксировали на энцефалограмме
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/12/16">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            16.12.23
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=882">
#           <p class="truncate">
#            Психология
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            1.8
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/12/16/label-smart">
#          <div>
#           Метки «веганский» и «растительный» не привлекли людей к продуктам без мяса
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/12/16">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            16.12.23
#           </span>
#          </a>
# ...
#           </svg>
#          </a>
#         </li>
#         <li class="w-12">
#          <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
#           <svg class="w-12 h-12">
#            <use xlink:href="#n1_tw">
#            </use>
#           </svg>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#    </footer>
#   </div>
#   <svg class="stroke-current" fill="none" height="16" id="n1_star" style="display:block;width:0;height:0" viewbox="3 3 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#    <path d="M11 5V17">
#    </path>
#    <path d="M6.75781 6.75781L15.2431 15.2431">
#    </path>
#    <path d="M17 11L5 11">
#    </path>
#    <path d="M15.2422 6.75781L6.75691 15.2431">
#    </path>
#   </svg>
#   <svg class="stroke-current" fill="none" id="n1_person" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
#    <circle cx="25" cy="25" r="24.5">
#    </circle>
#    <path d="M30.1897 30.3212C28.9483 29.9852 27.5345 29.7164 27.5345 28.5067C27.5345 27.8347 27.5 27.0618 28.2931 26.625C31.0172 25.0457 32.5 22.3911 32.1552 18.2581C31.8103 14.0578 29.2586 11 24.9828 11C20.7069 11 18.1552 14.0578 17.8103 18.2581C17.4655 22.3911 18.9138 25.0457 21.6724 26.625C22.4655 27.0618 22.431 27.8347 22.431 28.5067C22.431 29.7164 21.0172 29.9516 19.8103 30.3212C17.3966 30.9933 12.5 31.9005 12.5 36C16.431 36 33.569 36 37.5 36C37.4655 31.9005 32.6034 30.9933 30.1897 30.3212Z" stroke-miterlimit="10">
#    </path>
#   </svg>
#   <svg fill="none" id="n1_tg" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
#    <path class="fill-current" d="M16.3181 21.32H19.4961V30H20.7141V21.32H23.8921V20.2H16.3181V21.32ZM28.6969 30.084C30.3769 30.084 31.4269 29.286 31.8749 28.572L31.9589 30H33.0089V24.694H28.8789V25.814H31.8189V26.15C31.8189 27.886 30.5169 28.964 28.7109 28.964C26.6809 28.964 25.3369 27.368 25.3369 25.1C25.3369 22.832 26.6809 21.236 28.7389 21.236C30.2229 21.236 31.2729 22.034 31.6089 23.392H32.9109C32.5749 21.376 30.9369 20.116 28.7669 20.116C25.9249 20.116 24.0909 22.132 24.0909 25.1C24.0909 28.068 25.9809 30.084 28.6969 30.084Z">
#    </path>
#    <circle class="stroke-current" cx="25" cy="25" r="24.5">
#    </circle>
#   </svg>
#   <svg fill="none" id="n1_vk" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
#    <path class="fill-current" d="M19.8015 30H21.2715L24.7995 20.2H23.5395L20.5575 28.558L17.5615 20.2H16.2735L19.8015 30ZM25.8768 30H27.0948V27.452L29.0408 25.254L32.3448 30H33.8008L29.9368 24.33L33.5208 20.2H32.0368L27.0948 25.758V20.2H25.8768V30Z">
#    </path>
#    <circle class="stroke-current" cx="25" cy="25" r="24.5">
#    </circle>
#   </svg>
#   <svg fill="none" id="n1_ok" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
#    <path class="fill-current" d="M25.2125 25.1C25.2125 22.216 23.2945 20.116 20.5365 20.116C17.7785 20.116 15.8605 22.216 15.8605 25.1C15.8605 27.984 17.7785 30.084 20.5365 30.084C23.2945 30.084 25.2125 27.984 25.2125 25.1ZM17.1065 25.1C17.1065 22.846 18.4925 21.236 20.5365 21.236C22.5805 21.236 23.9665 22.846 23.9665 25.1C23.9665 27.354 22.5805 28.964 20.5365 28.964C18.4925 28.964 17.1065 27.354 17.1065 25.1ZM26.7518 30H27.9698V27.452L29.9158 25.254L33.2198 30H34.6758L30.8118 24.33L34.3958 20.2H32.9118L27.9698 25.758V20.2H26.7518V30Z">
#    </path>
#    <circle class="stroke-current" cx="25" cy="25" r="24.5">
#    </circle>
#   </svg>
#   <svg fill="none" id="n1_tw" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
#    <path class="fill-current" d="M14.4792 21.32H17.6572V30H18.8752V21.32H22.0532V20.2H14.4792V21.32ZM25.332 30H26.788L29.014 22.23L31.254 30H32.71L35.58 20.2H34.32L32.01 28.432L29.686 20.2H28.454L26.046 28.432L23.75 20.2H22.476L25.332 30Z">
#    </path>
#    <circle class="stroke-current" cx="25" cy="25" r="24.5">
#    </circle>
#   </svg>
#   <svg height="64px" id="n1_infinity" preserveaspectratio="xMidYMid" style="display:block;width:0;height:0" viewbox="0 0 100 100" width="64px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#    <path d="M24.3 30C11.4 30 5 43.3 5 50s6.4 20 19.3 20c19.3 0 32.1-40 51.4-40 C88.6 30 95 43.3 95 50s-6.4 20-19.3 20C56.4 70 43.6 30 24.3 30z" fill="none" stroke="#ffffff" stroke-dasharray="146.25568908691406 110.33323913574219" stroke-linecap="round" stroke-width="5" style="transform:scale(0.8);transform-origin:50px 50px">
#     <animate attributename="stroke-dashoffset" dur="1.3157894736842106s" keytimes="0;1" repeatcount="indefinite" values="0;256.58892822265625">
#     </animate>
#    </path>
#   </svg>
#   <svg fill="none" id="n1_cross" style="display:block;width:0;height:0" viewbox="0 0 14 14" xmlns="http://www.w3.org/2000/svg">
#    <path d="M1.00146 1L13.0015 13" stroke="#F9F9F9">
#    </path>
#    <path d="M13 1L1 13" stroke="#F9F9F9">
#    </path>
#   </svg>
#   <svg id="n1_link_arrow" style="display:block;width:0;height:0" viewbox="0 0 11 11" xmlns="http://www.w3.org/2000/svg">
#    <path d="M10.0738 5.87L5.08775 0.901999L4.15175 1.838L7.51775 5.204H0.19175V6.536H7.51775L4.15175 9.902L5.08775 10.838L10.0738 5.87Z" fill="currentColor">
#    </path>
#   </svg>
#   <svg id="n1_big_star" style="display:block;width:0;height:0;" viewbox="0 0 61 61" xmlns="http://www.w3.org/2000/svg">
#    <path class="fill-current" clip-rule="evenodd" d="M3 29.7729H29.0656L10.6345 11.3418L11.3416 10.6347L29.7728 29.0658V3H30.7728V29.0658L49.2039 10.6347L49.911 11.3418L31.4799 29.7729H57.5455V30.7729H31.4799L49.9111 49.2042L49.204 49.9113L30.7728 31.4801V57.5455H29.7728V31.4801L11.3415 49.9113L10.6344 49.2042L29.0656 30.7729H3V29.7729Z" fill-rule="evenodd">
#    </path>
#    <path class="fill-current" d="M29.0656 29.7729V32.2729H35.1012L30.8334 28.0052L29.0656 29.7729ZM3 29.7729V27.2729H0.5V29.7729H3ZM10.6345 11.3418L8.86676 9.57407L7.099 11.3418L8.86676 13.1096L10.6345 11.3418ZM11.3416 10.6347L13.1094 8.86696L11.3416 7.09919L9.57387 8.86696L11.3416 10.6347ZM29.7728 29.0658L28.005 30.8336L32.2728 35.1014V29.0658H29.7728ZM29.7728 3V0.5H27.2728V3H29.7728ZM30.7728 3H33.2728V0.5H30.7728V3ZM30.7728 29.0658H28.2728V35.1014L32.5405 30.8336L30.7728 29.0658ZM49.2039 10.6347L50.9716 8.86696L49.2039 7.09919L47.4361 8.86696L49.2039 10.6347ZM49.911 11.3418L51.6787 13.1096L53.4465 11.3418L51.6787 9.57407L49.911 11.3418ZM31.4799 29.7729L29.7121 28.0052L25.4443 32.2729H31.4799V29.7729ZM57.5455 29.7729H60.0455V27.2729H57.5455V29.7729ZM57.5455 30.7729V33.2729H60.0455V30.7729H57.5455ZM31.4799 30.7729V28.2729H25.4443L29.7121 32.5407L31.4799 30.7729ZM49.9111 49.2042L51.6789 50.972L53.4466 49.2042L51.6789 47.4364L49.9111 49.2042ZM49.204 49.9113L47.4362 51.6791L49.204 53.4468L50.9718 51.6791L49.204 49.9113ZM30.7728 31.4801L32.5405 29.7123L28.2728 25.4445V31.4801H30.7728ZM30.7728 57.5455V60.0455H33.2728V57.5455H30.7728ZM29.7728 57.5455H27.2728V60.0455H29.7728V57.5455ZM29.7728 31.4801H32.2728V25.4445L28.005 29.7123L29.7728 31.4801ZM11.3415 49.9113L9.57374 51.6791L11.3415 53.4468L13.1093 51.6791L11.3415 49.9113ZM10.6344 49.2042L8.86664 47.4364L7.09887 49.2042L8.86664 50.972L10.6344 49.2042ZM29.0656 30.7729L30.8334 32.5407L35.1012 28.2729H29.0656V30.7729ZM3 30.7729H0.5V33.2729H3V30.7729ZM29.0656 27.2729H3V32.2729H29.0656V27.2729ZM8.86676 13.1096L27.2979 31.5407L30.8334 28.0052L12.4023 9.57407L8.86676 13.1096ZM9.57387 8.86696L8.86676 9.57407L12.4023 13.1096L13.1094 12.4025L9.57387 8.86696ZM31.5405 27.2981L13.1094 8.86696L9.57387 12.4025L28.005 30.8336L31.5405 27.2981ZM27.2728 3V29.0658H32.2728V3H27.2728ZM30.7728 0.5H29.7728V5.5H30.7728V0.5ZM33.2728 29.0658V3H28.2728V29.0658H33.2728ZM32.5405 30.8336L50.9716 12.4025L47.4361 8.86696L29.005 27.2981L32.5405 30.8336ZM47.4361 12.4025L48.1432 13.1096L51.6787 9.57407L50.9716 8.86696L47.4361 12.4025ZM48.1432 9.57407L29.7121 28.0052L33.2476 31.5407L51.6787 13.1096L48.1432 9.57407ZM57.5455 27.2729H31.4799V32.2729H57.5455V27.2729ZM60.0455 30.7729V29.7729H55.0455V30.7729H60.0455ZM31.4799 33.2729H57.5455V28.2729H31.4799V33.2729ZM51.6789 47.4364L33.2476 29.0052L29.7121 32.5407L48.1433 50.972L51.6789 47.4364ZM50.9718 51.6791L51.6789 50.972L48.1433 47.4364L47.4362 48.1435L50.9718 51.6791ZM29.005 33.2478L47.4362 51.6791L50.9718 48.1435L32.5405 29.7123L29.005 33.2478ZM33.2728 57.5455V31.4801H28.2728V57.5455H33.2728ZM29.7728 60.0455H30.7728V55.0455H29.7728V60.0455ZM27.2728 31.4801V57.5455H32.2728V31.4801H27.2728ZM28.005 29.7123L9.57374 48.1435L13.1093 51.6791L31.5405 33.2478L28.005 29.7123ZM13.1093 48.1435L12.4022 47.4364L8.86664 50.972L9.57374 51.6791L13.1093 48.1435ZM12.4022 50.972L30.8334 32.5407L27.2979 29.0052L8.86664 47.4364L12.4022 50.972ZM3 33.2729H29.0656V28.2729H3V33.2729ZM0.5 29.7729V30.7729H5.5V29.7729H0.5Z">
#    </path>
#   </svg>
#   <svg class="stroke-current" fill="none" id="n1_circle_arrow" style="display:block;width:0;height:0" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
#    <rect height="29" rx="14.5" transform="rotate(-180 29.5 29.5)" width="29" x="29.5" y="29.5">
#    </rect>
#    <path d="M9.33985 14.7014L14.6198 19.9414L15.2598 19.3014L11.1198 15.1614L20.3398 15.1614L20.3398 14.2214L11.1198 14.2214L15.2598 10.0814L14.6198 9.44141L9.33985 14.7014Z">
#    </path>
#   </svg>
#   <svg fill="none" id="n1_circle_arrow_solid" style="display:block;width:0;height:0" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
#    <mask id="path-1-inside-1_2694_77554">
#     <path clip-rule="evenodd" d="M15 0C6.71573 0 0 6.71573 0 15C0 23.2843 6.71573 30 15 30C23.2843 30 30 23.2843 30 15C30 6.71573 23.2843 0 15 0ZM15.3792 10.0601L20.6592 15.3001L15.3792 20.5601L14.7392 19.9201L18.8792 15.7801H9.65918V14.8401H18.8792L14.7392 10.7001L15.3792 10.0601Z" fill-rule="evenodd">
#     </path>
#    </mask>
#    <path clip-rule="evenodd" d="M15 0C6.71573 0 0 6.71573 0 15C0 23.2843 6.71573 30 15 30C23.2843 30 30 23.2843 30 15C30 6.71573 23.2843 0 15 0ZM15.3792 10.0601L20.6592 15.3001L15.3792 20.5601L14.7392 19.9201L18.8792 15.7801H9.65918V14.8401H18.8792L14.7392 10.7001L15.3792 10.0601Z" fill="#fff" fill-rule="evenodd">
#    </path>
#    <path d="M20.6592 15.3001L21.3649 16.0085L22.0774 15.2987L21.3636 14.5903L20.6592 15.3001ZM15.3792 10.0601L16.0836 9.35027L15.3765 8.64853L14.6721 9.35295L15.3792 10.0601ZM15.3792 20.5601L14.6721 21.2672L15.3778 21.9729L16.0849 21.2685L15.3792 20.5601ZM14.7392 19.9201L14.0321 19.213L13.325 19.9201L14.0321 20.6272L14.7392 19.9201ZM18.8792 15.7801L19.5863 16.4872L21.2934 14.7801H18.8792V15.7801ZM9.65918 15.7801H8.65918V16.7801H9.65918V15.7801ZM9.65918 14.8401V13.8401H8.65918V14.8401H9.65918ZM18.8792 14.8401V15.8401H21.2934L19.5863 14.133L18.8792 14.8401ZM14.7392 10.7001L14.0321 9.99295L13.325 10.7001L14.0321 11.4072L14.7392 10.7001ZM1 15C1 7.26801 7.26801 1 15 1V-1C6.16344 -1 -1 6.16344 -1 15H1ZM15 29C7.26801 29 1 22.732 1 15H-1C-1 23.8366 6.16344 31 15 31V29ZM29 15C29 22.732 22.732 29 15 29V31C23.8366 31 31 23.8366 31 15H29ZM15 1C22.732 1 29 7.26801 29 15H31C31 6.16344 23.8366 -1 15 -1V1ZM21.3636 14.5903L16.0836 9.35027L14.6748 10.7698L19.9548 16.0098L21.3636 14.5903ZM16.0849 21.2685L21.3649 16.0085L19.9534 14.5916L14.6734 19.8516L16.0849 21.2685ZM14.0321 20.6272L14.6721 21.2672L16.0863 19.853L15.4463 19.213L14.0321 20.6272ZM18.1721 15.073L14.0321 19.213L15.4463 20.6272L19.5863 16.4872L18.1721 15.073ZM9.65918 16.7801H18.8792V14.7801H9.65918V16.7801ZM8.65918 14.8401V15.7801H10.6592V14.8401H8.65918ZM18.8792 13.8401H9.65918V15.8401H18.8792V13.8401ZM14.0321 11.4072L18.1721 15.5472L19.5863 14.133L15.4463 9.99295L14.0321 11.4072ZM14.6721 9.35295L14.0321 9.99295L15.4463 11.4072L16.0863 10.7672L14.6721 9.35295Z" fill="#fff" mask="url(#path-1-inside-1_2694_77554)">
#    </path>
#   </svg>
#   <svg fill="none" id="n1_play" style="display:block;width:0;height:0;" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
#    <circle class="stroke-current" cx="25" cy="25" r="24.5">
#    </circle>
#    <path class="stroke-current" d="M18 35V15L36 25L18 35Z">
#    </path>
#   </svg>
#   <svg fill="none" id="n1_pupa" style="display:block;width:0;height:0;" viewbox="0 0 24 23" xmlns="http://www.w3.org/2000/svg">
#    <path clip-rule="evenodd" d="M17 8.80329C17 13.0922 13.4392 16.6066 9 16.6066C4.56077 16.6066 1 13.0922 1 8.80329C1 4.51437 4.56077 1 9 1C13.4392 1 17 4.51437 17 8.80329ZM14.9967 15.3678C13.4049 16.7601 11.3035 17.6066 9 17.6066C4.02944 17.6066 0 13.6652 0 8.80329C0 3.94137 4.02944 0 9 0C13.9706 0 18 3.94137 18 8.80329C18 11.0562 17.1348 13.1114 15.7118 14.6684L23.3531 22.1427C23.5505 22.3358 23.554 22.6524 23.3609 22.8498C23.1678 23.0472 22.8513 23.0507 22.6539 22.8576L14.9967 15.3678Z" fill="#32363A" fill-rule="evenodd">
#    </path>
#   </svg>
#   <svg fill="none" id="n1_burger" style="display:block;width:0;height:0;" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
#    <line stroke="#32363A" x2="30" y1="6.5" y2="6.5">
#    </line>
#    <line stroke="#32363A" x2="30" y1="23.5" y2="23.5">
#    </line>
#    <line stroke="#32363A" x2="30" y1="15" y2="15">
#    </line>
#   </svg>
#   <svg fill="none" id="n1_cross_menu" style="display:block;width:0;height:0;" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
#    <path d="M4 4L26 26" stroke="#32363A">
#    </path>
#    <path d="M26 4L4 26" stroke="#32363A">
#    </path>
#   </svg>
#   <svg id="n1_check" style="display:block;width:0;height:0;fill:currentColor" version="1.1" viewbox="0 0 752 752" xmlns="http://www.w3.org/2000/svg">
#    <path d="m183.6 357.87-22.184 22.168v0.003907c-3.2969 3.293-3.2969 8.6367 0 11.934l133.29 133.28v0.003907c3.7305 3.7266 8.7891 5.8242 14.066 5.8242 5.2734 0 10.332-2.0977 14.062-5.8242l267.76-267.76c1.582-1.582 2.4727-3.7305 2.4727-5.9688 0-2.2383-0.89062-4.3867-2.4727-5.9688l-22.156-22.168c-1.582-1.5898-3.7344-2.4805-5.9727-2.4805-2.2422 0-4.3945 0.89062-5.9766 2.4805l-244.31 244.3c-1.8828 1.8789-4.9336 1.8789-6.8164 0l-109.84-109.83c-3.293-3.2852-8.625-3.2852-11.918 0z">
#    </path>
#   </svg>
#   <svg id="n1_specials_star" style="display:block;width:0;height:0;fill:none;stroke:white" version="1.1" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg">
#    <path d="M7.99982 2.18188L9.79764 5.77236L13.818 6.35166L10.9089 9.14489L11.5955 13.091L7.99982 11.2269L4.40419 13.091L5.09073 9.14489L2.18164 6.35166L6.202 5.77236L7.99982 2.18188Z" stroke-linecap="round">
#    </path>
#   </svg>
#   <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js">
#   </script>
#   <script src="/front-build/js/app.js?id=8f64b9230b5c5522518a6ccb46220bfe">
#   </script>
#   <!-- Yandex.Metrika counter 2-->
#   <script type="text/javascript">
#    (function(m,e,t,r,i,k,a){m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
# 	m[i].l=1*new Date();k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)})
# (window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#
# ym(88946384, "init", {
# 	clickmap:true,
# 	trackLinks:true,
# 	accurateTrackBounce:true,
# 	webvisor:true
# });
#
#
# ym(29654565, "init", {
# 	clickmap:true,
# 	trackLinks:true,
# 	accurateTrackBounce:true,
# 	webvisor:true,
# 	trackHash:true,
# 	ecommerce:"dataLayer"
# });
#   </script>
#   <noscript>
#    <div>
#     <img alt="" src="https://mc.yandex.ru/watch/88946384" style="position:absolute; left:-9999px;"/>
#     <img alt="" src="https://mc.yandex.ru/watch/29654565" style="position:absolute; left:-9999px;"/>
#    </div>
#   </noscript>
#   <!-- /Yandex.Metrika counter -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-61773772-1">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
# function gtag(){dataLayer.push(arguments);}
# gtag('js', new Date());
# gtag('config', 'UA-61773772-1');
#   </script>
#   <script>
#    window.yaContextCb = window.yaContextCb || []
#   </script>
#   <script async="" src="https://yandex.ru/ads/system/context.js">
#   </script>
#   <script>
#    if ('serviceWorker' in navigator) {
# 	window.addEventListener('load', () => {
# 		navigator.serviceWorker.register('/front-service-worker.js').then(reg => {
# 			// sometime later…
# 			reg.update()
# 		})
# 	})
# }
#   </script>
#  </body>
# </html>

# %% [markdown]
# В такой выдаче ориентироваться гораздо удобнее (но при желании, то же можно увидеть в браузере, на большом экране).

# %% [markdown]
# Чтобы сгрузить все новости с главной страницы сайта, нужно собрать все ссылки на страницы с этими новостями. Ссылки в html-файле всегда заключены в тэг `<a></a>` и имеют атрибут `href`.
#
# **Функция `soup.find('a')`** найдет первый в дереве тег \<a>.
# Если нам нужно найти не только первый элемент, а все элементы по определенному признаку, следует использовать функцию **`soup.find_all('a')`**

# %%
soup.find_all('a')
# Out:
# [<a class="w-7.5 h-7.5" href="/search">
#  <svg class="w-full h-full">
#  <use xlink:href="#n1_pupa"></use>
#  </svg>
#  </a>,
#  <a class="col-span-3 lg:col-span-2 col-start-7 lg:col-start-9 flex items-center hover:text-main transition-colors duration-75" href="https://offline.nplus1.ru/">N + offline</a>,
#  <a class="col-span-3 lg:col-span-2 col-start-10 lg:col-start-11 flex items-center hover:text-main transition-colors duration-75" href="https://nplus.pro/">N + production</a>,
#  <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/about">
#                  О нас
#                </a>,
#  <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/difficult" target="_blank">
#                  Сложность
#                </a>,
#  <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/adv" target="_blank">
#                  Рекламодателям
#                </a>,
#  <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/blog/2022/04/01/samotek" target="_blank">
#                  Авторам
#                </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=946">Игры</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=869">Физика</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=874">Зоология</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=880">Астрономия</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=768">Генетика</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=890">Математика</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=871">Космонавтика</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=876">Археология</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=775">Нейронауки</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=767">На мышах</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=771">Звук</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=772">Красота</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=778">Научные закрытия</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=917">ИИ спешит на помощь</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=918">Когда рассеется дым</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=824">Книжная полка</a>,
#  <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
#  <svg class="w-12 h-12">
#  <use xlink:href="#n1_tg"></use>
#  </svg>
#  </a>,
#  <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
#  <svg class="w-12 h-12">
#  <use xlink:href="#n1_vk"></use>
#  </svg>
#  </a>,
#  <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
#  <svg class="w-12 h-12">
#  <use xlink:href="#n1_ok"></use>
#  </svg>
#  </a>,
#  <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
#  <svg class="w-12 h-12">
#  <use xlink:href="#n1_tw"></use>
#  </svg>
#  </a>,
#  <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/about">О нас</a>,
#  <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/difficult" target="_blank">Сложность</a>,
#  <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/adv" target="_blank">Рекламодателям</a>,
#  <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/news/2015/09/21/editor-thy-name" target="_blank">Вакансии</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=946">Игры
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=869">Физика
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=874">Зоология
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=880">Астрономия
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=768">Генетика
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=890">Математика
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=871">Космонавтика
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=876">Археология
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=775">Нейронауки
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=767">На мышах
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=771">Звук
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=772">Красота
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=778">Научные закрытия
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=917">ИИ спешит на помощь
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=918">Когда рассеется дым
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=824">Книжная полка
#            </a>,
#  <a class="hover:text-main whitespace-nowrap" href="https://offline.nplus1.ru/">N + offline</a>,
#  <a class="hover:text-main whitespace-nowrap" href="https://nplus.pro/">N + production</a>,
#  <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
#  <svg class="w-10 h-10">
#  <use xlink:href="#n1_tg"></use>
#  </svg>
#  </a>,
#  <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
#  <svg class="w-10 h-10">
#  <use xlink:href="#n1_vk"></use>
#  </svg>
#  </a>,
#  <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
#  <svg class="w-10 h-10">
#  <use xlink:href="#n1_ok"></use>
#  </svg>
#  </a>,
#  <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
#  <svg class="w-10 h-10">
#  <use xlink:href="#n1_tw"></use>
#  </svg>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=903">Наука</a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/2">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">2.2</span>
#  </a>,
#  <a class="" href="https://nplus1.ru/material/2023/12/14/nature-top-10-2023">
#  <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#  <div class="hidden sm:block max-height-[333px]">
#  <div class="-inset-0.5 absolute group">
#  <picture>
#  <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/867516/014928d934004b2f63bfc59772b5ccaf.png">
#  <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/867517/aeeafd2b48b0e0443c09edbcf956a69a.png">
#  <img alt="ChatGPT, лунная миссия и мышата от двух отцов" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#  </source></source></picture>
#  </div>
#  </div>
#  <div class="block sm:hidden">
#  <div class="-inset-0.5 absolute max-height-[333px]">
#  <picture>
#  <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/867516/014928d934004b2f63bfc59772b5ccaf.png">
#  <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/867517/aeeafd2b48b0e0443c09edbcf956a69a.png">
#  <img alt="ChatGPT, лунная миссия и мышата от двух отцов" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#  </source></source></picture>
#  </div>
#  </div>
#  <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
#  <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">ChatGPT, лунная миссия и мышата от двух отцов</h3>
#  <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#                      Редакция Nature назвала героев уходящего года
#                    </div>
#  </div>
#  </div>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=908">Подкасты</a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=873">Медицина</a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/3">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">3.9</span>
#  </a>,
#  <a class="" href="https://nplus1.ru/blog/2023/12/14/circle-gets-the-square">
#  <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#  <div class="hidden sm:block max-height-[333px]">
#  <div class="-inset-0.5 absolute group">
#  <picture>
#  <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/868087/21e63eb31348fe20076f5635f309d519.gif">
#  <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/868088/a741e7e915a37b160a9238e57d19cbe3.gif">
#  <img alt="Голова кругом" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#  </source></source></picture>
#  <picture>
#  <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/868086/05c2ddea46b61fec25b430faf49ea499.gif">
#  <img alt="Голова кругом" class="w-full h-full object-cover absolute inset-0 opacity-0 group-hover:opacity-100 transition-opacity duration-500" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#  </source></picture>
#  </div>
#  </div>
#  <div class="block sm:hidden">
#  <div class="-inset-0.5 absolute max-height-[333px]">
#  <picture>
#  <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/868087/21e63eb31348fe20076f5635f309d519.gif">
#  <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/868088/a741e7e915a37b160a9238e57d19cbe3.gif">
#  <img alt="Голова кругом" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#  </source></source></picture>
#  </div>
#  </div>
#  <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
#  <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">Голова кругом</h3>
#  <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#                      Есть ли у сосудов мозга углы
#                    </div>
#  </div>
#  </div>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=812">Партнерский материал</a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=872">Экология и климат</a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/1">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">1.1</span>
#  </a>,
#  <a class="" href="https://nplus1.ru/material/2023/12/14/green-uni-initiatives">
#  <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#  <div class="hidden sm:block max-height-[333px]">
#  <div class="-inset-0.5 absolute group">
#  <picture>
#  <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/867448/d70a69ba48c9ab8b204da20326370eff.gif">
#  <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/867449/29ac7b1c83fe2a972e776960e3bd84e1.gif">
#  <img alt="Не парами едиными" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#  </source></source></picture>
#  <picture>
#  <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/867447/0edff5ba8e5f864f03f8b4abf994dd31.gif">
#  <img alt="Не парами едиными" class="w-full h-full object-cover absolute inset-0 opacity-0 group-hover:opacity-100 transition-opacity duration-500" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#  </source></picture>
#  </div>
#  </div>
#  <div class="block sm:hidden">
#  <div class="-inset-0.5 absolute max-height-[333px]">
#  <picture>
#  <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/867448/d70a69ba48c9ab8b204da20326370eff.gif">
#  <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/867449/29ac7b1c83fe2a972e776960e3bd84e1.gif">
#  <img alt="Не парами едиными" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#  </source></source></picture>
#  </div>
#  </div>
#  <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
#  <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">Не парами едиными</h3>
#  <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#                      Как университеты становятся центрами зеленой экономики и экологического просвещения
#                    </div>
#  </div>
#  </div>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=876">Археология</a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/3">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">3.2</span>
#  </a>,
#  <a class="" href="https://nplus1.ru/news/2023/12/15/human-skin">
#  <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#  <div class="hidden sm:block max-height-[333px]">
#  <div class="-inset-0.5 absolute group">
#  <picture>
#  <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/868710/8ca3b9fb4be51fa8cbd4b1d0d2bdf991.jpg">
#  <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/868711/8930a9285a9a3de1829e48335f4c3566.jpg">
#  <img alt="У скифов нашли изделия из человеческой кожи" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#  </source></source></picture>
#  </div>
#  </div>
#  <div class="block sm:hidden">
#  <div class="-inset-0.5 absolute max-height-[333px]">
#  <picture>
#  <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/868710/8ca3b9fb4be51fa8cbd4b1d0d2bdf991.jpg">
#  <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/868711/8930a9285a9a3de1829e48335f4c3566.jpg">
#  <img alt="У скифов нашли изделия из человеческой кожи" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#  </source></source></picture>
#  </div>
#  </div>
#  <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
#  <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">У скифов нашли изделия из человеческой кожи</h3>
#  <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#                      По данным Геродота, они снимали ее с мертвых врагов
#                    </div>
#  </div>
#  </div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/12/18">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">18.12.23</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=876">
#  <p class="truncate">Археология</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">2.5</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/12/18/parasite-eggs-from-granada">
#  <div>В старинных выгребных ямах Гранады нашли яйца кишечных паразитов</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/12/18">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">18.12.23</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=877">
#  <p class="truncate">Антропология</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">1.2</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/12/18/medieval-deformed-skull">
#  <div>Женщина с искусственно деформированным черепом обрела лицо</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/12/18">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">18.12.23</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=877">
#  <p class="truncate">Антропология</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/3">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">3.1</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/12/18/qafzeh-25">
#  <div>Архаичного сапиенса из пещеры Кафзех ранили в челюсть</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/12/16">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">16.12.23</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=880">
#  <p class="truncate">Астрономия</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/4">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">4.1</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/12/16/jwst-bd-light">
#  <div>«Джеймс Уэбб» напрямую рассмотрел кандидата в рекордно легкий одиночный коричневый карлик</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/12/16">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">16.12.23</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=883">
#  <p class="truncate">Роботы и дроны</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">1.7</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/12/16/hound-record-100m">
#  <div>Корейская робособака установила рекорд среди четвероногих роботов в забеге на 100 метров</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/12/16">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">16.12.23</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=903">
#  <p class="truncate">Наука</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">1.9</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/12/16/retracted-2023">
#  <div>Больше десяти тысяч научных статей отозвали в 2023 году</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/12/16">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">16.12.23</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=882">
#  <p class="truncate">Психология</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/3">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">3.9</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/12/16/turn-off">
#  <div>Изменение сознания при медитации зафиксировали на энцефалограмме</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/12/16">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">16.12.23</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=882">
#  <p class="truncate">Психология</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">1.8</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/12/16/label-smart">
#  <div>Метки «веганский» и «растительный» не привлекли людей к продуктам без мяса</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/12/16">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">16.12.23</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=874">
#  <p class="truncate">Зоология</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">1.5</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/12/16/wisdom-dance">
#  <div>Самая старая дикая птица вернулась на родной атолл и поучаствовала в брачных танцах</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/12/15">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">15.12.23</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=872">
#  <p class="truncate">Экология и климат</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">2.9</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/12/15/cr6-forest-fires">
#  <div>Пожары в Калифорнии оказались опасным источником шестивалентного хрома</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/12/15">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">15.12.23</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=871">
#  <p class="truncate">Космонавтика</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">1.9</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/12/15/vega-later-final">
#  <div>Финальный пуск ракеты Vega перенесли на осень 2024 года</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/12/15">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">15.12.23</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=880">
#  <p class="truncate">Астрономия</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/4">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">4.1</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/12/15/cute-hot-jupiter">
#  <div>Космический телескоп размером с обувную коробку заметил потерю атмосферы горячим юпитером</div>
#  </a>,
#  <a class="shrink-0 h-60 lg:h-72 xl:h-88 relative group" href="https://nplus1.ru/blog/2023/12/14/sex-with-scientists">
#  <picture>
#  <source media="(max-width: 768px)" srcset="https://minio.nplus1.ru/app-images/867792/65798e669b97e_cover_mobile.png">
#  <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/867791/65798e656d8f8_cover_tablet.png">
#  <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/867790/65798e644509d_cover.png">
#  <img alt="«Секс с учеными: Половое размножение и другие загадки биологии»" class="w-full h-full object-cover" loading="lazy" src="https://minio.nplus1.ru/app-images/867790/65798e644509d_cover.png"/>
#  </source></source></source></picture>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/blog/2023/12/14">
#  <span class="group-hover:text-main transition-colors duration-75">14.12.23</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="https://nplus1.ru/search?tags=885">
#  <span class="group-hover:text-main transition-colors duration-75">Биология</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/material/difficulty/1">
#  <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="group-hover:text-main transition-colors duration-75">1.1</span>
#  </a>,
#  <a class="group" href="https://nplus1.ru/blog/2023/12/14/sex-with-scientists">
#  <h3 class="text-34 sm:text-22 lg:text-32 mb-1 transition-colors duration-75 group-hover:text-main">
#                  «Секс с учеными: Половое размножение и другие загадки биологии»</h3>
#  <p class="font-spectral text-main-gray text-36 sm:text-24 lg:text-34 transition-colors duration-75 group-hover:text-main">
#                  Как дрожжи научились не скрещиваться с близкими родственниками</p>
#  </a>,
#  <a class="shrink-0 h-60 lg:h-72 xl:h-88 relative group" href="https://nplus1.ru/blog/2023/12/12/the-immortal-life-of-henrietta-lacks">
#  <picture>
#  <source media="(max-width: 768px)" srcset="https://minio.nplus1.ru/app-images/867469/65785aca0a843_cover_mobile.png">
#  <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/867468/65785ac890af2_cover_tablet.png">
#  <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/867467/65785ac75f478_cover.png">
#  <img alt="«Бессмертная жизнь Генриетты Лакс»" class="w-full h-full object-cover" loading="lazy" src="https://minio.nplus1.ru/app-images/867467/65785ac75f478_cover.png"/>
#  </source></source></source></picture>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/blog/2023/12/12">
#  <span class="group-hover:text-main transition-colors duration-75">12.12.23</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="https://nplus1.ru/search?tags=885">
#  <span class="group-hover:text-main transition-colors duration-75">Биология</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/material/difficulty/1">
#  <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="group-hover:text-main transition-colors duration-75">1.1</span>
#  </a>,
#  <a class="group" href="https://nplus1.ru/blog/2023/12/12/the-immortal-life-of-henrietta-lacks">
#  <h3 class="text-34 sm:text-22 lg:text-32 mb-1 transition-colors duration-75 group-hover:text-main">
#                  «Бессмертная жизнь Генриетты Лакс»</h3>
#  <p class="font-spectral text-main-gray text-36 sm:text-24 lg:text-34 transition-colors duration-75 group-hover:text-main">
#                  Почему о первых «бессмертных» клетках долго никто не слышал?</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/12/15">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">15.12.23</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=872">
#  <p class="truncate">Экология и климат</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">1.9</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/12/15/ch4-small-arctic-lakes">
#  <div>Эмиссия метана арктическими озерами оказалась завышена на 20 процентов</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/12/15">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">15.12.23</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=870">
#  <p class="truncate">Химия</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/4">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">4.1</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/12/15/cobalt-catalyzed-borylation">
#  <div>Кобальтовый катализатор помог провести реакцию борилирования аренов</div>
#  </a>,
#  <a class="w-full h-44 group relative" href="https://nplus1.ru/material/2023/12/08/where-is-philip">
#  <picture>
#  <source media="(max-width: 768px)" srcset="https://minio.nplus1.ru/app-images/865987/209c33d65bd7ddb19ef8a67f87ba9b33.png">
#  <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/865987/209c33d65bd7ddb19ef8a67f87ba9b33.png">
#  <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/865986/903a79fc743d8a6c5429bc10dc967ab3.png">
#  <img alt="Тень отца Александра Великого" class="w-full h-full object-cover z-10" loading="lazy" src="https://minio.nplus1.ru/app-images/865986/903a79fc743d8a6c5429bc10dc967ab3.png"/>
#  </source></source></source></picture>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/2023/12/08">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">08.12.23</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=876">
#  <p class="truncate">Археология</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/4">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">4.9</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/material/2023/12/08/where-is-philip">
#  <div>Тень отца Александра Великого</div>
#  <div class="text-main-gray">Где Филипп?</div>
#  </a>,
#  <a class="shrink-0 absolute inset-0 group" href="https://nplus1.ru/material/2023/12/05/the-anatomy-of-steel">
#  <picture>
#  <source media="(max-width: 768px)" srcset="https://minio.nplus1.ru/app-images/864272/9bc4610be21bc8de1a70f5a375616ece.png">
#  <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/864271/cfff66d00033325b8d565d25a8dfc893.png">
#  <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/864271/cfff66d00033325b8d565d25a8dfc893.png">
#  <img alt="Анатомия стали" class="w-full h-full object-cover absolute inset-0 brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#  </source></source></source></picture>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="https://nplus1.ru/search?tags=812">
#  <span class="group-hover:text-main transition-colors duration-75">Партнерский материал</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/material/difficulty/3">
#  <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="group-hover:text-main transition-colors duration-75">3.7</span>
#  </a>,
#  <a class="group text-white absolute bottom-5 inset-x-6 md:inset-x-5" href="https://nplus1.ru/material/2023/12/05/the-anatomy-of-steel">
#  <h3 class="text-14 sm:text-22 lg:text-32 mb-1 transition-colors duration-75 group-hover:text-main">
#                          Анастасия Решетняк
#            </h3>
#  <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#            Анатомия стали
#          </p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/blog/2023/12/08">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">08.12.23</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=877">
#  <p class="truncate">Антропология</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">1.1</span>
#  </a>,
#  <a class="flex flex-col text-14 overflow-hidden" href="/author/mann-ivanov-i-ferber">
#  <div class="mb-0.5 max-w-full whitespace-nowrap overflow-hidden text-ellipsis">
#                                  Манн, Иванов и Фербер
#                </div>
#  <div class="font-spectral max-w-full whitespace-nowrap overflow-hidden text-ellipsis">
#                  Научно-популярные книгоиздатели
#                </div>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/blog/2023/12/08/chinese-myths">
#  <div>«Китайские мифы. От Царя обезьян и Нефритового императора до небесных драконов и духов стихий»</div>
#  <div class="text-main-gray">Зачем клеить полководцев на дверь и какими были боги счастья, долголетия и богатства</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/12/15">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">15.12.23</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=874">
#  <p class="truncate">Зоология</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/3">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">3.9</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/12/15/domestic-yak">
#  <div>Жители Тибета разводили домашних яков не меньше 2500 лет назад</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/12/15">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">15.12.23</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=874">
#  <p class="truncate">Зоология</p>
#  </a>,
# ...
#  <span class="group-hover:text-main transition-colors duration-75">10.11.23</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=946">
#  <span class="group-hover:text-main transition-colors duration-75">
#              Игры
#              </span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/difficulty/3">
#  <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="group-hover:text-main transition-colors duration-75">
#            3.2
#          </span>
#  </a>,
#  <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group" href="https://nplus1.ru/material/2023/11/10/biased">
#  <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light transition-colors duration-75 group-hover:text-main">
#            Всемирный обман мышления</p>
#  <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#              Как когнитивные искажения управляют нами</p>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/news/2023/11/27">
#  <span class="group-hover:text-main transition-colors duration-75">27.11.23</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=869">
#  <span class="group-hover:text-main transition-colors duration-75">
#              Физика
#              </span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/difficulty/4">
#  <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="group-hover:text-main transition-colors duration-75">
#            4.3
#          </span>
#  </a>,
#  <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group" href="https://nplus1.ru/news/2023/11/27/droplet-kilovolt-discharge">
#  <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light transition-colors duration-75 group-hover:text-main">
#            Падающая капля воды вызвала искровой разряд в 1200 вольт</p>
#  <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#              Который разделил воду на кислород и водород</p>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/2023/11/07">
#  <span class="group-hover:text-main transition-colors duration-75">07.11.23</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=946">
#  <span class="group-hover:text-main transition-colors duration-75">
#              Игры
#              </span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/difficulty/1">
#  <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="group-hover:text-main transition-colors duration-75">
#            1.7
#          </span>
#  </a>,
#  <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group" href="https://nplus1.ru/material/2023/11/07/measuring-the-world">
#  <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light transition-colors duration-75 group-hover:text-main">
#            Измеряя мир</p>
#  <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#              Тест об измерительных шкалах и их изобретателях</p>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/2023/09/18">
#  <span class="group-hover:text-main transition-colors duration-75">18.09.23</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=946">
#  <span class="group-hover:text-main transition-colors duration-75">
#              Игры
#              </span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/difficulty/2">
#  <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="group-hover:text-main transition-colors duration-75">
#            2.1
#          </span>
#  </a>,
#  <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group" href="https://nplus1.ru/material/2023/09/18/edible-and-inedible">
#  <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light transition-colors duration-75 group-hover:text-main">
#            Назвался груздем</p>
#  <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#              Тест, который научит вас разбираться в грибах</p>
#  </a>,
#  <a class="absolute inset-0 md:static order-2 shrink-0 brightness-50 md:brightness-100" href="https://nplus1.ru/blog/2023/12/11/npluspodcast09">
#  <picture>
#  <source media="(max-width: 768px)" srcset="https://minio.nplus1.ru/app-images/866106/ca4b49dd8a8b8455ad6049f0a0218c82.png">
#  <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/866106/ca4b49dd8a8b8455ad6049f0a0218c82.png">
#  <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/866103/b6a2540967d9b8ddfc42c498b2a00b62.png">
#  <img alt="N + podcast: обсуждаем с Андреем Шмиловичем воспаление в мозге самоубийц" class="w-full h-full object-cover" loading="lazy" src="https://minio.nplus1.ru/app-images/866103/b6a2540967d9b8ddfc42c498b2a00b62.png"/>
#  </source></source></source></picture>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/blog/2023/12/11">
#  <span class="group-hover:text-main transition-colors duration-75">11.12.23</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="https://nplus1.ru/search?tags=908">
#  <span class="group-hover:text-main transition-colors duration-75">Подкасты</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="https://nplus1.ru/search?tags=873">
#  <span class="group-hover:text-main transition-colors duration-75">Медицина</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/material/difficulty/2">
#  <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="group-hover:text-main transition-colors duration-75">2.7</span>
#  </a>,
#  <a class="group" href="https://nplus1.ru/blog/2023/12/11/npluspodcast09">
#  <h3 class="text-34 lg:text-44 mb-1 transition-colors duration-75 group-hover:text-main">
#                  N + podcast: обсуждаем с Андреем Шмиловичем воспаление в мозге самоубийц</h3>
#  <p class="text-white md:text-main-gray font-spectral text-36 lg:text-46 transition-colors duration-75 group-hover:text-main">
#  </p>
#  </a>,
#  <a class="absolute inset-0 md:static order-2 md:order-1 shrink-0 brightness-50 md:brightness-100" href="https://nplus1.ru/material/2023/12/11/green-building">
#  <picture>
#  <source media="(max-width: 768px)" srcset="https://minio.nplus1.ru/app-images/865682/81417b48d3baaca503102d1c628d3087.png">
#  <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/865682/81417b48d3baaca503102d1c628d3087.png">
#  <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/865679/510d1c9d4daedccd7a274e4ff7733e2b.png">
#  <img alt="«Зеленое» строительство" class="w-full h-full object-cover" loading="lazy" src="https://minio.nplus1.ru/app-images/865679/510d1c9d4daedccd7a274e4ff7733e2b.png"/>
#  </source></source></source></picture>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/material/2023/12/11">
#  <span class="group-hover:text-main transition-colors duration-75">11.12.23</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="https://nplus1.ru/search?tags=812">
#  <span class="group-hover:text-main transition-colors duration-75">Партнерский материал</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="https://nplus1.ru/search?tags=872">
#  <span class="group-hover:text-main transition-colors duration-75">Экология и климат</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/material/difficulty/1">
#  <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="group-hover:text-main transition-colors duration-75">1.1</span>
#  </a>,
#  <a class="group" href="https://nplus1.ru/material/2023/12/11/green-building">
#  <h3 class="text-34 lg:text-44 mb-1 transition-colors duration-75 group-hover:text-main">
#                  «Зеленое» строительство</h3>
#  <p class="text-white md:text-main-gray font-spectral text-36 lg:text-46 transition-colors duration-75 group-hover:text-main">
#                  Как Россия встраивается в мировой тренд</p>
#  </a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/news/2023/11/27/lidocaine-induces-apoptosis-in-carcinoma">
#                Лидокаин запустил апоптоз опухолевых клеток через рецептор горького вкуса</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/news/2023/11/28/meteorite-in-bed">
#                Упавший на подушку канадки метеорит прибыл из внутренней части Главного пояса астероидов</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/material/2023/11/28/dias-irae">
#                Сверхнедоверие</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/material/2023/11/30/swift-sber-test">
#                Посвифти мне тут</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/news/2023/12/01/disprozii-poimali-v-lovusku">
#                Диспрозий поймали в магическую ловушку</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/material/2023/12/04/genes-or-cats">
#                Генетический кот</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/news/2023/12/04/the-lord-of-the-hopfion-rings">
#                Физики обжали скирмионную струну хопфионным кольцом</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/news/2023/12/05/kartvelian-linguistic-family">
#                Распад пракартвельского языка удревнили примерно на три тысячи лет</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/news/2023/12/06/mutations-intercoursed">
#                Мутагенез при образовании половых клеток оказался восьмикратно недооценен</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/material/2023/12/08/where-is-philip">
#                Тень отца Александра Великого</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/news/2023/12/08/jt-60-sa">
#                В Японии запущен крупнейший сверхпроводящий токамак JT-60SA</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/news/2023/12/11/time-resolution-accuracy">
#                Измерение времени ограничили в точности и разрешении</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/news/2023/12/11/poligonal-faraday-waves">
#                Вибрирующий вок сформировал многоугольники из воды</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/news/2023/12/13/brain-untouched">
#                CAR-T-лимфоциты третьего поколения оказались эффективными без нейротоксичности</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/news/2023/12/13/aboriginal-australians">
#                Предки австралийских аборигенов и папуасов разошлись примерно 47 тысяч лет назад</a>,
#  <a class="transition-colors duration-75 hover:text-main" href="https://nplus1.ru/about" target="_blank">О нас</a>,
#  <a class="transition-colors duration-75 hover:text-main" href="https://nplus1.ru/difficult" target="_blank">Сложность</a>,
#  <a class="transition-colors duration-75 hover:text-main" href="https://nplus1.ru/adv" target="_blank">Рекламодателям</a>,
#  <a class="transition-colors duration-75 hover:text-main" href="https://nplus1.ru/blog/2022/04/01/samotek" target="_blank">Авторам</a>,
#  <a href="/cdn-cgi/l/email-protection#680604280618041d1b59461a1d"><span class="__cf_email__" data-cfemail="6d03012d031d01181e5c431f18">[email protected]</span></a>,
#  <a href="/cdn-cgi/l/email-protection#422b2c242d022c322e3731736c3037"><span class="__cf_email__" data-cfemail="8be2e5ede4cbe5fbe7fef8baa5f9fe">[email protected]</span></a>,
#  <a class="underline transition-colors duration-75 hover:text-main inline-block col-span-6 sm:col-span-5 mb-5 font-spectral italic" href="/personal-data-policy">Политика
#            обработки
#            персональных данных пользователей сайта
#          </a>,
#  <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
#  <svg class="w-12 h-12">
#  <use xlink:href="#n1_tg"></use>
#  </svg>
#  </a>,
#  <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
#  <svg class="w-12 h-12">
#  <use xlink:href="#n1_vk"></use>
#  </svg>
#  </a>,
#  <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
#  <svg class="w-12 h-12">
#  <use xlink:href="#n1_ok"></use>
#  </svg>
#  </a>,
#  <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
#  <svg class="w-12 h-12">
#  <use xlink:href="#n1_tw"></use>
#  </svg>
#  </a>]

# %%
len(soup.find_all('a'))
# Out:
# 438

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# /search
# https://offline.nplus1.ru/
# https://nplus.pro/
# https://nplus1.ru/about
# https://nplus1.ru/difficult
# https://nplus1.ru/adv
# https://nplus1.ru/blog/2022/04/01/samotek
# https://nplus1.ru/search?tags=946
# https://nplus1.ru/search?tags=869
# https://nplus1.ru/search?tags=874
# https://nplus1.ru/search?tags=880
# https://nplus1.ru/search?tags=768
# https://nplus1.ru/search?tags=890
# https://nplus1.ru/search?tags=871
# https://nplus1.ru/search?tags=876
# https://nplus1.ru/search?tags=775
# https://nplus1.ru/search?tags=767
# https://nplus1.ru/search?tags=771
# https://nplus1.ru/search?tags=772
# https://nplus1.ru/search?tags=778
# https://nplus1.ru/search?tags=917
# https://nplus1.ru/search?tags=918
# https://nplus1.ru/search?tags=824
# https://t.me/nplusone
# https://vk.com/nplusone
# https://ok.ru/nplus1
# https://twitter.com/nplusodin
# https://nplus1.ru/about
# https://nplus1.ru/difficult
# https://nplus1.ru/adv
# https://nplus1.ru/news/2015/09/21/editor-thy-name
# https://nplus1.ru/search?tags=946
# https://nplus1.ru/search?tags=869
# https://nplus1.ru/search?tags=874
# https://nplus1.ru/search?tags=880
# https://nplus1.ru/search?tags=768
# https://nplus1.ru/search?tags=890
# https://nplus1.ru/search?tags=871
# https://nplus1.ru/search?tags=876
# https://nplus1.ru/search?tags=775
# https://nplus1.ru/search?tags=767
# https://nplus1.ru/search?tags=771
# https://nplus1.ru/search?tags=772
# https://nplus1.ru/search?tags=778
# https://nplus1.ru/search?tags=917
# https://nplus1.ru/search?tags=918
# https://nplus1.ru/search?tags=824
# https://offline.nplus1.ru/
# https://nplus.pro/
# https://t.me/nplusone
# https://vk.com/nplusone
# https://ok.ru/nplus1
# https://twitter.com/nplusodin
# https://nplus1.ru/search?tags=903
# /material/difficulty/2
# https://nplus1.ru/material/2023/12/14/nature-top-10-2023
# https://nplus1.ru/search?tags=908
# https://nplus1.ru/search?tags=873
# /material/difficulty/3
# https://nplus1.ru/blog/2023/12/14/circle-gets-the-square
# https://nplus1.ru/search?tags=812
# https://nplus1.ru/search?tags=872
# /material/difficulty/1
# https://nplus1.ru/material/2023/12/14/green-uni-initiatives
# https://nplus1.ru/search?tags=876
# /material/difficulty/3
# https://nplus1.ru/news/2023/12/15/human-skin
# /news/2023/12/18
# https://nplus1.ru/search?tags=876
# /material/difficulty/2
# https://nplus1.ru/news/2023/12/18/parasite-eggs-from-granada
# /news/2023/12/18
# https://nplus1.ru/search?tags=877
# /material/difficulty/1
# https://nplus1.ru/news/2023/12/18/medieval-deformed-skull
# /news/2023/12/18
# https://nplus1.ru/search?tags=877
# /material/difficulty/3
# https://nplus1.ru/news/2023/12/18/qafzeh-25
# /news/2023/12/16
# https://nplus1.ru/search?tags=880
# /material/difficulty/4
# https://nplus1.ru/news/2023/12/16/jwst-bd-light
# /news/2023/12/16
# https://nplus1.ru/search?tags=883
# /material/difficulty/1
# https://nplus1.ru/news/2023/12/16/hound-record-100m
# /news/2023/12/16
# https://nplus1.ru/search?tags=903
# /material/difficulty/1
# https://nplus1.ru/news/2023/12/16/retracted-2023
# /news/2023/12/16
# https://nplus1.ru/search?tags=882
# /material/difficulty/3
# https://nplus1.ru/news/2023/12/16/turn-off
# /news/2023/12/16
# https://nplus1.ru/search?tags=882
# /material/difficulty/1
# https://nplus1.ru/news/2023/12/16/label-smart
# /news/2023/12/16
# https://nplus1.ru/search?tags=874
# /material/difficulty/1
# https://nplus1.ru/news/2023/12/16/wisdom-dance
# /news/2023/12/15
# https://nplus1.ru/search?tags=872
# /material/difficulty/2
# https://nplus1.ru/news/2023/12/15/cr6-forest-fires
# /news/2023/12/15
# https://nplus1.ru/search?tags=871
# /material/difficulty/1
# https://nplus1.ru/news/2023/12/15/vega-later-final
# /news/2023/12/15
# https://nplus1.ru/search?tags=880
# /material/difficulty/4
# https://nplus1.ru/news/2023/12/15/cute-hot-jupiter
# https://nplus1.ru/blog/2023/12/14/sex-with-scientists
# /blog/2023/12/14
# https://nplus1.ru/search?tags=885
# /material/difficulty/1
# https://nplus1.ru/blog/2023/12/14/sex-with-scientists
# https://nplus1.ru/blog/2023/12/12/the-immortal-life-of-henrietta-lacks
# /blog/2023/12/12
# https://nplus1.ru/search?tags=885
# /material/difficulty/1
# https://nplus1.ru/blog/2023/12/12/the-immortal-life-of-henrietta-lacks
# /news/2023/12/15
# https://nplus1.ru/search?tags=872
# /material/difficulty/1
# https://nplus1.ru/news/2023/12/15/ch4-small-arctic-lakes
# /news/2023/12/15
# https://nplus1.ru/search?tags=870
# /material/difficulty/4
# https://nplus1.ru/news/2023/12/15/cobalt-catalyzed-borylation
# https://nplus1.ru/material/2023/12/08/where-is-philip
# /material/2023/12/08
# https://nplus1.ru/search?tags=876
# /material/difficulty/4
# https://nplus1.ru/material/2023/12/08/where-is-philip
# https://nplus1.ru/material/2023/12/05/the-anatomy-of-steel
# https://nplus1.ru/search?tags=812
# /material/difficulty/3
# https://nplus1.ru/material/2023/12/05/the-anatomy-of-steel
# /blog/2023/12/08
# https://nplus1.ru/search?tags=877
# /material/difficulty/1
# /author/mann-ivanov-i-ferber
# https://nplus1.ru/blog/2023/12/08/chinese-myths
# /news/2023/12/15
# https://nplus1.ru/search?tags=874
# /material/difficulty/3
# https://nplus1.ru/news/2023/12/15/domestic-yak
# /news/2023/12/15
# https://nplus1.ru/search?tags=874
# /material/difficulty/2
# https://nplus1.ru/news/2023/12/15/birds-vocal-exercises
# /news/2023/12/15
# https://nplus1.ru/search?tags=882
# /material/difficulty/2
# https://nplus1.ru/news/2023/12/15/dissatisfaction-guaranteed
# https://nplus1.ru/material/2023/12/05/smart-fungi
# /material/2023/12/05
# https://nplus1.ru/search?tags=879
# /material/difficulty/3
# https://nplus1.ru/material/2023/12/05/smart-fungi
# /news/2023/12/14
# https://nplus1.ru/search?tags=871
# /material/difficulty/2
# https://nplus1.ru/news/2023/12/14/voyager-1-ill
# /news/2023/12/14
# https://nplus1.ru/search?tags=874
# /material/difficulty/1
# https://nplus1.ru/news/2023/12/14/nemesia-berlandi
# https://nplus1.ru/material/2023/12/04/genes-or-cats
# /material/2023/12/04
# https://nplus1.ru/search?tags=874
# /material/difficulty/5
# https://nplus1.ru/material/2023/12/04/genes-or-cats
# https://nplus1.ru/material/2023/11/30/explain-this
# https://nplus1.ru/search?tags=812
# /material/difficulty/1
# https://nplus1.ru/material/2023/11/30/explain-this
# /blog/2023/12/07
# https://nplus1.ru/search?tags=874
# /material/difficulty/1
# /author/alpina-non-fiksn
# https://nplus1.ru/blog/2023/12/07/an-immense-world
# /news/2023/12/14
# https://nplus1.ru/search?tags=874
# /material/difficulty/2
# https://nplus1.ru/news/2023/12/14/%D1%81hlorophanes-spiza
# /news/2023/12/14
# https://nplus1.ru/search?tags=873
# /material/difficulty/3
# https://nplus1.ru/news/2023/12/14/helicobacter-pylori-and-alzheimers-disease
# /news/2023/12/14
# https://nplus1.ru/search?tags=873
# /material/difficulty/2
# https://nplus1.ru/news/2023/12/14/chronic-hcv
# https://nplus1.ru/material/2023/11/30/swift-sber-test
# /material/2023/11/30
# https://nplus1.ru/search?tags=812
# /material/difficulty/4
# https://nplus1.ru/material/2023/11/30/swift-sber-test
# /news/2023/12/14
# https://nplus1.ru/search?tags=869
# /material/difficulty/3
# https://nplus1.ru/news/2023/12/14/sausage-catastrophe
# /news/2023/12/14
# https://nplus1.ru/search?tags=877
# /material/difficulty/2
# https://nplus1.ru/news/2023/12/14/caries-prevalence
# https://nplus1.ru/material/2023/11/28/dias-irae
# /material/2023/11/28
# https://nplus1.ru/search?tags=879
# /material/difficulty/7
# https://nplus1.ru/material/2023/11/28/dias-irae
# https://nplus1.ru/material/2023/11/24/pwm-issue
# https://nplus1.ru/search?tags=812
# /material/difficulty/1
# https://nplus1.ru/material/2023/11/24/pwm-issue
# /blog/2023/12/04
# https://nplus1.ru/search?tags=817
# /material/difficulty/1
# /author/mann-ivanov-i-ferber
# https://nplus1.ru/blog/2023/12/04/the-once-and-future-sex
# /news/2023/12/14
# https://nplus1.ru/search?tags=873
# /material/difficulty/2
# https://nplus1.ru/news/2023/12/14/lonelinflammation
# /news/2023/12/14
# https://nplus1.ru/search?tags=883
# /material/difficulty/1
# https://nplus1.ru/news/2023/12/14/robot-tesla-optimus-gen-2
# /news/2023/12/14
# https://nplus1.ru/search?tags=873
# /material/difficulty/2
# https://nplus1.ru/news/2023/12/14/abdominal-ectopic-pregnancy
# https://nplus1.ru/material/2023/11/22/neuro-classic
# /material/2023/11/22
# https://nplus1.ru/search?tags=812
# /material/difficulty/1
# https://nplus1.ru/material/2023/11/22/neuro-classic
# /news/2023/12/13
# https://nplus1.ru/search?tags=873
# /material/difficulty/4
# https://nplus1.ru/news/2023/12/13/sick-of-gdf
# /news/2023/12/13
# https://nplus1.ru/search?tags=877
# /material/difficulty/4
# https://nplus1.ru/news/2023/12/13/aboriginal-australians
# https://nplus1.ru/material/2023/11/20/from-animal-to-human
# /material/2023/11/20
# https://nplus1.ru/search?tags=812
# /material/difficulty/2
# https://nplus1.ru/material/2023/11/20/from-animal-to-human
# https://nplus1.ru/material/2023/11/20/open-source-licenses
# https://nplus1.ru/search?tags=812
# /material/difficulty/3
# https://nplus1.ru/material/2023/11/20/open-source-licenses
# /blog/2023/12/01
# https://nplus1.ru/search?tags=895
# /material/difficulty/1
# /author/alpina-non-fiksn
# https://nplus1.ru/blog/2023/12/01/babel-fish
# /news/2023/12/13
# https://nplus1.ru/search?tags=887
# /material/difficulty/1
# https://nplus1.ru/news/2023/12/13/hyundai-memory-allow-integrated-snow-chain
# /news/2023/12/13
# https://nplus1.ru/search?tags=873
# /material/difficulty/2
# https://nplus1.ru/news/2023/12/13/dementia-after-stroke
# /news/2023/12/13
# https://nplus1.ru/search?tags=885
# /material/difficulty/2
# https://nplus1.ru/news/2023/12/13/sap-tbi
# https://nplus1.ru/material/2023/11/20/knock-on-the-seabed
# /material/2023/11/20
# https://nplus1.ru/search?tags=946
# /material/difficulty/2
# https://nplus1.ru/material/2023/11/20/knock-on-the-seabed
# /news/2023/12/13
# https://nplus1.ru/search?tags=872
# /material/difficulty/1
# https://nplus1.ru/news/2023/12/13/haliotis-rufescens
# /news/2023/12/13
# https://nplus1.ru/search?tags=877
# /material/difficulty/3
# https://nplus1.ru/news/2023/12/13/cliff-tomb-from-china
# https://nplus1.ru/material/2023/11/20/where-the-dino-lies
# /material/2023/11/20
# https://nplus1.ru/search?tags=946
# /material/difficulty/2
# https://nplus1.ru/material/2023/11/20/where-the-dino-lies
# https://nplus1.ru/material/2023/11/17/archeological-monuments
# https://nplus1.ru/search?tags=946
# /material/difficulty/2
# https://nplus1.ru/material/2023/11/17/archeological-monuments
# /blog/2023/11/30
# https://nplus1.ru/search?tags=875
# /material/difficulty/3
# /author/marat-xamadeev
# https://nplus1.ru/blog/2023/11/30/chronon-radar
# /news/2023/12/13
# https://nplus1.ru/search?tags=873
# /material/difficulty/6
# https://nplus1.ru/news/2023/12/13/brain-untouched
# /news/2023/12/13
# https://nplus1.ru/search?tags=872
# /material/difficulty/2
# https://nplus1.ru/news/2023/12/13/emoji-zoo
# /news/2023/12/13
# https://nplus1.ru/search?tags=873
# /material/difficulty/3
# https://nplus1.ru/news/2023/12/13/ketogenic-diet-in-polycystic-kidney-disease
# https://nplus1.ru/material/2023/11/17/love-or-symbiosis
# /material/2023/11/17
# https://nplus1.ru/search?tags=946
# /material/difficulty/3
# https://nplus1.ru/material/2023/11/17/love-or-symbiosis
# /news/2023/12/05
# https://nplus1.ru/search?tags=887
# /material/difficulty/1
# https://nplus1.ru/news/2023/12/05/automatic-transmission-for-bicycle-haven-mercer
# /material/2023/11/10
# https://nplus1.ru/search?tags=946
# /material/difficulty/4
# https://nplus1.ru/material/2023/11/10/dialectological-test
# /material/2023/08/21
# https://nplus1.ru/search?tags=946
# /material/difficulty/3
# https://nplus1.ru/material/2023/08/21/arctic-or-antarctic
# /material/2023/09/06
# https://nplus1.ru/search?tags=946
# /material/difficulty/2
# https://nplus1.ru/material/2023/09/06/draw-a-constellation
# /material/2023/09/22
# https://nplus1.ru/search?tags=946
# /material/difficulty/2
# https://nplus1.ru/material/2023/09/22/who-died-out-first
# /material/2023/11/17
# https://nplus1.ru/search?tags=946
# /material/difficulty/3
# https://nplus1.ru/material/2023/11/17/love-or-symbiosis
# /material/2023/11/10
# https://nplus1.ru/search?tags=946
# /material/difficulty/3
# https://nplus1.ru/material/2023/11/10/first-aid
# /material/2023/11/17
# https://nplus1.ru/search?tags=946
# /material/difficulty/3
# https://nplus1.ru/material/2023/11/17/choose-your-homo
# /material/2023/11/17
# https://nplus1.ru/search?tags=946
# /material/difficulty/4
# https://nplus1.ru/material/2023/11/17/make-a-color
# /material/2023/11/07
# https://nplus1.ru/search?tags=946
# /material/difficulty/2
# https://nplus1.ru/material/2023/11/07/to-the-factory
# /material/2023/11/17
# https://nplus1.ru/search?tags=946
# /material/difficulty/2
# https://nplus1.ru/material/2023/11/17/archeological-monuments
# /material/2023/05/22
# https://nplus1.ru/search?tags=890
# /material/difficulty/4
# https://nplus1.ru/material/2023/05/22/pi-calculator
# /material/2023/11/10
# https://nplus1.ru/search?tags=946
# /material/difficulty/2
# https://nplus1.ru/material/2023/11/10/bitten-2
# /news/2023/11/28
# https://nplus1.ru/search?tags=872
# /material/difficulty/1
# https://nplus1.ru/news/2023/11/28/the-largest-iceberg-ever
# /material/2023/11/10
# https://nplus1.ru/search?tags=946
# /material/difficulty/2
# https://nplus1.ru/material/2023/11/10/bitten
# /material/2023/11/10
# https://nplus1.ru/search?tags=946
# /material/difficulty/2
# https://nplus1.ru/material/2023/11/10/bitten-3
# /material/2023/11/10
# https://nplus1.ru/search?tags=946
# /material/difficulty/3
# https://nplus1.ru/material/2023/11/10/biased
# /news/2023/11/27
# https://nplus1.ru/search?tags=869
# /material/difficulty/4
# https://nplus1.ru/news/2023/11/27/droplet-kilovolt-discharge
# /material/2023/11/07
# https://nplus1.ru/search?tags=946
# /material/difficulty/1
# https://nplus1.ru/material/2023/11/07/measuring-the-world
# /material/2023/09/18
# https://nplus1.ru/search?tags=946
# /material/difficulty/2
# https://nplus1.ru/material/2023/09/18/edible-and-inedible
# https://nplus1.ru/blog/2023/12/11/npluspodcast09
# /blog/2023/12/11
# https://nplus1.ru/search?tags=908
# https://nplus1.ru/search?tags=873
# /material/difficulty/2
# https://nplus1.ru/blog/2023/12/11/npluspodcast09
# https://nplus1.ru/material/2023/12/11/green-building
# /material/2023/12/11
# https://nplus1.ru/search?tags=812
# https://nplus1.ru/search?tags=872
# /material/difficulty/1
# https://nplus1.ru/material/2023/12/11/green-building
# https://nplus1.ru/news/2023/11/27/lidocaine-induces-apoptosis-in-carcinoma
# https://nplus1.ru/news/2023/11/28/meteorite-in-bed
# https://nplus1.ru/material/2023/11/28/dias-irae
# https://nplus1.ru/material/2023/11/30/swift-sber-test
# https://nplus1.ru/news/2023/12/01/disprozii-poimali-v-lovusku
# https://nplus1.ru/material/2023/12/04/genes-or-cats
# https://nplus1.ru/news/2023/12/04/the-lord-of-the-hopfion-rings
# https://nplus1.ru/news/2023/12/05/kartvelian-linguistic-family
# https://nplus1.ru/news/2023/12/06/mutations-intercoursed
# https://nplus1.ru/material/2023/12/08/where-is-philip
# https://nplus1.ru/news/2023/12/08/jt-60-sa
# https://nplus1.ru/news/2023/12/11/time-resolution-accuracy
# https://nplus1.ru/news/2023/12/11/poligonal-faraday-waves
# https://nplus1.ru/news/2023/12/13/brain-untouched
# https://nplus1.ru/news/2023/12/13/aboriginal-australians
# https://nplus1.ru/about
# https://nplus1.ru/difficult
# https://nplus1.ru/adv
# https://nplus1.ru/blog/2022/04/01/samotek
# /cdn-cgi/l/email-protection#680604280618041d1b59461a1d
# /cdn-cgi/l/email-protection#422b2c242d022c322e3731736c3037
# /personal-data-policy
# https://t.me/nplusone
# https://vk.com/nplusone
# https://ok.ru/nplus1
# https://twitter.com/nplusodin

# %% [markdown]
# Ссылок много. Но нам нужны только новости – ссылки, которые начинаются со слова `/news`. Добавим условие: будем выбирать только те ссылки, в которых есть `/news`. Создадим пустой список `urls` и будем добавлять в него только ссылки, которые удовлетворяют этому условию.

# %%
urls = []

for link in soup.find_all('a'):
#     print(link)
    if '/news' in link.get('href'):
        if 'https://' in link.get('href'):
            urls.append(link.get('href'))
urls
# Out:
# ['https://nplus1.ru/news/2015/09/21/editor-thy-name',
#  'https://nplus1.ru/news/2023/12/15/human-skin',
#  'https://nplus1.ru/news/2023/12/18/parasite-eggs-from-granada',
#  'https://nplus1.ru/news/2023/12/18/medieval-deformed-skull',
#  'https://nplus1.ru/news/2023/12/18/qafzeh-25',
#  'https://nplus1.ru/news/2023/12/16/jwst-bd-light',
#  'https://nplus1.ru/news/2023/12/16/hound-record-100m',
#  'https://nplus1.ru/news/2023/12/16/retracted-2023',
#  'https://nplus1.ru/news/2023/12/16/turn-off',
#  'https://nplus1.ru/news/2023/12/16/label-smart',
#  'https://nplus1.ru/news/2023/12/16/wisdom-dance',
#  'https://nplus1.ru/news/2023/12/15/cr6-forest-fires',
#  'https://nplus1.ru/news/2023/12/15/vega-later-final',
#  'https://nplus1.ru/news/2023/12/15/cute-hot-jupiter',
#  'https://nplus1.ru/news/2023/12/15/ch4-small-arctic-lakes',
#  'https://nplus1.ru/news/2023/12/15/cobalt-catalyzed-borylation',
#  'https://nplus1.ru/news/2023/12/15/domestic-yak',
#  'https://nplus1.ru/news/2023/12/15/birds-vocal-exercises',
#  'https://nplus1.ru/news/2023/12/15/dissatisfaction-guaranteed',
#  'https://nplus1.ru/news/2023/12/14/voyager-1-ill',
#  'https://nplus1.ru/news/2023/12/14/nemesia-berlandi',
#  'https://nplus1.ru/news/2023/12/14/%D1%81hlorophanes-spiza',
#  'https://nplus1.ru/news/2023/12/14/helicobacter-pylori-and-alzheimers-disease',
#  'https://nplus1.ru/news/2023/12/14/chronic-hcv',
#  'https://nplus1.ru/news/2023/12/14/sausage-catastrophe',
#  'https://nplus1.ru/news/2023/12/14/caries-prevalence',
#  'https://nplus1.ru/news/2023/12/14/lonelinflammation',
#  'https://nplus1.ru/news/2023/12/14/robot-tesla-optimus-gen-2',
#  'https://nplus1.ru/news/2023/12/14/abdominal-ectopic-pregnancy',
#  'https://nplus1.ru/news/2023/12/13/sick-of-gdf',
#  'https://nplus1.ru/news/2023/12/13/aboriginal-australians',
#  'https://nplus1.ru/news/2023/12/13/hyundai-memory-allow-integrated-snow-chain',
#  'https://nplus1.ru/news/2023/12/13/dementia-after-stroke',
#  'https://nplus1.ru/news/2023/12/13/sap-tbi',
#  'https://nplus1.ru/news/2023/12/13/haliotis-rufescens',
#  'https://nplus1.ru/news/2023/12/13/cliff-tomb-from-china',
#  'https://nplus1.ru/news/2023/12/13/brain-untouched',
#  'https://nplus1.ru/news/2023/12/13/emoji-zoo',
#  'https://nplus1.ru/news/2023/12/13/ketogenic-diet-in-polycystic-kidney-disease',
#  'https://nplus1.ru/news/2023/12/05/automatic-transmission-for-bicycle-haven-mercer',
#  'https://nplus1.ru/news/2023/11/28/the-largest-iceberg-ever',
#  'https://nplus1.ru/news/2023/11/27/droplet-kilovolt-discharge',
#  'https://nplus1.ru/news/2023/11/27/lidocaine-induces-apoptosis-in-carcinoma',
#  'https://nplus1.ru/news/2023/11/28/meteorite-in-bed',
#  'https://nplus1.ru/news/2023/12/01/disprozii-poimali-v-lovusku',
#  'https://nplus1.ru/news/2023/12/04/the-lord-of-the-hopfion-rings',
#  'https://nplus1.ru/news/2023/12/05/kartvelian-linguistic-family',
#  'https://nplus1.ru/news/2023/12/06/mutations-intercoursed',
#  'https://nplus1.ru/news/2023/12/08/jt-60-sa',
#  'https://nplus1.ru/news/2023/12/11/time-resolution-accuracy',
#  'https://nplus1.ru/news/2023/12/11/poligonal-faraday-waves',
#  'https://nplus1.ru/news/2023/12/13/brain-untouched',
#  'https://nplus1.ru/news/2023/12/13/aboriginal-australians']

# %%
len(urls)
# Out:
# 53

# %%
urls[1]
# Out:
# 'https://nplus1.ru/news/2023/12/15/human-skin'

# %% [markdown]
# Теперь наша задача сводится к следующему: изучить одну страницу с новостью, научиться из нее вытаскивать текст и всю необходимую информацию, а потом применить весь набор действий к каждой ссылке из `full_urls` в цикле. Посмотрим на новость с индексом 1, у вас может быть другая, новости обновляются.

# %%
url0 = urls[1]

page0 = requests.get(url0)
print(page0)

soup0 = BeautifulSoup(page0.text, 'html')
print(soup0)
# Out:
# <Response [200]>
# <!DOCTYPE html>
# <html lang="ru" prefix="og: http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>У скифов нашли изделия из человеческой кожи. По данным Геродота, они снимали ее с мертвых врагов</title>
# <link as="font" crossorigin="" href="https://staticn1.nplus1.ru/fonts/AeonikPro/AeonikPro-Regular.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://staticn1.nplus1.ru/fonts/Spectral/Spectral-Regular.woff" rel="preload" type="font/woff2"/>
# <link href="/front-build/css/main.css?id=9b496fbb252428c03791da99722528ab" rel="stylesheet"/>
# <link href="/front-build/css/app.css?id=f9c00b5102d287d01698f43324336ca6" rel="stylesheet"/>
# <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/site.webmanifest" rel="manifest"/>
# <link color="#f26e40" href="/safari-pinned-tab.svg" rel="mask-icon"/>
# <meta content="#f26e40" name="msapplication-TileColor"/>
# <meta content="#ffffff" name="theme-color"/>
# <link href="https://nplus1.ru/news/2023/12/15/human-skin" rel="canonical"/>
# <meta content="8c90b02c84ac3b72" name="yandex-verification"/>
# <meta content="b419949322895fc9106e24ed01be58ac" name="pmail-verification"/>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#
#     })(window,document,'script','dataLayer','GTM-PJWMQBQ');</script>
# <!-- End Google Tag Manager -->
# <meta content="N + 1 — главное издание о науке, технике и технологиях" name="description"/>
# <meta content="N + 1 — главное издание о науке, технике и технологиях" property="og:site_name"/>
# <meta content="У скифов нашли изделия из человеческой кожи" property="og:title"/>
# <meta content="https://minio.nplus1.ru/app-images/868703/657be5cfaa218_cover_share.jpeg" property="og:image"/>
# <meta content="https://nplus1.ru/news/2023/12/15/human-skin" property="og:url"/>
# <meta content="N + 1 — главное издание о науке, технике и технологиях" property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="2023-12-15" itemprop="datePublished"/>
# <!-- amp page -->
# <link href="https://nplus1.ru/news/2023/12/15/human-skin/amp" rel="amphtml"/>
# <meta content="2023-12-15" itemprop="datePublished"/>
# <meta content="Михаил Подрезов" name="mediator_author"/>
# <meta content="Михаил Подрезов" name="author"/>
# <meta content="" name="copyright"/>
# <script type="application/ld+json">
#     {
#       "@context": "https://schema.org",
#       "@type": "NewsArticle",
#       "mainEntityOfPage": {
#         "@type": "WebPage",
#         "@id": "https://nplus1.ru/news/2023/12/15/human-skin"
#       },
#       "headline": "У скифов нашли изделия из человеческой кожи",
#       "description": "По данным Геродота, они снимали ее с мертвых врагов",
#             "image": "https://minio.nplus1.ru/app-images/868703/657be5cfaa218_cover_share.jpeg",
#
#
#
#
#           "author": {
#         "@type": "Person",
#         "name": "Михаил Подрезов",
#                 "image": "https://minio.nplus1.ru/app-images/694945/74bdb254e2830245d9d6f5901187ee56.jpg",
#                 "url": "https://nplus1.ru/author/mixail-podrezov"
#         },
#
#         "publisher": {
#       "@type": "Organization",
#       "name": "N+1",
#       "logo": {
#         "@type": "ImageObject",
#         "url": "https://minio.nplus1.ru/app-images/868703/657be5cfaa218_cover_share.jpeg"
#       }
#     },
#     "datePublished": "2023-12-15",
#       "dateModified": "2023-12-15"
#     }
#
#
#
#     </script>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@nplusodin" name="twitter:site"/>
# <meta content="У скифов нашли изделия из человеческой кожи" name="twitter:title"/>
# <meta content="N + 1 — главное издание о науке, технике и технологиях" name="twitter:description"/>
# <meta content="https://minio.nplus1.ru/app-images/868703/657be5cfaa218_cover_share.jpeg" name="twitter:image"/>
# <link href="https://nplus1.ru/rss" rel="alternate" title="RSS" type="application/rss+xml"/>
# </head>
# <body class="antialiased">
# <!-- Top.Mail.Ru counter -->
# <script type="text/javascript">
#
# var tmr = window.tmr || (window._tmr = []);
#
# _tmr.push({id: "3377932", type: "pageView", start: (new Date()).getTime()});
#
# (function (d, w, id) {
#
#   if (d.getElementById(id)) return;
#
#   var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
#
#   ts.src = "https://top-fwz1.mail.ru/js/code.js";
#
#   var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
#
#   if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
#
# })(document, window, "tmr-code");
#
# </script>
# <noscript><div><img alt="Top.Mail.Ru" src="https://top-fwz1.mail.ru/counter?id=3377932;js=na" style="position:absolute;left:-9999px;"/></div></noscript>
# <!-- /Top.Mail.Ru counter -->
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PJWMQBQ" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <div class="font-aeonik text-main-black flex flex-col min-h-screen pt-15 bg-light-gray" id="appfront">
# <header class="bg-light-gray fixed h-15 left-0 top-0 w-full z-50" data-ref-header="" ref="headerRef">
# <div class="absolute bg-main-gray/5 bottom-0 left-0 top-0" id="progressBar" style="z-index: -1"></div>
# <div class="border-b border-main-gray h-full">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto flex justify-between items-center h-full" data-ref-header-container="" ref="headerContainerRef">
# <button aria-label="Go" class="w-7.5 h-7.5" data-ref-header-menu-btn="" id="topMenuBtn" ref="headerMenuBtnRef">
# <template v-if="isOpenDesktopMenu || isOpenMobileMenu">
# <svg class="w-full h-full">
# <use xlink:href="#n1_cross_menu"></use>
# </svg>
# </template>
# <template v-else="">
# <svg class="w-full h-full">
# <use xlink:href="#n1_burger"></use>
# </svg>
# </template>
# </button>
# <div>
# <a href="/">
# <img alt="as" height="23" loading="lazy" src="https://staticn1.nplus1.ru/image-new/logo.svg" width="57"/>
# </a>
# </div>
# <a class="w-7.5 h-7.5" href="/search">
# <svg class="w-full h-full">
# <use xlink:href="#n1_pupa"></use>
# </svg>
# </a>
# </div>
# </div>
# <nav :style="stylesNavDesktop" class="relative bg-light-gray max-h-0 n1_top_nav overflow-hidden" id="navMenu" v-if="isOpenDesktopMenu">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto h-full flex flex-col overflow-y-auto">
# <div class="py-12 mb-12 border-b border-gray-2 text-18 grid grid-cols-flow lg:grid-cols-12 gap-x-5 md:gap-x-9">
# <!--
#         <a @click.native="menuClose"
#            class="col-span-3 flex gap-x-2 lg:gap-x-5 items-center hover:text-main transition-colors duration-75"
#            href="/lk">
#           <svg class="h-10 lg:h-12 w-10 lg:w-12 shrink-0">
#             <use xlink:href="#n1_person"></use>
#           </svg>
#           <span>Личный кабинет</span>
#         </a>
#         -->
# <a class="col-span-3 lg:col-span-2 col-start-7 lg:col-start-9 flex items-center hover:text-main transition-colors duration-75" href="https://offline.nplus1.ru/">N + offline</a>
# <a class="col-span-3 lg:col-span-2 col-start-10 lg:col-start-11 flex items-center hover:text-main transition-colors duration-75" href="https://nplus.pro/">N + production</a>
# </div>
# <div class="grid grid-cols-12 gap-x-5 gap-y-5 md:gap-y-9 pb-6">
# <div class="col-span-6 md:col-span-3 text-20 lg:text-26 xl:text-34 font-spectral flex flex-col gap-y-3">
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/about">
#                 О нас
#               </a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/difficult" target="_blank">
#                 Сложность
#               </a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/adv" target="_blank">
#                 Рекламодателям
#               </a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/blog/2022/04/01/samotek" target="_blank">
#                 Авторам
#               </a>
# </div>
# <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=946">Игры</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=869">Физика</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=874">Зоология</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=880">Астрономия</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=768">Генетика</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=890">Математика</a>
# </div>
# <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=871">Космонавтика</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=876">Археология</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=775">Нейронауки</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=767">На мышах</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=771">Звук</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=772">Красота</a>
# </div>
# <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=778">Научные закрытия</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=917">ИИ спешит на помощь</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=918">Когда рассеется дым</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=824">Книжная полка</a>
# </div>
# </div>
# <div class="py-12 mt-auto border-t border-gray-2 text-18 grid grid-cols-12 gap-x-5 md:gap-x-9">
# <ul class="flex gap-2.5">
# <li>
# <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_tg"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_vk"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_ok"></use>
# </svg>
# </a>
# </li>
# <li class="w-12">
# <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_tw"></use>
# </svg>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <nav :style="stylesNavMobile" class="relative bg-white max-h-0 n1_top_nav overflow-hidden" id="mobNavMenu" v-if="isOpenMobileMenu">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto h-full flex flex-col overflow-y-auto">
# <div class="text-30 font-spectral flex flex-col gap-y-5 mb-10 mt-10">
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/about">О нас</a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/difficult" target="_blank">Сложность</a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/adv" target="_blank">Рекламодателям</a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/news/2015/09/21/editor-thy-name" target="_blank">Вакансии</a>
# </div>
# <div class="text-28 text-main flex flex-col gap-y-2.5 mb-10">
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=946">Игры
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=869">Физика
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=874">Зоология
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=880">Астрономия
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=768">Генетика
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=890">Математика
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=871">Космонавтика
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=876">Археология
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=775">Нейронауки
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=767">На мышах
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=771">Звук
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=772">Красота
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=778">Научные закрытия
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=917">ИИ спешит на помощь
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=918">Когда рассеется дым
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=824">Книжная полка
#           </a>
# </div>
# <div class="max-w-full flex py-5 border-t border-gray-2">
# <div class="flex gap-x-5 overflow-x-auto">
# <a class="hover:text-main whitespace-nowrap" href="https://offline.nplus1.ru/">N + offline</a>
# <a class="hover:text-main whitespace-nowrap" href="https://nplus.pro/">N + production</a>
# </div>
# </div>
# <div class="pt-5 pb-10 border-t border-gray-2 text-18">
# <ul class="flex gap-2.5">
# <li>
# <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
# <svg class="w-10 h-10">
# <use xlink:href="#n1_tg"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
# <svg class="w-10 h-10">
# <use xlink:href="#n1_vk"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
# <svg class="w-10 h-10">
# <use xlink:href="#n1_ok"></use>
# </svg>
# </a>
# </li>
# <li class="w-12">
# <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
# <svg class="w-10 h-10">
# <use xlink:href="#n1_tw"></use>
# </svg>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# </header>
# <app-heading-nav></app-heading-nav>
# <section class="mb-15 md:mb-20">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto grid grid-cols-6 md:grid-cols-12 gap-x-5 md:gap-x-7.5 relative overflow-hidden" data-heading-wrap="">
# <!--tags-->
# <div class="flex-wrap col-span-6 md:col-span-12 lg:col-span-2 mt-5 -mb-2.5 lg:-mb-0 lg:mt-10 content-start mr-9">
# <div class="flex flex-wrap lg:mb-10 gap-2 text-tags xl:pr-9">
# <span class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center">
# <span class="group-hover:text-main transition-colors duration-75">09:56</span>
# </span>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/news/2023/12/15">
# <span class="group-hover:text-main transition-colors duration-75">15.12.23</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/material/difficulty/3">
# <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="group-hover:text-main transition-colors duration-75">3.2</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="https://nplus1.ru/search?tags=876">
# <span class="group-hover:text-main transition-colors duration-75">Археология</span>
# </a>
# </div>
# <div class="hidden lg:flex items-center gap-x-2">
# <a class="group" href="https://nplus1.ru/material-print/67046" target="_blank">
# <svg class="group-hover:text-main transition-colors duration-75 stroke-current" fill="none" height="30" viewbox="0 0 22 30" width="22" xmlns="http://www.w3.org/2000/svg">
# <rect height="29" width="21" x="0.5" y="0.5"></rect>
# <line x1="4" x2="18" y1="7.5" y2="7.5"></line>
# <line x1="4" x2="18" y1="21.5" y2="21.5"></line>
# <line x1="4" x2="18" y1="14.5" y2="14.5"></line>
# </svg>
# </a>
# <app-copy-material link="https://nplus1.ru/news/2023/12/15/human-skin" type="full-2"></app-copy-material>
# </div>
# <div class="w-full flex flex-col mt-5">
# </div>
# </div>
# <!--dotes menu mobile-->
# <template v-if="isMobile">
# <button class="absolute flex right-5 top-5 z-30 text-main-black">
# <svg class="fill-current" fill="none" height="30" viewbox="0 0 30 30" width="30" xmlns="http://www.w3.org/2000/svg">
# <path clip-rule="evenodd" d="M17 6C17 6.55228 16.5523 7 16 7H15C14.4477 7 14 6.55228 14 6V5C14 4.44772 14.4477 4 15 4H16C16.5523 4 17 4.44772 17 5V6ZM17 23C17 23.5523 16.5523 24 16 24H15C14.4477 24 14 23.5523 14 23V22C14 21.4477 14.4477 21 15 21H16C16.5523 21 17 21.4477 17 22V23ZM14 14.5C14 15.0523 14.4477 15.5 15 15.5H16C16.5523 15.5 17 15.0523 17 14.5V13.5C17 12.9477 16.5523 12.5 16 12.5H15C14.4477 12.5 14 12.9477 14 13.5V14.5Z" fill-rule="evenodd"></path>
# </svg>
# </button>
# <div :class="{
#            'transition-transform flex items-center gap-x-7.5 absolute top-0 right-0 w-full px-6 md:px-8 h-20 bg-white z-30 justify-end bg-light-gray':true,
#            '-translate-x-full': !isOpenMobileDotsMenu,
#            '-translate-x-0': isOpenMobileDotsMenu
#            }" ref="mobileDotsMenuRef">
# <app-copy-material link="https://nplus1.ru/news/2023/12/15/human-skin" type="mobile"></app-copy-material>
# <button aria-label="Go" class="group">
# <svg class="group-focus:text-main transition-colors duration-75 stroke-current" fill="none" height="40" viewbox="0 0 30 40" width="30" xmlns="http://www.w3.org/2000/svg">
# <path d="M14.3303 26.2967L0.5 38.8697V0.5H28.8333V38.8697L15.003 26.2967L14.6667 25.9909L14.3303 26.2967Z"></path>
# </svg>
# </button>
# <button aria-label="Go" class="group">
# <svg class="group-focus:text-main transition-colors duration-75 stroke-current" fill="none" height="40" viewbox="0 0 30 40" width="30" xmlns="http://www.w3.org/2000/svg">
# <rect height="39" width="28.3333" x="0.833984" y="0.5"></rect>
# <line x1="5.66732" x2="24.334" y1="10.1665" y2="10.1665"></line>
# <line x1="5.66732" x2="24.334" y1="28.8335" y2="28.8335"></line>
# <line x1="5.66732" x2="24.334" y1="19.5" y2="19.5"></line>
# </svg>
# </button>
# </div>
# </template>
# <!-- main image -->
# <!--main-->
# <div class="col-span-6 md:col-span-8 lg:col-span-7 lg:col-start-3 row-span-2 lg:border-l lg:border-gray-200 xl:-ml-9 lg:pl-9 mt-10">
# <div class="flex flex-col">
# <h1 class="text-34 md:text-42 xl:text-52 break-words">
#             У скифов нашли изделия из человеческой кожи
#           </h1>
# <p class="text-36 md:text-44 xl:text-54 font-spectral text-main-gray mb-6">По данным Геродота, они снимали ее с мертвых врагов</p>
# <div class="text-14 mb-5 sm:mb-12 flex flex-wrap">
# <span class="whitespace-nowrap">
# <a class="underline" href="/author/mixail-podrezov">Михаил Подрезов</a>
# </span>
# </div>
# <div class="mb-14" data-lmb-0="">
# <basegallerymain :gid="68706"></basegallerymain>
# <div></div>
# <div class="n1_material text-18"><p class="mb-6">Группа ученых исследовала 45 фрагментов кожаных изделий и 2 кусочка меха, которые нашли в 18 скифских погребениях. Масс-спектрометрическая пептидная дактилоскопия показала, что в основном для производства вещей древние кочевники использовали кожу овец и коз. Однако в двух случаях материал, по всей видимости, представлял собой человеческую кожу. Как <a href="https://doi.org/10.1371/journal.pone.0294129" rel="noreferrer noopener" target="_blank">сообщается</a> в статье, опубликованной в журнале <em>PLoS One</em>, эти данные подтверждают рассказ Геродота, что скифы снимали кожу с мертвых врагов и делали из нее вещи.</p></div>
# <div class="block md:hidden col-span-6 mb-6">
# <div class="w-full" data-ref-sidebar=""></div>
# <a href="https://www.sberbank.com/promo/sberscienceaward#broadcast?utm_source=nplus1&amp;utm_medium=fix&amp;utm_campaign=sberscienceaward_specialproject_person_sp_dec-2023" target="_blank">
# <picture>
# <source media="(min-width: 768px)" srcset="https://nplus1.ru/images-new/material-banner-1-desktop.png">
# <img alt="Итоги научной премии Сбера 2023." class="w-full" loading="lazy" src="https://nplus1.ru/images-new/material-banner-1-mobile.png"/>
# </source></picture>
# </a>
# </div>
# <div class="n1_material text-18"><p class="mb-6">Скифы — ираноязычные кочевники, которые в I тысячелетии до нашей эры на протяжении нескольких столетий доминировали в степной зоне от Дуная до Дона. Эти люди хорошо известны не только по археологическим данным, но и по письменным источникам. Так, большое количество сведений о скифах содержится у древнегреческого историка Геродота (V век до нашей эры). Среди прочего, он <a href="https://ancientrome.ru/antlitr/t.htm?a=1269004000" rel="noreferrer noopener" target="_blank">рассказывал</a> о военных обычаях этих кочевников. Например, о том, что скифы снимали кожу с головы убитых врагов, выделывали ее, а затем пользовались ей как полотенцами для рук. Также он писал, что некоторые скифы шили из кожи врагов плащи, а другие сдирали кожу вместе с ногтями с рук и делали из этого материала футляры для колчанов — гориты. Разумеется, далеко не всем сведениям Геродота можно доверять без опоры на другие независимые источники информации.</p></div>
# <basegallerymain :gid="68707"></basegallerymain>
# <div></div>
# <div class="n1_material text-18"><p class="mb-6">Во многих скифских курганах археологи находили фрагменты кожаных изделий, однако часто определить, из какого сырья они были сделаны, не получалось. На этот раз группа ученых из Великобритании, Дании, Италии и Украины во главе с Маргаритой Глеба (Margarita Gleba) из Падуанского университета решила восполнить этот пробел с помощью масс-спектрометрической пептидной дактилоскопии (ZooMS), которую в последние годы ученые все активнее стали использовать при работе с неинформативными останками древних животных, включая людей. Например, с его помощью в Денисовой пещере<a href="https://nplus1.ru/news/2018/08/22/the-direct-offspring" rel="noreferrer noopener" target="_blank"> идентифицировали</a> кость Денни — единственного известного гибрида между денисовцем и неандертальцем, а также <a href="https://nplus1.ru/news/2021/11/25/denisovans" rel="noreferrer noopener" target="_blank">нашли</a> несколько фрагментов костей других архаичных гоминин.</p></div>
# <div class="n1_material text-18"><p class="mb-6">Для новых исследований ученые отобрали 45 образцов кожи из 13 скифских курганов, раскопанных на Украине, которые в основном датируются IV веком до нашей эры. Один из этих образцов, а также два фрагмента меха они изучили и с помощью метода жидкостной хроматографии и тандемной масс-спектрометрии. Тем самым количество представленных памятников в этом исследовании суммарно составило 14 штук, а раскопанных в них погребений — 18.</p></div>
# <div class="n1_material text-18"><p class="mb-6">С помощью ZooMS ученые определили 33 из 45 образцов на уровне от вида до семейства. Большинство из них представляли собой кожу домашних животных — коз и овец. Удалось определить как минимум один образец коровьей кожи и два лошадиной. Три образца выделялись на фоне других. Один из них принадлежал лисице, второй — тигру, льву, кунице, росомахе, выдре или гиене, а третий — человеку. Еще три образца, изученных с помощью метода жидкостной хроматографии и тандемной масс-спектрометрии, также показали интересный результат. Два фрагмента меха принадлежали представителям семейств беличьих (вероятно, обыкновенной белке) и кошачьих. А кусочек кожи — гоминину, то есть, скорее всего, человеку.</p></div>
# <div class="n1_material text-18"><p class="mb-6">Среди полученных результатов ученых больше всего заинтересовали образцы человеческой кожи, которые происходили из памятников Ильинка и Булгаково. По мнению исследователей, эти находки подтверждают рассказы Геродота о том, как скифские воины поступали с телами мертвых врагов. Оба кусочка человеческой кожи, по всей видимости, представляли собой остатки колчанов, при изготовлении которых кожа людей использовалась вместе с кожей других животных. Ранее подобные изделия у ранних кочевников <a href="https://archeology-rb.ru/index.php/nashi-publikatsii/57-stati/142-fedorov-vk-gorshkovave-kolchan-iz-chelovecheskoj-kozhi-v-pogrebenii-rannego-kochevnika-iz-bashkirskogo-zauralya">обнаруживали</a> лишь однажды, когда изучали материалы из погребения, раскопанного в Башкирском Зауралье.</p></div>
# <div class="n1_material text-18"><p class="mb-6">В скифских погребениях, раскопанных у села Булгаково, сохранились и другие изделия из органических материалов, а также ценные вещи. Например, ранее мы рассказывали, что в одном из них исследователи, среди прочего, <a href="https://nplus1.ru/news/2022/10/15/scythians" rel="noreferrer noopener" target="_blank">нашли</a> колчан со стрелами, копье, греческие сосуды, драгоценные украшения и бронзовый котел.</p></div>
# </div>
# <div class="text-18">
# <app-tags-carousel>
# <template v-slot:default="slotProps">
# <a :class="slotProps.classesTag" href="https://nplus1.ru/search?tags=876">Археология</a>
# </template>
# </app-tags-carousel>
# <div class="text-20 font-spectral text-main-gray leading-none" v-if="!isMobile">
#               Нашли опечатку? Выделите фрагмент и нажмите Ctrl+Enter.
#             </div>
# </div>
# </div>
# </div>
# <!--right sidebar-->
# <div class="block col-span-6 md:col-span-4 lg:col-span-3 mt-10">
# <div class="w-full" data-ref-sidebar=""></div>
# <a class="hidden md:block" href="https://www.sberbank.com/promo/sberscienceaward#broadcast?utm_source=nplus1&amp;utm_medium=fix&amp;utm_campaign=sberscienceaward_specialproject_person_sp_dec-2023" target="_blank">
# <picture>
# <source media="(min-width: 768px)" srcset="https://nplus1.ru/images-new/material-banner-1-desktop.png">
# <img alt="Итоги научной премии Сбера 2023." class="w-full" loading="lazy" src="https://nplus1.ru/images-new/material-banner-1-mobile.png"/>
# </source></picture>
# </a>
# <!-- ba2 -->
# <!--AdFox START-->
# <!--nplus1_dir-->
# <!--Площадка: https://nplus1.ru/ / * / *-->
# <!--Тип баннера: CLICKIO html5-->
# <!--Расположение: <верх страницы>-->
# <div class="bg-gray-100 mt-2 py-4 w-full" id="adfox_153934342663011746"></div>
# <!--
#         <a class="text-14 leading-21 group" href="#">
#           <p>
#             Human mobility at Tell Atchana (Alalakh), Hatay, Turkey during the 2nd millennium BC: Integration of
#             isotopic and genomic evidence
#           </p>
#           <div class="group-hover:text-main inline-flex items-center font-spectral text-main-gray">
#             <p class="mr-1">PLOS ONE, 30.06.2021</p>
#             <svg class="fill-current" width="11" height="11" viewBox="0 0 11 11" xmlns="http://www.w3.org/2000/svg">
#               <path d="M10.0738 5.87L5.08775 0.901999L4.15175 1.838L7.51775 5.204H0.19175V6.536H7.51775L4.15175 9.902L5.08775 10.838L10.0738 5.87Z"
#                     fill="currentColor"></path>
#             </svg>
#           </div>
#         </a>
#         -->
# </div>
# </div>
# </section>
# <section class="mb-15 md:mb-20">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto grid grid-cols-6 md:grid-cols-12 gap-x-5 md:gap-x-9">
# <!--tags-->
# <div class="flex-wrap col-span-6 md:col-span-12 lg:col-span-2 -mb-2.5 lg:-mb-0 content-start">
# <div class="flex flex-wrap lg:mb-10 gap-2 text-tags xl:pr-9">
# <span class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center">
# <span class="group-hover:text-main transition-colors duration-75">11:29</span>
# </span>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/news/2023/11/07">
# <span class="group-hover:text-main transition-colors duration-75">07.11.23</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/material/difficulty/3">
# <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="group-hover:text-main transition-colors duration-75">3.3</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="https://nplus1.ru/search?tags=876">
# <span class="group-hover:text-main transition-colors duration-75">Археология</span>
# </a>
# </div>
# <div class="hidden lg:flex items-center gap-x-2">
# <a aria-label="Go" class="group" href="https://nplus1.ru/material-print/66670">
# <svg class="group-hover:text-main transition-colors duration-75 stroke-current" fill="none" height="30" viewbox="0 0 22 30" width="22" xmlns="http://www.w3.org/2000/svg">
# <rect height="29" width="21" x="0.5" y="0.5"></rect>
# <line x1="4" x2="18" y1="7.5" y2="7.5"></line>
# <line x1="4" x2="18" y1="21.5" y2="21.5"></line>
# <line x1="4" x2="18" y1="14.5" y2="14.5"></line>
# </svg>
# </a>
# <app-copy-material link="https://nplus1.ru/news/2023/11/07/kara-bom" type="full-2"></app-copy-material>
# </div>
# </div>
# <!--main image  -->
# <!--main-->
# <div class="col-span-6 md:col-span-8 lg:col-span-7 lg:col-start-3 row-span-2 lg:border-l lg:border-gray-200 xl:-ml-9 lg:pl-9 mt-10 lg:mt-0">
# <div class="flex flex-col">
# <div class="text-34 md:text-42 xl:text-52 break-words">
#           Орудиям эпохи верхнего палеолита из алтайской стоянки оказалось больше 45,5 тысячи лет
#         </div>
# <p class="text-36 md:text-44 xl:text-54 font-spectral text-main-gray mb-6">Исследовали датировали находки из памятника Кара-Бом</p>
# <div class="text-14 pt-4 sm:pt-6 mb-10 sm:mb-12 flex flex-wrap">
# <a class="underline whitespace-nowrap" href="/author/mixail-podrezov">Михаил Подрезов</a>
# </div>
# <div class="n1_material text-18" id="read-next-2">
# <p class="mb-6">Группа австрийских и российских ученых провела радиоуглеродный анализ находок из памятника Кара-Бом, который находится на Алтае. Они пришли к выводу, что характерные для начального этапа верхнего палеолита каменные орудия появились здесь между 49,2 и 45,5 тысячи лет назад. Обычно эти артефакты отражают время прихода в регион людей современного анатомического типа (Homo sapiens). Результаты исследования опубликованы в Journal of Human Evolution.</p>
# </div>
# <div class="mt-5 md:mt-6">
# <a class="inline-flex justify-center bg-main w-full py-4" href="https://nplus1.ru/news/2023/11/07/kara-bom">
# <span class="text-white text-22 md:text-24">Читать дальше</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="mb-15 md:mb-20">
# <div class="bg-gray-100 w-full" id="adfox_154408219501673625"></div>
# </section>
# <div class="mb-1 w-full overflow-hidden">
# <app-material-slider-carousel :const-container="constContainer" :const-start-container="constStartContainer">
# <template v-slot:default="slotProps">
# <div :style="{'width': constWidthHorizontalsCard + 'px',
#                                'padding-left': slotProps.left + 'px'
#                               }" class="absolute left-0 mr-1 box-content">
# <div class="relative w-full flex relative w-full flex shrink-0 h-72 xl:h-88">
# <div class="shrink-0 absolute inset-0 group bg-main">
# <picture>
# <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/864719/656ee358952a9_hl_cover_v.jpg">
# <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/864720/656ee358e666d_hl_cover_h.jpg">
# <img alt="Американский изобретатель запатентовал автоматическую велосипедную трансмиссию" class="w-full h-full object-cover absolute inset-0 brightness-50" loading="lazy" src="https://minio.nplus1.ru/app-images/864720/656ee358e666d_hl_cover_h.jpg"/>
# </source></source></picture>
# </div>
# <div class="flex flex-col pb-10 sm:pb-5 text-22 sm:text-20">
# <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags text-white absolute top-0 inset-x-5">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/news/2023/12/05">
# <span class="group-hover:text-main transition-colors duration-75">05.12.23</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=887">
# <span class="group-hover:text-main transition-colors duration-75">
#             Транспорт
#             </span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/difficulty/1">
# <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="group-hover:text-main transition-colors duration-75">
#           1.7
#         </span>
# </a>
# </div>
# <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group" href="https://nplus1.ru/news/2023/12/05/automatic-transmission-for-bicycle-haven-mercer">
# <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light transition-colors duration-75 group-hover:text-main">
#           Американский изобретатель запатентовал автоматическую велосипедную трансмиссию</p>
# <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#             Диаметры ведущей и ведомой звезд меняются в зависимости от усилия на педалях</p>
# </a>
# </div>
# </div>
# </div>
# <div :style="{'width': constWidthHorizontalsCard + 'px',
#                               }" class="absolute left-0 mr-1 box-content">
# <div class="relative w-full flex relative w-full flex shrink-0 h-72 xl:h-88">
# <div class="shrink-0 absolute inset-0 group bg-main">
# <picture>
# <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/852724/f66729bd5e20de2b00a199854dc8a0bf.png">
# <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/852723/3ce7ccc237107ec580bd288f45bf9b1e.png">
# <img alt="Долой сомжу!" class="w-full h-full object-cover absolute inset-0 brightness-50" loading="lazy" src="https://minio.nplus1.ru/app-images/852723/3ce7ccc237107ec580bd288f45bf9b1e.png"/>
# </source></source></picture>
# </div>
# <div class="flex flex-col pb-10 sm:pb-5 text-22 sm:text-20">
# <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags text-white absolute top-0 inset-x-5">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/2023/11/10">
# <span class="group-hover:text-main transition-colors duration-75">10.11.23</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=946">
# <span class="group-hover:text-main transition-colors duration-75">
#             Игры
#             </span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/difficulty/4">
# <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="group-hover:text-main transition-colors duration-75">
#           4.2
#         </span>
# </a>
# </div>
# <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group" href="https://nplus1.ru/material/2023/11/10/dialectological-test">
# <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light transition-colors duration-75 group-hover:text-main">
#           Долой сомжу!</p>
# <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#             Сложный тест о редких диалектизмах русского языка</p>
# </a>
# </div>
# </div>
# </div>
# <div :style="{'width': constWidthHorizontalsCard + 'px',
#                               }" class="absolute left-0 mr-1 box-content">
# <div class="relative w-full flex relative w-full flex shrink-0 h-72 xl:h-88">
# <div class="shrink-0 absolute inset-0 group bg-main">
# <picture>
# <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/823282/ff280af454a350a11ba4e59e9fd5b843.png">
# <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/823278/64e496996b541_hl_cover_h.png">
# <img alt="Арктика или Антарктика" class="w-full h-full object-cover absolute inset-0 brightness-50" loading="lazy" src="https://minio.nplus1.ru/app-images/823278/64e496996b541_hl_cover_h.png"/>
# </source></source></picture>
# </div>
# <div class="flex flex-col pb-10 sm:pb-5 text-22 sm:text-20">
# <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags text-white absolute top-0 inset-x-5">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/2023/08/21">
# <span class="group-hover:text-main transition-colors duration-75">21.08.23</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=946">
# <span class="group-hover:text-main transition-colors duration-75">
#             Игры
#             </span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/difficulty/3">
# <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="group-hover:text-main transition-colors duration-75">
#           3.1
#         </span>
# </a>
# </div>
# <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group" href="https://nplus1.ru/material/2023/08/21/arctic-or-antarctic">
# <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light transition-colors duration-75 group-hover:text-main">
#           Арктика или Антарктика</p>
# <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#             Быстрый тест на знание полюсов Земли</p>
# </a>
# </div>
# </div>
# </div>
# <div :style="{'width': constWidthHorizontalsCard + 'px',
#                               }" class="absolute left-0 mr-1 box-content">
# <div class="relative w-full flex relative w-full flex shrink-0 h-72 xl:h-88">
# <div class="shrink-0 absolute inset-0 group bg-main">
# <picture>
# <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/829958/710abd0564efdbde2e91677dd766a5ea.png">
# <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/829957/4171220f8e3c0d73c54d2a0844ce95b7.png">
# <img alt="Через линии к звездам" class="w-full h-full object-cover absolute inset-0 brightness-50" loading="lazy" src="https://minio.nplus1.ru/app-images/829957/4171220f8e3c0d73c54d2a0844ce95b7.png"/>
# </source></source></picture>
# </div>
# <div class="flex flex-col pb-10 sm:pb-5 text-22 sm:text-20">
# <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags text-white absolute top-0 inset-x-5">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/2023/09/06">
# <span class="group-hover:text-main transition-colors duration-75">06.09.23</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=946">
# <span class="group-hover:text-main transition-colors duration-75">
#             Игры
#             </span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/difficulty/2">
# <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="group-hover:text-main transition-colors duration-75">
#           2.6
#         </span>
# </a>
# </div>
# <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group" href="https://nplus1.ru/material/2023/09/06/draw-a-constellation">
# <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light transition-colors duration-75 group-hover:text-main">
#           Через линии к звездам</p>
# <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#             Попробуйте нарисовать популярные созвездия</p>
# </a>
# </div>
# </div>
# </div>
# <div :style="{'width': constWidthHorizontalsCard + 'px',
#                               }" class="absolute left-0 mr-1 box-content">
# <div class="relative w-full flex relative w-full flex shrink-0 h-72 xl:h-88">
# <div class="shrink-0 absolute inset-0 group bg-main">
# <picture>
# <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/830937/a212ba9b14a560f61e2ea8f43bf0d72a.png">
# <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/830936/4b99120efacc79291cbb61382d956626.png">
# <img alt="Кто вымер раньше" class="w-full h-full object-cover absolute inset-0 brightness-50" loading="lazy" src="https://minio.nplus1.ru/app-images/830936/4b99120efacc79291cbb61382d956626.png"/>
# </source></source></picture>
# </div>
# <div class="flex flex-col pb-10 sm:pb-5 text-22 sm:text-20">
# <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags text-white absolute top-0 inset-x-5">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/2023/09/22">
# <span class="group-hover:text-main transition-colors duration-75">22.09.23</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=946">
# <span class="group-hover:text-main transition-colors duration-75">
#             Игры
#             </span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/difficulty/2">
# <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="group-hover:text-main transition-colors duration-75">
#           2.7
#         </span>
# </a>
# </div>
# <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group" href="https://nplus1.ru/material/2023/09/22/who-died-out-first">
# <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light transition-colors duration-75 group-hover:text-main">
#           Кто вымер раньше</p>
# <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#             Игра о тех, кого больше нет с нами</p>
# </a>
# </div>
# </div>
# </div>
# <div :style="{'width': constWidthHorizontalsCard + 'px',
#                               }" class="absolute left-0 mr-1 box-content">
# <div class="relative w-full flex relative w-full flex shrink-0 h-72 xl:h-88">
# <div class="shrink-0 absolute inset-0 group bg-main">
# <picture>
# <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/852763/d7d2122d442e9946aef71670406dd99e.png">
# <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/852762/8ac4fdc146dc695ccbe05e6a2c8ef962.png">
# <img alt="Любовь или симбиоз" class="w-full h-full object-cover absolute inset-0 brightness-50" loading="lazy" src="https://minio.nplus1.ru/app-images/852762/8ac4fdc146dc695ccbe05e6a2c8ef962.png"/>
# </source></source></picture>
# </div>
# <div class="flex flex-col pb-10 sm:pb-5 text-22 sm:text-20">
# <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags text-white absolute top-0 inset-x-5">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/2023/11/17">
# <span class="group-hover:text-main transition-colors duration-75">17.11.23</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=946">
# <span class="group-hover:text-main transition-colors duration-75">
#             Игры
#             </span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/difficulty/3">
# <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="group-hover:text-main transition-colors duration-75">
#           3.5
#         </span>
# </a>
# </div>
# <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group" href="https://nplus1.ru/material/2023/11/17/love-or-symbiosis">
# <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light transition-colors duration-75 group-hover:text-main">
#           Любовь или симбиоз</p>
# <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#             Отличите природную зависимость от сюжета фильма или книги</p>
# </a>
# </div>
# </div>
# </div>
# <div :style="{'width': constWidthHorizontalsCard + 'px',
#                               }" class="absolute left-0 mr-1 box-content">
# <div class="relative w-full flex relative w-full flex shrink-0 h-72 xl:h-88">
# <div class="shrink-0 absolute inset-0 group bg-main">
# <picture>
# <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/853069/9b45ff6b1e6b1c3d40701900039101f5.jpg">
# <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/853068/2fa35380abfec6c79841b9a71a9a1de6.jpg">
# <img alt="Первая помощь" class="w-full h-full object-cover absolute inset-0 brightness-50" loading="lazy" src="https://minio.nplus1.ru/app-images/853068/2fa35380abfec6c79841b9a71a9a1de6.jpg"/>
# </source></source></picture>
# </div>
# <div class="flex flex-col pb-10 sm:pb-5 text-22 sm:text-20">
# <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags text-white absolute top-0 inset-x-5">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/2023/11/10">
# <span class="group-hover:text-main transition-colors duration-75">10.11.23</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=946">
# <span class="group-hover:text-main transition-colors duration-75">
# ...
# <ul class="flex gap-3 text-gray-2">
# <li>
# <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_tg"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_vk"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_ok"></use>
# </svg>
# </a>
# </li>
# <li class="w-12">
# <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_tw"></use>
# </svg>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </footer>
# </div>
# <svg class="stroke-current" fill="none" height="16" id="n1_star" style="display:block;width:0;height:0" viewbox="3 3 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
# <path d="M11 5V17"></path>
# <path d="M6.75781 6.75781L15.2431 15.2431"></path>
# <path d="M17 11L5 11"></path>
# <path d="M15.2422 6.75781L6.75691 15.2431"></path>
# </svg>
# <svg class="stroke-current" fill="none" id="n1_person" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <circle cx="25" cy="25" r="24.5"></circle>
# <path d="M30.1897 30.3212C28.9483 29.9852 27.5345 29.7164 27.5345 28.5067C27.5345 27.8347 27.5 27.0618 28.2931 26.625C31.0172 25.0457 32.5 22.3911 32.1552 18.2581C31.8103 14.0578 29.2586 11 24.9828 11C20.7069 11 18.1552 14.0578 17.8103 18.2581C17.4655 22.3911 18.9138 25.0457 21.6724 26.625C22.4655 27.0618 22.431 27.8347 22.431 28.5067C22.431 29.7164 21.0172 29.9516 19.8103 30.3212C17.3966 30.9933 12.5 31.9005 12.5 36C16.431 36 33.569 36 37.5 36C37.4655 31.9005 32.6034 30.9933 30.1897 30.3212Z" stroke-miterlimit="10"></path>
# </svg>
# <svg fill="none" id="n1_tg" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" d="M16.3181 21.32H19.4961V30H20.7141V21.32H23.8921V20.2H16.3181V21.32ZM28.6969 30.084C30.3769 30.084 31.4269 29.286 31.8749 28.572L31.9589 30H33.0089V24.694H28.8789V25.814H31.8189V26.15C31.8189 27.886 30.5169 28.964 28.7109 28.964C26.6809 28.964 25.3369 27.368 25.3369 25.1C25.3369 22.832 26.6809 21.236 28.7389 21.236C30.2229 21.236 31.2729 22.034 31.6089 23.392H32.9109C32.5749 21.376 30.9369 20.116 28.7669 20.116C25.9249 20.116 24.0909 22.132 24.0909 25.1C24.0909 28.068 25.9809 30.084 28.6969 30.084Z"></path>
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# </svg>
# <svg fill="none" id="n1_vk" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" d="M19.8015 30H21.2715L24.7995 20.2H23.5395L20.5575 28.558L17.5615 20.2H16.2735L19.8015 30ZM25.8768 30H27.0948V27.452L29.0408 25.254L32.3448 30H33.8008L29.9368 24.33L33.5208 20.2H32.0368L27.0948 25.758V20.2H25.8768V30Z"></path>
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# </svg>
# <svg fill="none" id="n1_ok" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" d="M25.2125 25.1C25.2125 22.216 23.2945 20.116 20.5365 20.116C17.7785 20.116 15.8605 22.216 15.8605 25.1C15.8605 27.984 17.7785 30.084 20.5365 30.084C23.2945 30.084 25.2125 27.984 25.2125 25.1ZM17.1065 25.1C17.1065 22.846 18.4925 21.236 20.5365 21.236C22.5805 21.236 23.9665 22.846 23.9665 25.1C23.9665 27.354 22.5805 28.964 20.5365 28.964C18.4925 28.964 17.1065 27.354 17.1065 25.1ZM26.7518 30H27.9698V27.452L29.9158 25.254L33.2198 30H34.6758L30.8118 24.33L34.3958 20.2H32.9118L27.9698 25.758V20.2H26.7518V30Z"></path>
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# </svg>
# <svg fill="none" id="n1_tw" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" d="M14.4792 21.32H17.6572V30H18.8752V21.32H22.0532V20.2H14.4792V21.32ZM25.332 30H26.788L29.014 22.23L31.254 30H32.71L35.58 20.2H34.32L32.01 28.432L29.686 20.2H28.454L26.046 28.432L23.75 20.2H22.476L25.332 30Z"></path>
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# </svg>
# <svg height="64px" id="n1_infinity" preserveaspectratio="xMidYMid" style="display:block;width:0;height:0" viewbox="0 0 100 100" width="64px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <path d="M24.3 30C11.4 30 5 43.3 5 50s6.4 20 19.3 20c19.3 0 32.1-40 51.4-40 C88.6 30 95 43.3 95 50s-6.4 20-19.3 20C56.4 70 43.6 30 24.3 30z" fill="none" stroke="#ffffff" stroke-dasharray="146.25568908691406 110.33323913574219" stroke-linecap="round" stroke-width="5" style="transform:scale(0.8);transform-origin:50px 50px">
# <animate attributename="stroke-dashoffset" dur="1.3157894736842106s" keytimes="0;1" repeatcount="indefinite" values="0;256.58892822265625"></animate>
# </path>
# </svg>
# <svg fill="none" id="n1_cross" style="display:block;width:0;height:0" viewbox="0 0 14 14" xmlns="http://www.w3.org/2000/svg">
# <path d="M1.00146 1L13.0015 13" stroke="#F9F9F9"></path>
# <path d="M13 1L1 13" stroke="#F9F9F9"></path>
# </svg>
# <svg id="n1_link_arrow" style="display:block;width:0;height:0" viewbox="0 0 11 11" xmlns="http://www.w3.org/2000/svg">
# <path d="M10.0738 5.87L5.08775 0.901999L4.15175 1.838L7.51775 5.204H0.19175V6.536H7.51775L4.15175 9.902L5.08775 10.838L10.0738 5.87Z" fill="currentColor"></path>
# </svg>
# <svg id="n1_big_star" style="display:block;width:0;height:0;" viewbox="0 0 61 61" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" clip-rule="evenodd" d="M3 29.7729H29.0656L10.6345 11.3418L11.3416 10.6347L29.7728 29.0658V3H30.7728V29.0658L49.2039 10.6347L49.911 11.3418L31.4799 29.7729H57.5455V30.7729H31.4799L49.9111 49.2042L49.204 49.9113L30.7728 31.4801V57.5455H29.7728V31.4801L11.3415 49.9113L10.6344 49.2042L29.0656 30.7729H3V29.7729Z" fill-rule="evenodd"></path>
# <path class="fill-current" d="M29.0656 29.7729V32.2729H35.1012L30.8334 28.0052L29.0656 29.7729ZM3 29.7729V27.2729H0.5V29.7729H3ZM10.6345 11.3418L8.86676 9.57407L7.099 11.3418L8.86676 13.1096L10.6345 11.3418ZM11.3416 10.6347L13.1094 8.86696L11.3416 7.09919L9.57387 8.86696L11.3416 10.6347ZM29.7728 29.0658L28.005 30.8336L32.2728 35.1014V29.0658H29.7728ZM29.7728 3V0.5H27.2728V3H29.7728ZM30.7728 3H33.2728V0.5H30.7728V3ZM30.7728 29.0658H28.2728V35.1014L32.5405 30.8336L30.7728 29.0658ZM49.2039 10.6347L50.9716 8.86696L49.2039 7.09919L47.4361 8.86696L49.2039 10.6347ZM49.911 11.3418L51.6787 13.1096L53.4465 11.3418L51.6787 9.57407L49.911 11.3418ZM31.4799 29.7729L29.7121 28.0052L25.4443 32.2729H31.4799V29.7729ZM57.5455 29.7729H60.0455V27.2729H57.5455V29.7729ZM57.5455 30.7729V33.2729H60.0455V30.7729H57.5455ZM31.4799 30.7729V28.2729H25.4443L29.7121 32.5407L31.4799 30.7729ZM49.9111 49.2042L51.6789 50.972L53.4466 49.2042L51.6789 47.4364L49.9111 49.2042ZM49.204 49.9113L47.4362 51.6791L49.204 53.4468L50.9718 51.6791L49.204 49.9113ZM30.7728 31.4801L32.5405 29.7123L28.2728 25.4445V31.4801H30.7728ZM30.7728 57.5455V60.0455H33.2728V57.5455H30.7728ZM29.7728 57.5455H27.2728V60.0455H29.7728V57.5455ZM29.7728 31.4801H32.2728V25.4445L28.005 29.7123L29.7728 31.4801ZM11.3415 49.9113L9.57374 51.6791L11.3415 53.4468L13.1093 51.6791L11.3415 49.9113ZM10.6344 49.2042L8.86664 47.4364L7.09887 49.2042L8.86664 50.972L10.6344 49.2042ZM29.0656 30.7729L30.8334 32.5407L35.1012 28.2729H29.0656V30.7729ZM3 30.7729H0.5V33.2729H3V30.7729ZM29.0656 27.2729H3V32.2729H29.0656V27.2729ZM8.86676 13.1096L27.2979 31.5407L30.8334 28.0052L12.4023 9.57407L8.86676 13.1096ZM9.57387 8.86696L8.86676 9.57407L12.4023 13.1096L13.1094 12.4025L9.57387 8.86696ZM31.5405 27.2981L13.1094 8.86696L9.57387 12.4025L28.005 30.8336L31.5405 27.2981ZM27.2728 3V29.0658H32.2728V3H27.2728ZM30.7728 0.5H29.7728V5.5H30.7728V0.5ZM33.2728 29.0658V3H28.2728V29.0658H33.2728ZM32.5405 30.8336L50.9716 12.4025L47.4361 8.86696L29.005 27.2981L32.5405 30.8336ZM47.4361 12.4025L48.1432 13.1096L51.6787 9.57407L50.9716 8.86696L47.4361 12.4025ZM48.1432 9.57407L29.7121 28.0052L33.2476 31.5407L51.6787 13.1096L48.1432 9.57407ZM57.5455 27.2729H31.4799V32.2729H57.5455V27.2729ZM60.0455 30.7729V29.7729H55.0455V30.7729H60.0455ZM31.4799 33.2729H57.5455V28.2729H31.4799V33.2729ZM51.6789 47.4364L33.2476 29.0052L29.7121 32.5407L48.1433 50.972L51.6789 47.4364ZM50.9718 51.6791L51.6789 50.972L48.1433 47.4364L47.4362 48.1435L50.9718 51.6791ZM29.005 33.2478L47.4362 51.6791L50.9718 48.1435L32.5405 29.7123L29.005 33.2478ZM33.2728 57.5455V31.4801H28.2728V57.5455H33.2728ZM29.7728 60.0455H30.7728V55.0455H29.7728V60.0455ZM27.2728 31.4801V57.5455H32.2728V31.4801H27.2728ZM28.005 29.7123L9.57374 48.1435L13.1093 51.6791L31.5405 33.2478L28.005 29.7123ZM13.1093 48.1435L12.4022 47.4364L8.86664 50.972L9.57374 51.6791L13.1093 48.1435ZM12.4022 50.972L30.8334 32.5407L27.2979 29.0052L8.86664 47.4364L12.4022 50.972ZM3 33.2729H29.0656V28.2729H3V33.2729ZM0.5 29.7729V30.7729H5.5V29.7729H0.5Z"></path>
# </svg>
# <svg class="stroke-current" fill="none" id="n1_circle_arrow" style="display:block;width:0;height:0" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
# <rect height="29" rx="14.5" transform="rotate(-180 29.5 29.5)" width="29" x="29.5" y="29.5"></rect>
# <path d="M9.33985 14.7014L14.6198 19.9414L15.2598 19.3014L11.1198 15.1614L20.3398 15.1614L20.3398 14.2214L11.1198 14.2214L15.2598 10.0814L14.6198 9.44141L9.33985 14.7014Z"></path>
# </svg>
# <svg fill="none" id="n1_circle_arrow_solid" style="display:block;width:0;height:0" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
# <mask id="path-1-inside-1_2694_77554">
# <path clip-rule="evenodd" d="M15 0C6.71573 0 0 6.71573 0 15C0 23.2843 6.71573 30 15 30C23.2843 30 30 23.2843 30 15C30 6.71573 23.2843 0 15 0ZM15.3792 10.0601L20.6592 15.3001L15.3792 20.5601L14.7392 19.9201L18.8792 15.7801H9.65918V14.8401H18.8792L14.7392 10.7001L15.3792 10.0601Z" fill-rule="evenodd"></path>
# </mask>
# <path clip-rule="evenodd" d="M15 0C6.71573 0 0 6.71573 0 15C0 23.2843 6.71573 30 15 30C23.2843 30 30 23.2843 30 15C30 6.71573 23.2843 0 15 0ZM15.3792 10.0601L20.6592 15.3001L15.3792 20.5601L14.7392 19.9201L18.8792 15.7801H9.65918V14.8401H18.8792L14.7392 10.7001L15.3792 10.0601Z" fill="#fff" fill-rule="evenodd"></path>
# <path d="M20.6592 15.3001L21.3649 16.0085L22.0774 15.2987L21.3636 14.5903L20.6592 15.3001ZM15.3792 10.0601L16.0836 9.35027L15.3765 8.64853L14.6721 9.35295L15.3792 10.0601ZM15.3792 20.5601L14.6721 21.2672L15.3778 21.9729L16.0849 21.2685L15.3792 20.5601ZM14.7392 19.9201L14.0321 19.213L13.325 19.9201L14.0321 20.6272L14.7392 19.9201ZM18.8792 15.7801L19.5863 16.4872L21.2934 14.7801H18.8792V15.7801ZM9.65918 15.7801H8.65918V16.7801H9.65918V15.7801ZM9.65918 14.8401V13.8401H8.65918V14.8401H9.65918ZM18.8792 14.8401V15.8401H21.2934L19.5863 14.133L18.8792 14.8401ZM14.7392 10.7001L14.0321 9.99295L13.325 10.7001L14.0321 11.4072L14.7392 10.7001ZM1 15C1 7.26801 7.26801 1 15 1V-1C6.16344 -1 -1 6.16344 -1 15H1ZM15 29C7.26801 29 1 22.732 1 15H-1C-1 23.8366 6.16344 31 15 31V29ZM29 15C29 22.732 22.732 29 15 29V31C23.8366 31 31 23.8366 31 15H29ZM15 1C22.732 1 29 7.26801 29 15H31C31 6.16344 23.8366 -1 15 -1V1ZM21.3636 14.5903L16.0836 9.35027L14.6748 10.7698L19.9548 16.0098L21.3636 14.5903ZM16.0849 21.2685L21.3649 16.0085L19.9534 14.5916L14.6734 19.8516L16.0849 21.2685ZM14.0321 20.6272L14.6721 21.2672L16.0863 19.853L15.4463 19.213L14.0321 20.6272ZM18.1721 15.073L14.0321 19.213L15.4463 20.6272L19.5863 16.4872L18.1721 15.073ZM9.65918 16.7801H18.8792V14.7801H9.65918V16.7801ZM8.65918 14.8401V15.7801H10.6592V14.8401H8.65918ZM18.8792 13.8401H9.65918V15.8401H18.8792V13.8401ZM14.0321 11.4072L18.1721 15.5472L19.5863 14.133L15.4463 9.99295L14.0321 11.4072ZM14.6721 9.35295L14.0321 9.99295L15.4463 11.4072L16.0863 10.7672L14.6721 9.35295Z" fill="#fff" mask="url(#path-1-inside-1_2694_77554)"></path>
# </svg>
# <svg fill="none" id="n1_play" style="display:block;width:0;height:0;" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# <path class="stroke-current" d="M18 35V15L36 25L18 35Z"></path>
# </svg>
# <svg fill="none" id="n1_pupa" style="display:block;width:0;height:0;" viewbox="0 0 24 23" xmlns="http://www.w3.org/2000/svg">
# <path clip-rule="evenodd" d="M17 8.80329C17 13.0922 13.4392 16.6066 9 16.6066C4.56077 16.6066 1 13.0922 1 8.80329C1 4.51437 4.56077 1 9 1C13.4392 1 17 4.51437 17 8.80329ZM14.9967 15.3678C13.4049 16.7601 11.3035 17.6066 9 17.6066C4.02944 17.6066 0 13.6652 0 8.80329C0 3.94137 4.02944 0 9 0C13.9706 0 18 3.94137 18 8.80329C18 11.0562 17.1348 13.1114 15.7118 14.6684L23.3531 22.1427C23.5505 22.3358 23.554 22.6524 23.3609 22.8498C23.1678 23.0472 22.8513 23.0507 22.6539 22.8576L14.9967 15.3678Z" fill="#32363A" fill-rule="evenodd"></path>
# </svg>
# <svg fill="none" id="n1_burger" style="display:block;width:0;height:0;" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
# <line stroke="#32363A" x2="30" y1="6.5" y2="6.5"></line>
# <line stroke="#32363A" x2="30" y1="23.5" y2="23.5"></line>
# <line stroke="#32363A" x2="30" y1="15" y2="15"></line>
# </svg>
# <svg fill="none" id="n1_cross_menu" style="display:block;width:0;height:0;" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
# <path d="M4 4L26 26" stroke="#32363A"></path>
# <path d="M26 4L4 26" stroke="#32363A"></path>
# </svg>
# <svg id="n1_check" style="display:block;width:0;height:0;fill:currentColor" version="1.1" viewbox="0 0 752 752" xmlns="http://www.w3.org/2000/svg">
# <path d="m183.6 357.87-22.184 22.168v0.003907c-3.2969 3.293-3.2969 8.6367 0 11.934l133.29 133.28v0.003907c3.7305 3.7266 8.7891 5.8242 14.066 5.8242 5.2734 0 10.332-2.0977 14.062-5.8242l267.76-267.76c1.582-1.582 2.4727-3.7305 2.4727-5.9688 0-2.2383-0.89062-4.3867-2.4727-5.9688l-22.156-22.168c-1.582-1.5898-3.7344-2.4805-5.9727-2.4805-2.2422 0-4.3945 0.89062-5.9766 2.4805l-244.31 244.3c-1.8828 1.8789-4.9336 1.8789-6.8164 0l-109.84-109.83c-3.293-3.2852-8.625-3.2852-11.918 0z"></path>
# </svg>
# <svg id="n1_specials_star" style="display:block;width:0;height:0;fill:none;stroke:white" version="1.1" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg">
# <path d="M7.99982 2.18188L9.79764 5.77236L13.818 6.35166L10.9089 9.14489L11.5955 13.091L7.99982 11.2269L4.40419 13.091L5.09073 9.14489L2.18164 6.35166L6.202 5.77236L7.99982 2.18188Z" stroke-linecap="round"></path>
# </svg>
# <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js"></script><script src="/front-build/js/app.js?id=8f64b9230b5c5522518a6ccb46220bfe"></script>
# <!-- Yandex.Metrika counter 2-->
# <script type="text/javascript">
# (function(m,e,t,r,i,k,a){m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
# 	m[i].l=1*new Date();k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)})
# (window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#
# ym(88946384, "init", {
# 	clickmap:true,
# 	trackLinks:true,
# 	accurateTrackBounce:true,
# 	webvisor:true
# });
#
#
# ym(29654565, "init", {
# 	clickmap:true,
# 	trackLinks:true,
# 	accurateTrackBounce:true,
# 	webvisor:true,
# 	trackHash:true,
# 	ecommerce:"dataLayer"
# });
# </script>
# <noscript>
# <div>
# <img alt="" src="https://mc.yandex.ru/watch/88946384" style="position:absolute; left:-9999px;"/>
# <img alt="" src="https://mc.yandex.ru/watch/29654565" style="position:absolute; left:-9999px;"/>
# </div>
# </noscript>
# <!-- /Yandex.Metrika counter -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-61773772-1"></script>
# <script>
# window.dataLayer = window.dataLayer || [];
# function gtag(){dataLayer.push(arguments);}
# gtag('js', new Date());
# gtag('config', 'UA-61773772-1');
# </script>
# <script>window.yaContextCb = window.yaContextCb || []</script>
# <script async="" src="https://yandex.ru/ads/system/context.js"></script>
# <script>
# if ('serviceWorker' in navigator) {
# 	window.addEventListener('load', () => {
# 		navigator.serviceWorker.register('/front-service-worker.js').then(reg => {
# 			// sometime later…
# 			reg.update()
# 		})
# 	})
# }
# </script>
# </body>
# </html>

# %% [markdown]
# В коде каждой страницы с новостью есть часть с мета-информацией: датой, именем автора и проч. Такая информация окружена тэгом `<meta></meta>`. Посмотрим:

# %%
soup0.find_all('meta')
# Out:
# [<meta charset="utf-8"/>,
#  <meta content="width=device-width, initial-scale=1" name="viewport"/>,
#  <meta content="#f26e40" name="msapplication-TileColor"/>,
#  <meta content="#ffffff" name="theme-color"/>,
#  <meta content="8c90b02c84ac3b72" name="yandex-verification"/>,
#  <meta content="b419949322895fc9106e24ed01be58ac" name="pmail-verification"/>,
#  <meta content="N + 1 — главное издание о науке, технике и технологиях" name="description"/>,
#  <meta content="N + 1 — главное издание о науке, технике и технологиях" property="og:site_name"/>,
#  <meta content="У скифов нашли изделия из человеческой кожи" property="og:title"/>,
#  <meta content="https://minio.nplus1.ru/app-images/868703/657be5cfaa218_cover_share.jpeg" property="og:image"/>,
#  <meta content="https://nplus1.ru/news/2023/12/15/human-skin" property="og:url"/>,
#  <meta content="N + 1 — главное издание о науке, технике и технологиях" property="og:description"/>,
#  <meta content="article" property="og:type"/>,
#  <meta content="2023-12-15" itemprop="datePublished"/>,
#  <meta content="2023-12-15" itemprop="datePublished"/>,
#  <meta content="Михаил Подрезов" name="mediator_author"/>,
#  <meta content="Михаил Подрезов" name="author"/>,
#  <meta content="" name="copyright"/>,
#  <meta content="summary_large_image" name="twitter:card"/>,
#  <meta content="@nplusodin" name="twitter:site"/>,
#  <meta content="У скифов нашли изделия из человеческой кожи" name="twitter:title"/>,
#  <meta content="N + 1 — главное издание о науке, технике и технологиях" name="twitter:description"/>,
#  <meta content="https://minio.nplus1.ru/app-images/868703/657be5cfaa218_cover_share.jpeg" name="twitter:image"/>]

# %%
soup0.find('meta', {'property': 'og:title'}).get('content')
# Out:
# 'У\xa0скифов нашли изделия из\xa0человеческой кожи'

# %%
soup0.find_all('meta', {'itemprop': 'datePublished'})[0].get('content')
# Out:
# '2023-12-15'

# %% [markdown]
# Из этого списка нам нужны части с именем автора, датой, заголовком и кратким описанием. Воспользуемся поиском по атрибуту `name`. Передадим функции `find_all()` в качестве аргумента словарь с названием и значением атрибута:

# %%
soup0.find_all('meta', {'name' : 'author'}) # например, автор
# Out:
# [<meta content="Михаил Подрезов" name="author"/>]

# %% [markdown]
# Теперь выберем единственный элемент полученного списка (с индексом 0):

# %%
soup0.find_all('meta', {'name' : 'author'})[0]
# Out:
# <meta content="Михаил Подрезов" name="author"/>

# %% [markdown]
# Нам нужно вытащить из этого объекта `content` – имя автора. Посмотрим на атрибуты:

# %%
soup0.find_all('meta', {'name' : 'author'})[0].attrs
# Out:
# {'name': 'author', 'content': 'Михаил Подрезов'}

# %% [markdown]
# Как получить отсюда `content`? Очень просто, ведь это словарь! А доставать из словаря значение по ключу мы умеем.

# %%
author = soup0.find('meta', {'name' : 'author'}).get('content')
author
# Out:
# 'Михаил Подрезов'

# %% [markdown]
# Аналогичным образом извлечем дату, заголовок и описание.

# %%
date = soup0.find_all('meta', {'itemprop' : 'datePublished'})[0].get('content')
title = soup0.find_all('meta', {'property' : 'og:title'})[0].get('content')

# %%
title
# Out:
# 'У\xa0скифов нашли изделия из\xa0человеческой кожи'

# %%
date
# Out:
# '2023-12-15'

# %% [markdown]
# Теперь осталось совсем чуть-чуть. Написать готовую функцию для всех проделанных нами действий и применить ее в цикле для всех ссылок в списке `full_urls`. Напишем! Аргументом функции будет ссылка на новость, а возвращать она будет текст новости и всю необходимую информацию (дата, автор, сложность и проч.). Скопируем все строки кода выше.

# %%
def GetNews(url0):
    """
    Возвращает кортеж с url0, date, author, title.
    Параметры:
    
    url0 - ссылка на новость (строка).
    """
    page0 = requests.get(url0)
    soup0 = BeautifulSoup(page0.text, 'html')
    
    author = soup0.find_all('meta', {'name' : 'author'})[0].get('content')
    date = soup0.find_all('meta', {'itemprop' : 'datePublished'})[0].get('content')
    title = soup0.find_all('meta', {'property' : 'og:title'})[0].get('content')
     
    return url0, date, author, title

# %%
help(GetNews)
# Out:
# Help on function GetNews in module __main__:
#
# GetNews(url0)
#     Возвращает кортеж с url0, date, author, title.
#     Параметры:
#
#     url0 - ссылка на новость (строка).

# %% [markdown]
# Уфф. Осталось применить ее в цикле. Но давайте не будем спешить: импортируем функцию `sleep` для задержки, чтобы на каждой итерации цикла, прежде чем перейти к следующей новости, Python ждал несколько секунд. Во-первых, это нужно, чтобы сайт «не понял», чтобы мы его грабим, да еще автоматически. Во-вторых, с небольшой задержкой всегда есть гарантия, что страница прогрузится (сейчас это пока не очень важно, но особенно актуально будет, когда будем обсуждать встраивание в браузер с Selenium). Приступим.

# %%
from time import sleep

# %%
urls
# Out:
# ['https://nplus1.ru/news/2015/09/21/editor-thy-name',
#  'https://nplus1.ru/news/2023/12/15/human-skin',
#  'https://nplus1.ru/news/2023/12/18/parasite-eggs-from-granada',
#  'https://nplus1.ru/news/2023/12/18/medieval-deformed-skull',
#  'https://nplus1.ru/news/2023/12/18/qafzeh-25',
#  'https://nplus1.ru/news/2023/12/16/jwst-bd-light',
#  'https://nplus1.ru/news/2023/12/16/hound-record-100m',
#  'https://nplus1.ru/news/2023/12/16/retracted-2023',
#  'https://nplus1.ru/news/2023/12/16/turn-off',
#  'https://nplus1.ru/news/2023/12/16/label-smart',
#  'https://nplus1.ru/news/2023/12/16/wisdom-dance',
#  'https://nplus1.ru/news/2023/12/15/cr6-forest-fires',
#  'https://nplus1.ru/news/2023/12/15/vega-later-final',
#  'https://nplus1.ru/news/2023/12/15/cute-hot-jupiter',
#  'https://nplus1.ru/news/2023/12/15/ch4-small-arctic-lakes',
#  'https://nplus1.ru/news/2023/12/15/cobalt-catalyzed-borylation',
#  'https://nplus1.ru/news/2023/12/15/domestic-yak',
#  'https://nplus1.ru/news/2023/12/15/birds-vocal-exercises',
#  'https://nplus1.ru/news/2023/12/15/dissatisfaction-guaranteed',
#  'https://nplus1.ru/news/2023/12/14/voyager-1-ill',
#  'https://nplus1.ru/news/2023/12/14/nemesia-berlandi',
#  'https://nplus1.ru/news/2023/12/14/%D1%81hlorophanes-spiza',
#  'https://nplus1.ru/news/2023/12/14/helicobacter-pylori-and-alzheimers-disease',
#  'https://nplus1.ru/news/2023/12/14/chronic-hcv',
#  'https://nplus1.ru/news/2023/12/14/sausage-catastrophe',
#  'https://nplus1.ru/news/2023/12/14/caries-prevalence',
#  'https://nplus1.ru/news/2023/12/14/lonelinflammation',
#  'https://nplus1.ru/news/2023/12/14/robot-tesla-optimus-gen-2',
#  'https://nplus1.ru/news/2023/12/14/abdominal-ectopic-pregnancy',
#  'https://nplus1.ru/news/2023/12/13/sick-of-gdf',
#  'https://nplus1.ru/news/2023/12/13/aboriginal-australians',
#  'https://nplus1.ru/news/2023/12/13/hyundai-memory-allow-integrated-snow-chain',
#  'https://nplus1.ru/news/2023/12/13/dementia-after-stroke',
#  'https://nplus1.ru/news/2023/12/13/sap-tbi',
#  'https://nplus1.ru/news/2023/12/13/haliotis-rufescens',
#  'https://nplus1.ru/news/2023/12/13/cliff-tomb-from-china',
#  'https://nplus1.ru/news/2023/12/13/brain-untouched',
#  'https://nplus1.ru/news/2023/12/13/emoji-zoo',
#  'https://nplus1.ru/news/2023/12/13/ketogenic-diet-in-polycystic-kidney-disease',
#  'https://nplus1.ru/news/2023/12/05/automatic-transmission-for-bicycle-haven-mercer',
#  'https://nplus1.ru/news/2023/11/28/the-largest-iceberg-ever',
#  'https://nplus1.ru/news/2023/11/27/droplet-kilovolt-discharge',
#  'https://nplus1.ru/news/2023/11/27/lidocaine-induces-apoptosis-in-carcinoma',
#  'https://nplus1.ru/news/2023/11/28/meteorite-in-bed',
#  'https://nplus1.ru/news/2023/12/01/disprozii-poimali-v-lovusku',
#  'https://nplus1.ru/news/2023/12/04/the-lord-of-the-hopfion-rings',
#  'https://nplus1.ru/news/2023/12/05/kartvelian-linguistic-family',
#  'https://nplus1.ru/news/2023/12/06/mutations-intercoursed',
#  'https://nplus1.ru/news/2023/12/08/jt-60-sa',
#  'https://nplus1.ru/news/2023/12/11/time-resolution-accuracy',
#  'https://nplus1.ru/news/2023/12/11/poligonal-faraday-waves',
#  'https://nplus1.ru/news/2023/12/13/brain-untouched',
#  'https://nplus1.ru/news/2023/12/13/aboriginal-australians']

# %%
news = [] # это будет список из кортежей, в которых будут храниться данные по каждой новости

for link in urls[1:]:
    print(link)
    res = GetNews(link)
    news.append(res)
        
    sleep(3) # задержка в 3 секунды
# Out:
# https://nplus1.ru/news/2023/12/15/human-skin
# https://nplus1.ru/news/2023/12/18/parasite-eggs-from-granada
# https://nplus1.ru/news/2023/12/18/medieval-deformed-skull
# https://nplus1.ru/news/2023/12/18/qafzeh-25
# https://nplus1.ru/news/2023/12/16/jwst-bd-light
# https://nplus1.ru/news/2023/12/16/hound-record-100m
# https://nplus1.ru/news/2023/12/16/retracted-2023
# https://nplus1.ru/news/2023/12/16/turn-off
# https://nplus1.ru/news/2023/12/16/label-smart
# https://nplus1.ru/news/2023/12/16/wisdom-dance
# https://nplus1.ru/news/2023/12/15/cr6-forest-fires
# https://nplus1.ru/news/2023/12/15/vega-later-final
# https://nplus1.ru/news/2023/12/15/cute-hot-jupiter
# https://nplus1.ru/news/2023/12/15/ch4-small-arctic-lakes
# https://nplus1.ru/news/2023/12/15/cobalt-catalyzed-borylation
# https://nplus1.ru/news/2023/12/15/domestic-yak
# https://nplus1.ru/news/2023/12/15/birds-vocal-exercises
# https://nplus1.ru/news/2023/12/15/dissatisfaction-guaranteed
# https://nplus1.ru/news/2023/12/14/voyager-1-ill
# https://nplus1.ru/news/2023/12/14/nemesia-berlandi
# https://nplus1.ru/news/2023/12/14/%D1%81hlorophanes-spiza
# https://nplus1.ru/news/2023/12/14/helicobacter-pylori-and-alzheimers-disease
# https://nplus1.ru/news/2023/12/14/chronic-hcv
# https://nplus1.ru/news/2023/12/14/sausage-catastrophe
# https://nplus1.ru/news/2023/12/14/caries-prevalence
# https://nplus1.ru/news/2023/12/14/lonelinflammation
# https://nplus1.ru/news/2023/12/14/robot-tesla-optimus-gen-2
# https://nplus1.ru/news/2023/12/14/abdominal-ectopic-pregnancy
# https://nplus1.ru/news/2023/12/13/sick-of-gdf
# https://nplus1.ru/news/2023/12/13/aboriginal-australians
# https://nplus1.ru/news/2023/12/13/hyundai-memory-allow-integrated-snow-chain
# https://nplus1.ru/news/2023/12/13/dementia-after-stroke
# https://nplus1.ru/news/2023/12/13/sap-tbi
# https://nplus1.ru/news/2023/12/13/haliotis-rufescens
# https://nplus1.ru/news/2023/12/13/cliff-tomb-from-china
# https://nplus1.ru/news/2023/12/13/brain-untouched
# https://nplus1.ru/news/2023/12/13/emoji-zoo
# https://nplus1.ru/news/2023/12/13/ketogenic-diet-in-polycystic-kidney-disease
# https://nplus1.ru/news/2023/12/05/automatic-transmission-for-bicycle-haven-mercer
# https://nplus1.ru/news/2023/11/28/the-largest-iceberg-ever
# https://nplus1.ru/news/2023/11/27/droplet-kilovolt-discharge
# https://nplus1.ru/news/2023/11/27/lidocaine-induces-apoptosis-in-carcinoma
# https://nplus1.ru/news/2023/11/28/meteorite-in-bed
# https://nplus1.ru/news/2023/12/01/disprozii-poimali-v-lovusku
# https://nplus1.ru/news/2023/12/04/the-lord-of-the-hopfion-rings
# https://nplus1.ru/news/2023/12/05/kartvelian-linguistic-family
# https://nplus1.ru/news/2023/12/06/mutations-intercoursed
# https://nplus1.ru/news/2023/12/08/jt-60-sa
# https://nplus1.ru/news/2023/12/11/time-resolution-accuracy
# https://nplus1.ru/news/2023/12/11/poligonal-faraday-waves
# https://nplus1.ru/news/2023/12/13/brain-untouched
# https://nplus1.ru/news/2023/12/13/aboriginal-australians

# %%
news
# Out:
# [('https://nplus1.ru/news/2023/12/15/human-skin',
#   '2023-12-15',
#   'Михаил Подрезов',
#   'У\xa0скифов нашли изделия из\xa0человеческой кожи'),
#  ('https://nplus1.ru/news/2023/12/18/parasite-eggs-from-granada',
#   '2023-12-18',
#   'Михаил Подрезов',
#   'В\xa0старинных выгребных ямах Гранады нашли яйца кишечных паразитов'),
#  ('https://nplus1.ru/news/2023/12/18/medieval-deformed-skull',
#   '2023-12-18',
#   'Михаил Подрезов',
#   'Женщина с\xa0искусственно деформированным черепом обрела лицо'),
#  ('https://nplus1.ru/news/2023/12/18/qafzeh-25',
#   '2023-12-18',
#   'Михаил Подрезов',
#   'Архаичного сапиенса из\xa0пещеры Кафзех ранили в\xa0челюсть'),
#  ('https://nplus1.ru/news/2023/12/16/jwst-bd-light',
#   '2023-12-16',
#   'Александр Войтюк',
#   '«Джеймс Уэбб» напрямую рассмотрел кандидата в\xa0рекордно легкий одиночный коричневый карлик'),
#  ('https://nplus1.ru/news/2023/12/16/hound-record-100m',
#   '2023-12-16',
#   'Андрей Фокин',
#   'Корейская робособака установила рекорд среди четвероногих роботов в\xa0забеге на\xa0100 метров'),
#  ('https://nplus1.ru/news/2023/12/16/retracted-2023',
#   '2023-12-16',
#   'Катерина Петрова',
#   'Больше десяти тысяч научных статей отозвали в\xa02023 году'),
#  ('https://nplus1.ru/news/2023/12/16/turn-off',
#   '2023-12-16',
#   'Олег Лищук',
#   'Изменение сознания при медитации зафиксировали на\xa0энцефалограмме'),
#  ('https://nplus1.ru/news/2023/12/16/label-smart',
#   '2023-12-16',
#   'Олег Лищук',
#   'Метки «веганский» и\xa0«растительный» не\xa0привлекли людей к\xa0продуктам без мяса'),
#  ('https://nplus1.ru/news/2023/12/16/wisdom-dance',
#   '2023-12-16',
#   'Сергей Коленов',
#   'Самая старая дикая птица вернулась на\xa0родной атолл и\xa0поучаствовала в\xa0брачных танцах'),
#  ('https://nplus1.ru/news/2023/12/15/cr6-forest-fires',
#   '2023-12-15',
#   'Марина Попова',
#   'Пожары в\xa0Калифорнии оказались опасным источником шестивалентного хрома'),
#  ('https://nplus1.ru/news/2023/12/15/vega-later-final',
#   '2023-12-15',
#   'Александр Войтюк',
#   'Финальный пуск ракеты Vega перенесли на\xa0осень 2024 года'),
#  ('https://nplus1.ru/news/2023/12/15/cute-hot-jupiter',
#   '2023-12-15',
#   'Александр Войтюк',
#   'Космический телескоп размером с\xa0обувную коробку заметил потерю атмосферы горячим юпитером'),
#  ('https://nplus1.ru/news/2023/12/15/ch4-small-arctic-lakes',
#   '2023-12-15',
#   'Марина Попова',
#   'Эмиссия метана арктическими озерами оказалась завышена на\xa020\xa0процентов'),
#  ('https://nplus1.ru/news/2023/12/15/cobalt-catalyzed-borylation',
#   '2023-12-15',
#   'Михаил Бойм',
#   'Кобальтовый катализатор помог провести реакцию борилирования аренов'),
#  ('https://nplus1.ru/news/2023/12/15/domestic-yak',
#   '2023-12-15',
#   'Михаил Подрезов',
#   'Жители Тибета разводили домашних яков не\xa0меньше 2500 лет назад'),
#  ('https://nplus1.ru/news/2023/12/15/birds-vocal-exercises',
#   '2023-12-15',
#   'Катерина Петрова',
#   'Зебровые амадины запели хуже после недели без тренировок'),
#  ('https://nplus1.ru/news/2023/12/15/dissatisfaction-guaranteed',
#   '2023-12-15',
#   'Олег Лищук',
#   'Избыток массы в\xa07\xa0лет связали с\xa0депрессией в\xa014\xa0лет'),
#  ('https://nplus1.ru/news/2023/12/14/voyager-1-ill',
#   '2023-12-14',
#   'Александр Войтюк',
#   '«Вояджер-1» прекратил передачу данных на\xa0Землю'),
#  ('https://nplus1.ru/news/2023/12/14/nemesia-berlandi',
#   '2023-12-14',
#   'Сергей Коленов',
#   'Потерянного паука из\xa0Португалии переоткрыли спустя 92\xa0года'),
#  ('https://nplus1.ru/news/2023/12/14/%D1%81hlorophanes-spiza',
#   '2023-12-14',
#   'Сергей Коленов',
#   'В\xa0Колумбии встретили танагру-гинандроморфа'),
#  ('https://nplus1.ru/news/2023/12/14/helicobacter-pylori-and-alzheimers-disease',
#   '2023-12-14',
#   'Слава Гоменюк',
#   'Хеликобактерную инфекцию связали с\xa0повышенным риском болезни Альцгеймера'),
#  ('https://nplus1.ru/news/2023/12/14/chronic-hcv',
#   '2023-12-14',
#   'Слава Гоменюк',
#   'Италия стала лидером по\xa0абсолютному числу случаев гепатита C\xa0в Европе'),
#  ('https://nplus1.ru/news/2023/12/14/sausage-catastrophe',
#   '2023-12-14',
#   'Артем Моськин',
#   'Группа коллоидных частиц устроила колбасный коллапс упаковки'),
#  ('https://nplus1.ru/news/2023/12/14/caries-prevalence',
#   '2023-12-14',
#   'Михаил Подрезов',
#   'Половина средневековых скандинавов пострадала от\xa0кариеса'),
#  ('https://nplus1.ru/news/2023/12/14/lonelinflammation',
#   '2023-12-14',
#   'Олег Лищук',
#   'У\xa0одиноких обнаружили признаки хронического системного воспаления'),
#  ('https://nplus1.ru/news/2023/12/14/robot-tesla-optimus-gen-2',
#   '2023-12-14',
#   'Андрей Фокин',
#   'Человекоподобный робот Tesla Optimus второго поколения поприседал'),
#  ('https://nplus1.ru/news/2023/12/14/abdominal-ectopic-pregnancy',
#   '2023-12-14',
#   'Слава Гоменюк',
#   'Француженка с\xa0Реюньона выносила ребенка в\xa0брюшной полости'),
#  ('https://nplus1.ru/news/2023/12/13/sick-of-gdf',
#   '2023-12-13',
#   'Олег Лищук',
#   'Причиной тошноты беременных назвали чувствительность к\xa0гормону плода'),
#  ('https://nplus1.ru/news/2023/12/13/aboriginal-australians',
#   '2023-12-13',
#   'Михаил Подрезов',
#   'Предки австралийских аборигенов и\xa0папуасов разошлись примерно 47\xa0тысяч лет назад'),
#  ('https://nplus1.ru/news/2023/12/13/hyundai-memory-allow-integrated-snow-chain',
#   '2023-12-13',
#   'Андрей Фокин',
#   'Hyundai представила концепт интегрированного в\xa0колесо устройства противоскольжения'),
#  ('https://nplus1.ru/news/2023/12/13/dementia-after-stroke',
#   '2023-12-13',
#   'Слава Гоменюк',
#   'Когнитивные нарушения повысили риск развития деменции после инсульта'),
#  ('https://nplus1.ru/news/2023/12/13/sap-tbi',
#   '2023-12-13',
#   'Катерина Петрова',
#   'В\xa0нейронах после черепно-мозговой травмы обнаружили нейротоксичный белок'),
#  ('https://nplus1.ru/news/2023/12/13/haliotis-rufescens',
#   '2023-12-13',
#   'Марина Попова',
#   'Взросление в\xa0подкисленной воде испортило жизнь красным морским ушкам и\xa0их\xa0потомству'),
#  ('https://nplus1.ru/news/2023/12/13/cliff-tomb-from-china',
#   '2023-12-13',
#   'Михаил Подрезов',
#   'Древнекитайская скальная гробница оказалась семейной усыпальницей'),
#  ('https://nplus1.ru/news/2023/12/13/brain-untouched',
#   '2023-12-13',
#   'Олег Лищук',
#   'CAR-T-лимфоциты третьего поколения оказались эффективными без нейротоксичности'),
#  ('https://nplus1.ru/news/2023/12/13/emoji-zoo',
#   '2023-12-13',
#   'Сергей Коленов',
#   'Эмодзи плохо справились с\xa0отражением биоразнообразия'),
#  ('https://nplus1.ru/news/2023/12/13/ketogenic-diet-in-polycystic-kidney-disease',
#   '2023-12-13',
#   'Слава Гоменюк',
#   'Кетогенная диета облегчила симптомы поликистозной болезни почек'),
#  ('https://nplus1.ru/news/2023/12/05/automatic-transmission-for-bicycle-haven-mercer',
#   '2023-12-05',
#   'Андрей Фокин',
#   'Американский изобретатель запатентовал автоматическую велосипедную трансмиссию'),
#  ('https://nplus1.ru/news/2023/11/28/the-largest-iceberg-ever',
#   '2023-11-28',
#   'Марина Попова',
#   'От\xa0Антарктиды отделился айсберг размером с\xa0половину Адыгеи'),
#  ('https://nplus1.ru/news/2023/11/27/droplet-kilovolt-discharge',
#   '2023-11-27',
#   'Дмитрий Рудик',
#   'Падающая капля воды вызвала искровой разряд в\xa01200 вольт'),
#  ('https://nplus1.ru/news/2023/11/27/lidocaine-induces-apoptosis-in-carcinoma',
#   '2023-11-27',
#   'Слава Гоменюк',
#   'Лидокаин запустил апоптоз опухолевых клеток через рецептор горького вкуса'),
#  ('https://nplus1.ru/news/2023/11/28/meteorite-in-bed',
#   '2023-11-28',
#   'Александр Войтюк',
#   'Упавший на\xa0подушку канадки метеорит прибыл из\xa0внутренней части Главного пояса астероидов'),
#  ('https://nplus1.ru/news/2023/12/01/disprozii-poimali-v-lovusku',
#   '2023-12-01',
#   'Оксана Борзенкова',
#   'Диспрозий поймали в\xa0магическую ловушку'),
#  ('https://nplus1.ru/news/2023/12/04/the-lord-of-the-hopfion-rings',
#   '2023-12-04',
#   'Артем Моськин',
#   'Физики обжали скирмионную струну хопфионным кольцом'),
#  ('https://nplus1.ru/news/2023/12/05/kartvelian-linguistic-family',
#   '2023-12-05',
#   'Михаил Подрезов',
#   'Распад пракартвельского языка удревнили примерно на\xa0три тысячи лет'),
#  ('https://nplus1.ru/news/2023/12/06/mutations-intercoursed',
#   '2023-12-06',
#   'Олег Лищук',
#   'Мутагенез при образовании половых клеток оказался восьмикратно недооценен'),
#  ('https://nplus1.ru/news/2023/12/08/jt-60-sa',
#   '2023-12-08',
#   'Александр Войтюк',
#   'В\xa0Японии запущен крупнейший сверхпроводящий токамак JT-60SA'),
#  ('https://nplus1.ru/news/2023/12/11/time-resolution-accuracy',
#   '2023-12-11',
#   'Дмитрий Рудик',
#   'Измерение времени ограничили в\xa0точности и\xa0разрешении'),
#  ('https://nplus1.ru/news/2023/12/11/poligonal-faraday-waves',
#   '2023-12-11',
#   'Артем Моськин',
#   'Вибрирующий вок сформировал многоугольники из\xa0воды'),
#  ('https://nplus1.ru/news/2023/12/13/brain-untouched',
#   '2023-12-13',
#   'Олег Лищук',
#   'CAR-T-лимфоциты третьего поколения оказались эффективными без нейротоксичности'),
#  ('https://nplus1.ru/news/2023/12/13/aboriginal-australians',
#   '2023-12-13',
#   'Михаил Подрезов',
#   'Предки австралийских аборигенов и\xa0папуасов разошлись примерно 47\xa0тысяч лет назад')]

# %% [markdown]
# Так теперь выглядит первый элемент списка:

# %% [markdown]
# Импортируем `pandas` и создадим датафрейм из списка кортежей:

# %%
import pandas as pd

# %%
df = pd.DataFrame(news)

# %%
df.head(10)
# Out:
#                                                    0           1  \
# 0       https://nplus1.ru/news/2023/12/15/human-skin  2023-12-15
# 1  https://nplus1.ru/news/2023/12/18/parasite-egg...  2023-12-18
# 2  https://nplus1.ru/news/2023/12/18/medieval-def...  2023-12-18
# 3        https://nplus1.ru/news/2023/12/18/qafzeh-25  2023-12-18
# 4    https://nplus1.ru/news/2023/12/16/jwst-bd-light  2023-12-16
# 5  https://nplus1.ru/news/2023/12/16/hound-record...  2023-12-16
# 6   https://nplus1.ru/news/2023/12/16/retracted-2023  2023-12-16
# 7         https://nplus1.ru/news/2023/12/16/turn-off  2023-12-16
# 8      https://nplus1.ru/news/2023/12/16/label-smart  2023-12-16
# 9     https://nplus1.ru/news/2023/12/16/wisdom-dance  2023-12-16
#
#                   2                                                  3
# 0   Михаил Подрезов        У скифов нашли изделия из человеческой кожи
# 1   Михаил Подрезов  В старинных выгребных ямах Гранады нашли яйца ...
# 2   Михаил Подрезов  Женщина с искусственно деформированным черепом...
# 3   Михаил Подрезов  Архаичного сапиенса из пещеры Кафзех ранили в ...
# 4  Александр Войтюк  «Джеймс Уэбб» напрямую рассмотрел кандидата в ...
# 5      Андрей Фокин  Корейская робособака установила рекорд среди ч...
# 6  Катерина Петрова  Больше десяти тысяч научных статей отозвали в ...
# 7        Олег Лищук  Изменение сознания при медитации зафиксировали...
# 8        Олег Лищук  Метки «веганский» и «растительный» не привлекл...
# 9    Сергей Коленов  Самая старая дикая птица вернулась на родной а...

# %% [markdown]
# Переименуем столбцы в базе.

# %%
df.columns = ['link', 'date', 'author', 'title']

# %%
df.head()
# Out:
#                                                 link        date  \
# 0       https://nplus1.ru/news/2023/12/15/human-skin  2023-12-15
# 1  https://nplus1.ru/news/2023/12/18/parasite-egg...  2023-12-18
# 2  https://nplus1.ru/news/2023/12/18/medieval-def...  2023-12-18
# 3        https://nplus1.ru/news/2023/12/18/qafzeh-25  2023-12-18
# 4    https://nplus1.ru/news/2023/12/16/jwst-bd-light  2023-12-16
#
#              author                                              title
# 0   Михаил Подрезов        У скифов нашли изделия из человеческой кожи
# 1   Михаил Подрезов  В старинных выгребных ямах Гранады нашли яйца ...
# 2   Михаил Подрезов  Женщина с искусственно деформированным черепом...
# 3   Михаил Подрезов  Архаичного сапиенса из пещеры Кафзех ранили в ...
# 4  Александр Войтюк  «Джеймс Уэбб» напрямую рассмотрел кандидата в ...

# %% [markdown]
# Всё! Сохраняем датафрейм в файл. Для разнообразия сохраним в Excel:

# %%
df.to_excel('nplus-news.xlsx', index=False)
